# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots
const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter = 1_000_000
include("functions.jl")
Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :          
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :     
    error("Unknown data tag: $tag")

model_tag_sym = :powerlaw
data_tag_sym  = :powerlaw

KMAX_UPPER = 30  

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

# Fixed output dir
out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = []
if model_tag_sym === :memoryless
    global header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    global header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    global header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    global header_cont = ["beta", "alpha", "gamma", "lambda_R"] 
elseif model_tag_sym === :sliding
    global header_cont = ["beta", "alpha", "gamma"]            
else
    error("Unknown model tag: $(model_tag_sym)")
end

i = 2
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))
@info "[$(String(model_tag_sym))_model_$(String(data_tag_sym))_data] Fitting dataset $(i) chain $(c) (tau=$tau)"

Random.seed!(2025 + i * 100 + c)
initθ_chain = initθ_for_chain(model_tag_sym) 
t0 = Dates.now()

try
    samples, loglik_aug_vecs =
        mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
            fit_mech=model_tag_sym,
            n_iter=n_iter,
            initθ=initθ_chain,
            KMAX_UPPER=KMAX_UPPER)

    if size(samples, 1) != n_iter
        error("Chain $c did not complete all iterations.")
    end

    # Save samples
    samples_filename = "samples_sim_$(i)_chain_$(c).csv"
    write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

    # Save per-time log-likelihoods (thinned & post-burnin inside mcmc)
    loglik_filename = "loglik_sim_$(i)_chain_$(c).csv"
    write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

    el = Dates.value(Dates.now() - t0) / 1000
    @info(@sprintf("Dataset %03d chain %d: ok in %.2fs", i, c, el))
catch err
    el = Dates.value(Dates.now() - t0) / 1000
    @warn(@sprintf("Dataset %03d chain %d: ERROR - %s after %.2fs", i, c, err))
end

@info "Chain completed -> output dir: $out_dir"
# Out:
# [ Info: [powerlaw_model_powerlaw_data] Fitting dataset 2 chain 1 (tau=50)
# [ Info: [powerlaw] iter 1000/1000000 elapsed=3.5s, rate=0.326, medians=[0.767, 0.00454, 0.320, 0.615], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 2000/1000000 elapsed=7.4s, rate=0.332, medians=[0.782, 0.00449, 0.327, 0.620], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 3000/1000000 elapsed=10.6s, rate=0.343, medians=[0.796, 0.00445, 0.340, 0.635], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 4000/1000000 elapsed=13.8s, rate=0.356, medians=[0.800, 0.00452, 0.353, 0.640], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 5000/1000000 elapsed=17.0s, rate=0.363, medians=[0.805, 0.00454, 0.362, 0.645], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 6000/1000000 elapsed=20.2s, rate=0.368, medians=[0.808, 0.00459, 0.368, 0.645], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 7000/1000000 elapsed=23.4s, rate=0.371, medians=[0.810, 0.00458, 0.369, 0.647], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 8000/1000000 elapsed=26.6s, rate=0.371, medians=[0.811, 0.00458, 0.371, 0.648], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 9000/1000000 elapsed=29.8s, rate=0.375, medians=[0.810, 0.00461, 0.373, 0.648], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 10000/1000000 elapsed=33.0s, rate=0.376, medians=[0.812, 0.00461, 0.376, 0.650], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 11000/1000000 elapsed=36.2s, rate=0.385, medians=[0.815, 0.00466, 0.384, 0.652], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 12000/1000000 elapsed=39.4s, rate=0.393, medians=[0.819, 0.00469, 0.393, 0.656], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 13000/1000000 elapsed=42.6s, rate=0.395, medians=[0.822, 0.00471, 0.398, 0.658], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 14000/1000000 elapsed=45.8s, rate=0.397, medians=[0.824, 0.00472, 0.402, 0.660], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 15000/1000000 elapsed=49.0s, rate=0.401, medians=[0.827, 0.00471, 0.405, 0.663], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 16000/1000000 elapsed=52.2s, rate=0.402, medians=[0.829, 0.00472, 0.409, 0.665], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 17000/1000000 elapsed=55.4s, rate=0.403, medians=[0.832, 0.00470, 0.410, 0.666], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 18000/1000000 elapsed=58.6s, rate=0.405, medians=[0.834, 0.00471, 0.414, 0.668], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 19000/1000000 elapsed=61.8s, rate=0.407, medians=[0.837, 0.00470, 0.416, 0.671], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 20000/1000000 elapsed=65.0s, rate=0.405, medians=[0.837, 0.00469, 0.416, 0.671], std=[0.0035, 0.000035, 0.0035, 0.0035] [ADAPT]
# [ Info: [powerlaw] iter 21000/1000000 elapsed=68.2s, rate=0.403, medians=[0.837, 0.00467, 0.413, 0.670], std=[0.0359, 0.001106, 0.0527, 0.0320] [ADAPT]
# [ Info: [powerlaw] iter 22000/1000000 elapsed=71.4s, rate=0.401, medians=[0.835, 0.00466, 0.409, 0.669], std=[0.0366, 0.001106, 0.0546, 0.0323] [ADAPT]
# [ Info: [powerlaw] iter 23000/1000000 elapsed=74.6s, rate=0.397, medians=[0.832, 0.00465, 0.405, 0.666], std=[0.0378, 0.001107, 0.0574, 0.0335] [ADAPT]
# [ Info: [powerlaw] iter 24000/1000000 elapsed=77.8s, rate=0.396, medians=[0.831, 0.00464, 0.402, 0.664], std=[0.0382, 0.001107, 0.0587, 0.0349] [ADAPT]
# [ Info: [powerlaw] iter 25000/1000000 elapsed=81.0s, rate=0.393, medians=[0.828, 0.00464, 0.398, 0.661], std=[0.0396, 0.001106, 0.0601, 0.0373] [ADAPT]
# [ Info: [powerlaw] iter 26000/1000000 elapsed=84.3s, rate=0.390, medians=[0.827, 0.00463, 0.396, 0.660], std=[0.0397, 0.001106, 0.0609, 0.0376] [ADAPT]
# [ Info: [powerlaw] iter 27000/1000000 elapsed=87.5s, rate=0.388, medians=[0.826, 0.00462, 0.393, 0.659], std=[0.0396, 0.001106, 0.0611, 0.0373] [ADAPT]
# [ Info: [powerlaw] iter 28000/1000000 elapsed=90.7s, rate=0.386, medians=[0.824, 0.00462, 0.392, 0.658], std=[0.0395, 0.001104, 0.0606, 0.0369] [ADAPT]
# [ Info: [powerlaw] iter 29000/1000000 elapsed=93.9s, rate=0.386, medians=[0.824, 0.00461, 0.391, 0.658], std=[0.0391, 0.001104, 0.0598, 0.0366] [ADAPT]
# [ Info: [powerlaw] iter 30000/1000000 elapsed=97.1s, rate=0.386, medians=[0.824, 0.00460, 0.390, 0.659], std=[0.0387, 0.001105, 0.0590, 0.0362] [ADAPT]
# [ Info: [powerlaw] iter 31000/1000000 elapsed=100.3s, rate=0.387, medians=[0.825, 0.00460, 0.391, 0.659], std=[0.0383, 0.001105, 0.0582, 0.0358] [ADAPT]
# [ Info: [powerlaw] iter 32000/1000000 elapsed=103.5s, rate=0.388, medians=[0.826, 0.00461, 0.392, 0.659], std=[0.0382, 0.001105, 0.0580, 0.0356] [ADAPT]
# [ Info: [powerlaw] iter 33000/1000000 elapsed=106.7s, rate=0.388, medians=[0.826, 0.00461, 0.393, 0.660], std=[0.0380, 0.001104, 0.0574, 0.0354] [ADAPT]
# [ Info: [powerlaw] iter 34000/1000000 elapsed=109.9s, rate=0.388, medians=[0.825, 0.00461, 0.392, 0.660], std=[0.0380, 0.001103, 0.0569, 0.0351] [ADAPT]
# [ Info: [powerlaw] iter 35000/1000000 elapsed=113.2s, rate=0.387, medians=[0.825, 0.00461, 0.391, 0.659], std=[0.0375, 0.001103, 0.0563, 0.0348] [ADAPT]
# [ Info: [powerlaw] iter 36000/1000000 elapsed=116.4s, rate=0.386, medians=[0.825, 0.00460, 0.391, 0.659], std=[0.0373, 0.001102, 0.0558, 0.0344] [ADAPT]
# [ Info: [powerlaw] iter 37000/1000000 elapsed=119.6s, rate=0.385, medians=[0.825, 0.00460, 0.390, 0.659], std=[0.0369, 0.001101, 0.0551, 0.0340] [ADAPT]
# [ Info: [powerlaw] iter 38000/1000000 elapsed=122.8s, rate=0.386, medians=[0.825, 0.00460, 0.391, 0.660], std=[0.0366, 0.001101, 0.0547, 0.0341] [ADAPT]
# [ Info: [powerlaw] iter 39000/1000000 elapsed=126.0s, rate=0.387, medians=[0.826, 0.00460, 0.392, 0.660], std=[0.0364, 0.001100, 0.0541, 0.0338] [ADAPT]
# [ Info: [powerlaw] iter 40000/1000000 elapsed=129.2s, rate=0.387, medians=[0.826, 0.00461, 0.392, 0.660], std=[0.0360, 0.001100, 0.0537, 0.0336] [ADAPT]
# [ Info: [powerlaw] iter 41000/1000000 elapsed=132.4s, rate=0.387, medians=[0.826, 0.00460, 0.392, 0.661], std=[0.0357, 0.001101, 0.0531, 0.0334] [ADAPT]
# [ Info: [powerlaw] iter 42000/1000000 elapsed=135.6s, rate=0.387, medians=[0.826, 0.00460, 0.392, 0.660], std=[0.0354, 0.001100, 0.0527, 0.0331] [ADAPT]
# [ Info: [powerlaw] iter 43000/1000000 elapsed=138.8s, rate=0.387, medians=[0.826, 0.00460, 0.391, 0.660], std=[0.0352, 0.001100, 0.0522, 0.0329] [ADAPT]
# [ Info: [powerlaw] iter 44000/1000000 elapsed=142.0s, rate=0.386, medians=[0.825, 0.00459, 0.390, 0.659], std=[0.0352, 0.001099, 0.0525, 0.0330] [ADAPT]
# [ Info: [powerlaw] iter 45000/1000000 elapsed=145.2s, rate=0.384, medians=[0.824, 0.00458, 0.388, 0.659], std=[0.0351, 0.001102, 0.0533, 0.0328] [ADAPT]
# [ Info: [powerlaw] iter 46000/1000000 elapsed=148.5s, rate=0.382, medians=[0.824, 0.00457, 0.387, 0.658], std=[0.0350, 0.001103, 0.0536, 0.0326] [ADAPT]
# [ Info: [powerlaw] iter 47000/1000000 elapsed=151.7s, rate=0.381, medians=[0.823, 0.00457, 0.385, 0.657], std=[0.0353, 0.001103, 0.0545, 0.0331] [ADAPT]
# [ Info: [powerlaw] iter 48000/1000000 elapsed=154.9s, rate=0.379, medians=[0.822, 0.00456, 0.384, 0.657], std=[0.0353, 0.001103, 0.0549, 0.0331] [ADAPT]
# [ Info: [powerlaw] iter 49000/1000000 elapsed=158.1s, rate=0.379, medians=[0.822, 0.00456, 0.383, 0.656], std=[0.0353, 0.001103, 0.0548, 0.0336] [ADAPT]
# [ Info: [powerlaw] iter 50000/1000000 elapsed=161.3s, rate=0.378, medians=[0.822, 0.00456, 0.382, 0.656], std=[0.0350, 0.001103, 0.0544, 0.0334] [ADAPT]
# [ Info: [powerlaw] iter 51000/1000000 elapsed=164.5s, rate=0.378, medians=[0.822, 0.00456, 0.382, 0.656], std=[0.0348, 0.001103, 0.0540, 0.0331] [ADAPT]
# [ Info: [powerlaw] iter 52000/1000000 elapsed=167.7s, rate=0.377, medians=[0.822, 0.00456, 0.382, 0.656], std=[0.0346, 0.001103, 0.0537, 0.0330] [ADAPT]
# [ Info: [powerlaw] iter 53000/1000000 elapsed=170.9s, rate=0.378, medians=[0.822, 0.00456, 0.383, 0.656], std=[0.0347, 0.001103, 0.0535, 0.0327] [ADAPT]
# [ Info: [powerlaw] iter 54000/1000000 elapsed=174.2s, rate=0.379, medians=[0.823, 0.00457, 0.384, 0.656], std=[0.0349, 0.001102, 0.0535, 0.0327] [ADAPT]
# [ Info: [powerlaw] iter 55000/1000000 elapsed=177.4s, rate=0.379, medians=[0.823, 0.00456, 0.384, 0.657], std=[0.0348, 0.001102, 0.0532, 0.0329] [ADAPT]
# [ Info: [powerlaw] iter 56000/1000000 elapsed=180.6s, rate=0.379, medians=[0.824, 0.00456, 0.385, 0.658], std=[0.0348, 0.001102, 0.0530, 0.0331] [ADAPT]
# [ Info: [powerlaw] iter 57000/1000000 elapsed=183.8s, rate=0.380, medians=[0.824, 0.00457, 0.386, 0.658], std=[0.0346, 0.001102, 0.0528, 0.0330] [ADAPT]
# [ Info: [powerlaw] iter 58000/1000000 elapsed=187.0s, rate=0.380, medians=[0.825, 0.00456, 0.386, 0.659], std=[0.0347, 0.001102, 0.0525, 0.0330] [ADAPT]
# [ Info: [powerlaw] iter 59000/1000000 elapsed=190.2s, rate=0.381, medians=[0.825, 0.00456, 0.386, 0.659], std=[0.0345, 0.001101, 0.0521, 0.0328] [ADAPT]
