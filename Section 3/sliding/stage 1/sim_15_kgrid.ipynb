# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")
    
model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 15
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.399, medians=[0.721, 0.00980, 0.467], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.5s, rate=0.352, medians=[0.750, 0.01286, 0.573], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.8s, rate=0.373, medians=[0.802, 0.01512, 0.700], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.1s, rate=0.399, medians=[0.862, 0.01688, 0.857], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.4s, rate=0.424, medians=[0.917, 0.01836, 1.025], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.6s, rate=0.453, medians=[0.962, 0.01954, 1.186], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.9s, rate=0.471, medians=[0.997, 0.02060, 1.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.2s, rate=0.491, medians=[1.024, 0.02145, 1.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.5s, rate=0.501, medians=[1.047, 0.02217, 1.551], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.7s, rate=0.512, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=38.0s, rate=0.522, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=41.3s, rate=0.530, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.5s, rate=0.538, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.8s, rate=0.544, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=51.0s, rate=0.547, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=54.3s, rate=0.551, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.5s, rate=0.555, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.8s, rate=0.558, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=64.1s, rate=0.560, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=67.3s, rate=0.562, medians=[1.066, 0.02273, 1.646], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=1: ok in 71.31s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.312, medians=[0.687, 0.00963, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.289, medians=[0.704, 0.01201, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.315, medians=[0.758, 0.01341, 0.599], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.347, medians=[0.821, 0.01446, 0.727], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.375, medians=[0.879, 0.01552, 0.870], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.399, medians=[0.929, 0.01643, 1.015], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.427, medians=[0.973, 0.01723, 1.164], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.449, medians=[1.007, 0.01798, 1.299], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.467, medians=[1.036, 0.01855, 1.417], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.481, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.495, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.505, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.513, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.520, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.527, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.533, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.537, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.541, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.545, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.550, medians=[1.059, 0.01905, 1.514], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=2: ok in 65.27s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.357, medians=[0.832, 0.00917, 0.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.348, medians=[0.838, 0.01139, 0.616], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.362, medians=[0.879, 0.01267, 0.726], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.388, medians=[0.929, 0.01370, 0.855], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.413, medians=[0.977, 0.01453, 0.991], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.438, medians=[1.018, 0.01532, 1.131], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.460, medians=[1.051, 0.01602, 1.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.476, medians=[1.078, 0.01656, 1.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.492, medians=[1.102, 0.01693, 1.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.504, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.516, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.525, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.530, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.537, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.542, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.546, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.551, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.556, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.559, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.563, medians=[1.122, 0.01735, 1.571], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=3: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.313, medians=[0.723, 0.00903, 0.440], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.295, medians=[0.770, 0.01012, 0.527], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.322, medians=[0.824, 0.01088, 0.619], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.346, medians=[0.877, 0.01160, 0.720], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.377, medians=[0.927, 0.01232, 0.833], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.402, medians=[0.970, 0.01298, 0.946], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.424, medians=[1.007, 0.01360, 1.059], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.445, medians=[1.037, 0.01414, 1.163], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.460, medians=[1.063, 0.01461, 1.254], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.473, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.486, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.496, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.505, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.512, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.518, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.525, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.530, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.535, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.540, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.544, medians=[1.083, 0.01503, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=4: ok in 65.41s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.298, medians=[0.795, 0.00805, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.279, medians=[0.825, 0.00912, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.304, medians=[0.863, 0.00987, 0.622], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.338, medians=[0.904, 0.01055, 0.708], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.362, medians=[0.946, 0.01117, 0.803], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.384, medians=[0.983, 0.01175, 0.898], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.404, medians=[1.015, 0.01226, 0.989], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.421, medians=[1.043, 0.01271, 1.077], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.438, medians=[1.067, 0.01307, 1.157], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.452, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.461, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.469, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.477, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.482, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.490, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.494, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.501, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.505, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.510, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.515, medians=[1.087, 0.01340, 1.225], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=5: ok in 65.65s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.320, medians=[0.794, 0.00778, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.289, medians=[0.836, 0.00840, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.311, medians=[0.873, 0.00895, 0.603], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.329, medians=[0.905, 0.00943, 0.664], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.341, medians=[0.935, 0.00988, 0.727], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.359, medians=[0.965, 0.01030, 0.795], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.380, medians=[0.993, 0.01071, 0.864], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.398, medians=[1.019, 0.01109, 0.935], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.414, medians=[1.044, 0.01141, 1.006], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.428, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.440, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.452, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.461, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.468, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.475, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.481, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.486, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.491, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.495, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.498, medians=[1.066, 0.01172, 1.076], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=6: ok in 65.60s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.264, medians=[0.824, 0.00683, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.251, medians=[0.840, 0.00739, 0.490], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.258, medians=[0.861, 0.00778, 0.532], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.277, medians=[0.886, 0.00815, 0.579], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.287, medians=[0.910, 0.00849, 0.626], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.301, medians=[0.930, 0.00882, 0.669], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.317, medians=[0.951, 0.00914, 0.715], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.333, medians=[0.971, 0.00942, 0.761], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.344, medians=[0.990, 0.00972, 0.807], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.359, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.371, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.382, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.392, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.401, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.409, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.418, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.424, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.429, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.435, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.440, medians=[1.005, 0.01003, 0.852], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=7: ok in 65.50s
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.221, medians=[0.763, 0.00629, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.6s, rate=0.209, medians=[0.805, 0.00665, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.214, medians=[0.834, 0.00696, 0.482], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.233, medians=[0.857, 0.00725, 0.518], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.256, medians=[0.880, 0.00752, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.273, medians=[0.901, 0.00779, 0.593], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.286, medians=[0.920, 0.00803, 0.630], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.296, medians=[0.938, 0.00827, 0.666], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.306, medians=[0.956, 0.00850, 0.703], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.318, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.328, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.337, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.347, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.355, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.366, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.372, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.380, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.387, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.392, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.397, medians=[0.971, 0.00872, 0.738], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=8: ok in 65.63s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.225, medians=[0.824, 0.00624, 0.436], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.214, medians=[0.849, 0.00654, 0.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.220, medians=[0.869, 0.00677, 0.504], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.223, medians=[0.883, 0.00696, 0.529], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.230, medians=[0.896, 0.00714, 0.553], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.247, medians=[0.908, 0.00732, 0.577], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.257, medians=[0.921, 0.00749, 0.601], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.267, medians=[0.933, 0.00765, 0.625], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.277, medians=[0.945, 0.00781, 0.650], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.285, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.294, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.302, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.310, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.316, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.322, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.327, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.332, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.337, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.343, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.348, medians=[0.957, 0.00797, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=9: ok in 65.22s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.189, medians=[0.851, 0.00555, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.190, medians=[0.849, 0.00583, 0.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.188, medians=[0.856, 0.00599, 0.449], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.201, medians=[0.865, 0.00614, 0.467], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.208, medians=[0.873, 0.00627, 0.483], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.216, medians=[0.880, 0.00639, 0.497], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.220, medians=[0.886, 0.00649, 0.510], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.224, medians=[0.893, 0.00658, 0.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.230, medians=[0.899, 0.00668, 0.535], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.8s, rate=0.238, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.0s, rate=0.242, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.3s, rate=0.248, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.253, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.256, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.2s, rate=0.261, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.5s, rate=0.266, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.7s, rate=0.271, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.0s, rate=0.275, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.3s, rate=0.280, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.284, medians=[0.905, 0.00678, 0.549], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=10: ok in 64.64s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.179, medians=[0.802, 0.00522, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.170, medians=[0.818, 0.00532, 0.388], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.168, medians=[0.828, 0.00543, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.177, medians=[0.836, 0.00554, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.180, medians=[0.844, 0.00564, 0.429], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.185, medians=[0.851, 0.00572, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.192, medians=[0.857, 0.00580, 0.450], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.198, medians=[0.862, 0.00587, 0.460], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.200, medians=[0.867, 0.00594, 0.469], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.203, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.207, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.212, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.214, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.217, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.221, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.225, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.228, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.229, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.233, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.236, medians=[0.872, 0.00600, 0.477], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=11: ok in 63.50s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.138, medians=[0.807, 0.00459, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.121, medians=[0.804, 0.00470, 0.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.124, medians=[0.808, 0.00478, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.131, medians=[0.814, 0.00485, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.138, medians=[0.817, 0.00491, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.142, medians=[0.821, 0.00497, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.145, medians=[0.824, 0.00502, 0.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.148, medians=[0.826, 0.00506, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.148, medians=[0.828, 0.00510, 0.385], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.148, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.151, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.153, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.157, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.158, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.161, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.163, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.165, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.167, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.170, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.172, medians=[0.830, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=12: ok in 63.48s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.131, medians=[0.787, 0.00462, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.124, medians=[0.800, 0.00463, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.128, medians=[0.805, 0.00466, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.124, medians=[0.808, 0.00468, 0.350], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.122, medians=[0.810, 0.00470, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.123, medians=[0.812, 0.00472, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.127, medians=[0.813, 0.00474, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.127, medians=[0.815, 0.00477, 0.362], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.130, medians=[0.817, 0.00479, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.131, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.134, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.135, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.135, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.137, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.137, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.137, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.137, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.138, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.139, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.140, medians=[0.819, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=13: ok in 63.45s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.095, medians=[0.792, 0.00418, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.099, medians=[0.790, 0.00419, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.100, medians=[0.791, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.098, medians=[0.792, 0.00421, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.099, medians=[0.792, 0.00423, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.100, medians=[0.793, 0.00424, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.100, medians=[0.793, 0.00425, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.100, medians=[0.792, 0.00426, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.100, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.100, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.101, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.102, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.102, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.103, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.104, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.104, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.105, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.105, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.106, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.106, medians=[0.792, 0.00427, 0.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=14: ok in 63.49s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.138, medians=[0.829, 0.00421, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.116, medians=[0.812, 0.00421, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.100, medians=[0.803, 0.00420, 0.321], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.097, medians=[0.799, 0.00418, 0.317], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.095, medians=[0.796, 0.00416, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.096, medians=[0.793, 0.00414, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.092, medians=[0.791, 0.00413, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.091, medians=[0.789, 0.00411, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.089, medians=[0.787, 0.00410, 0.305], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.088, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.086, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.085, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.085, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.085, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.084, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.085, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.084, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.084, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.083, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.083, medians=[0.786, 0.00408, 0.303], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=15: ok in 63.52s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.143, medians=[0.779, 0.00433, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.141, medians=[0.783, 0.00426, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.128, medians=[0.781, 0.00422, 0.322], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.117, medians=[0.779, 0.00416, 0.316], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.112, medians=[0.778, 0.00411, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.105, medians=[0.776, 0.00408, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.100, medians=[0.775, 0.00404, 0.302], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.096, medians=[0.773, 0.00401, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.093, medians=[0.772, 0.00398, 0.294], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.092, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.090, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.088, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.086, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.083, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.080, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.078, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.077, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.076, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.075, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.073, medians=[0.770, 0.00395, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=16: ok in 63.51s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.100, medians=[0.756, 0.00398, 0.294], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.089, medians=[0.756, 0.00390, 0.287], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.080, medians=[0.756, 0.00385, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.080, medians=[0.756, 0.00380, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.078, medians=[0.755, 0.00376, 0.273], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.076, medians=[0.754, 0.00373, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.073, medians=[0.752, 0.00369, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.072, medians=[0.750, 0.00365, 0.260], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.071, medians=[0.749, 0.00362, 0.256], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.068, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.066, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.064, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.062, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.5s, rate=0.061, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.060, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.058, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.057, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.2s, rate=0.057, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.056, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.055, medians=[0.748, 0.00358, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=17: ok in 63.55s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.117, medians=[0.750, 0.00419, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.103, medians=[0.748, 0.00411, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.098, medians=[0.747, 0.00404, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.092, medians=[0.747, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.085, medians=[0.746, 0.00392, 0.289], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.081, medians=[0.744, 0.00386, 0.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.078, medians=[0.743, 0.00381, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.074, medians=[0.741, 0.00375, 0.271], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.073, medians=[0.739, 0.00370, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.8s, rate=0.070, medians=[0.738, 0.00364, 0.259], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.068, medians=[0.738, 0.00364, 0.259], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.065, medians=[0.738, 0.00364, 0.259], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.062, medians=[0.738, 0.00364, 0.259], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.155, medians=[0.658, 0.00546, 0.357], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.181, medians=[0.676, 0.00616, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.204, medians=[0.703, 0.00693, 0.467], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.236, medians=[0.733, 0.00787, 0.543], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.264, medians=[0.765, 0.00884, 0.631], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.291, medians=[0.796, 0.00981, 0.724], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.313, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.333, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.350, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.366, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.379, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.390, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.402, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.413, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.421, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.429, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.438, medians=[0.824, 0.01074, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=25: ok in 65.24s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.220, medians=[0.709, 0.00656, 0.462], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.243, medians=[0.720, 0.00773, 0.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.266, medians=[0.743, 0.00885, 0.586], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.293, medians=[0.773, 0.01003, 0.668], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.324, medians=[0.810, 0.01123, 0.769], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.353, medians=[0.847, 0.01238, 0.883], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.381, medians=[0.879, 0.01348, 0.994], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.401, medians=[0.906, 0.01455, 1.099], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.420, medians=[0.929, 0.01553, 1.196], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.432, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.443, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.454, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.464, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.469, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.475, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.481, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.487, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.491, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.495, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.499, medians=[0.948, 0.01642, 1.283], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=26: ok in 65.48s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.201, medians=[0.713, 0.00391, 0.262], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.158, medians=[0.665, 0.00437, 0.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.160, medians=[0.658, 0.00484, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.172, medians=[0.665, 0.00541, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.186, medians=[0.682, 0.00607, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.208, medians=[0.702, 0.00692, 0.455], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.236, medians=[0.730, 0.00785, 0.528], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.264, medians=[0.761, 0.00888, 0.616], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.290, medians=[0.793, 0.00986, 0.714], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.315, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.336, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.354, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.370, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.383, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.395, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.406, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.416, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.426, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.433, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.440, medians=[0.823, 0.01085, 0.816], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=27: ok in 65.25s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.232, medians=[0.690, 0.00494, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.211, medians=[0.676, 0.00566, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.208, medians=[0.688, 0.00641, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.228, medians=[0.710, 0.00726, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.258, medians=[0.739, 0.00828, 0.559], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.285, medians=[0.772, 0.00933, 0.648], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.311, medians=[0.807, 0.01035, 0.747], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.335, medians=[0.839, 0.01131, 0.848], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.355, medians=[0.868, 0.01230, 0.953], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.375, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.393, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.405, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.419, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.430, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.438, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.446, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.455, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.463, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.469, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.474, medians=[0.893, 0.01325, 1.055], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=28: ok in 65.38s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.190, medians=[0.656, 0.00566, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.207, medians=[0.671, 0.00643, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.225, medians=[0.693, 0.00724, 0.475], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.245, medians=[0.722, 0.00823, 0.546], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.274, medians=[0.756, 0.00936, 0.631], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.304, medians=[0.793, 0.01055, 0.734], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.333, medians=[0.828, 0.01174, 0.843], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.358, medians=[0.861, 0.01284, 0.959], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.380, medians=[0.887, 0.01387, 1.061], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.394, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.407, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.420, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.431, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.442, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.451, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.460, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.466, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.472, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.477, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.482, medians=[0.909, 0.01482, 1.151], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=29: ok in 65.41s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.177, medians=[0.644, 0.00550, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.179, medians=[0.658, 0.00614, 0.398], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.210, medians=[0.682, 0.00690, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.242, medians=[0.714, 0.00773, 0.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.275, medians=[0.749, 0.00868, 0.603], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.298, medians=[0.785, 0.00965, 0.695], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.323, medians=[0.819, 0.01061, 0.794], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.347, medians=[0.850, 0.01164, 0.894], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.365, medians=[0.878, 0.01259, 0.995], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.383, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.401, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.416, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.428, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.437, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.443, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.451, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.458, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.464, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.470, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.473, medians=[0.902, 0.01348, 1.090], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 15 chain 1, k=30: ok in 65.42s
# [ Info: All k (1..30) finished for dataset 15. Total time 1945.51s -> output dir: output
