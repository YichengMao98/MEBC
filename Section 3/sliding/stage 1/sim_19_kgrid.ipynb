# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 19
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.358, medians=[0.670, 0.01019, 0.399], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.6s, rate=0.330, medians=[0.683, 0.01338, 0.488], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.8s, rate=0.340, medians=[0.733, 0.01535, 0.597], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.2s, rate=0.371, medians=[0.796, 0.01683, 0.734], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.4s, rate=0.403, medians=[0.860, 0.01825, 0.904], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.7s, rate=0.430, medians=[0.914, 0.01943, 1.080], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=25.0s, rate=0.453, medians=[0.959, 0.02040, 1.247], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.2s, rate=0.474, medians=[0.994, 0.02126, 1.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.5s, rate=0.489, medians=[1.022, 0.02206, 1.525], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.7s, rate=0.502, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.9s, rate=0.513, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=41.2s, rate=0.521, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.4s, rate=0.531, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.6s, rate=0.536, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.8s, rate=0.541, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=54.1s, rate=0.546, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.3s, rate=0.549, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.5s, rate=0.553, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.7s, rate=0.558, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.9s, rate=0.562, medians=[1.044, 0.02273, 1.632], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=1: ok in 70.89s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.365, medians=[0.773, 0.00976, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.323, medians=[0.776, 0.01213, 0.552], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.349, medians=[0.819, 0.01374, 0.662], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.374, medians=[0.873, 0.01495, 0.792], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.403, medians=[0.925, 0.01607, 0.941], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.433, medians=[0.972, 0.01696, 1.095], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.454, medians=[1.006, 0.01796, 1.228], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.472, medians=[1.037, 0.01869, 1.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.493, medians=[1.062, 0.01931, 1.481], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.505, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.517, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.525, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.532, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.539, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.544, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.549, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.553, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.557, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.560, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.564, medians=[1.084, 0.01974, 1.585], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=2: ok in 64.94s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.345, medians=[0.797, 0.00896, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.309, medians=[0.801, 0.01095, 0.550], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.339, medians=[0.842, 0.01217, 0.649], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.372, medians=[0.892, 0.01321, 0.768], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.403, medians=[0.941, 0.01410, 0.897], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.431, medians=[0.985, 0.01496, 1.037], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.452, medians=[1.022, 0.01561, 1.165], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.468, medians=[1.052, 0.01622, 1.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.482, medians=[1.078, 0.01664, 1.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.491, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.503, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.511, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.520, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.526, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.532, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.537, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.542, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.546, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.551, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.554, medians=[1.099, 0.01702, 1.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=3: ok in 65.12s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.328, medians=[0.763, 0.00908, 0.474], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.321, medians=[0.805, 0.01036, 0.564], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.330, medians=[0.854, 0.01123, 0.657], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.361, medians=[0.902, 0.01204, 0.759], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.393, medians=[0.946, 0.01285, 0.870], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.417, medians=[0.987, 0.01355, 0.985], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.441, medians=[1.022, 0.01408, 1.091], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.460, medians=[1.052, 0.01448, 1.189], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.477, medians=[1.078, 0.01489, 1.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.491, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.502, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.513, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.519, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.526, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.532, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.537, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.540, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.543, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.546, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.549, medians=[1.101, 0.01523, 1.379], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=4: ok in 65.37s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.288, medians=[0.729, 0.00794, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.271, medians=[0.767, 0.00883, 0.474], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.288, medians=[0.813, 0.00942, 0.545], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.310, medians=[0.853, 0.01003, 0.618], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.339, medians=[0.893, 0.01062, 0.699], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.366, medians=[0.930, 0.01116, 0.782], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.387, medians=[0.965, 0.01168, 0.867], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.404, medians=[0.993, 0.01219, 0.948], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.422, medians=[1.020, 0.01262, 1.028], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.434, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.445, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.458, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.470, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.477, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.485, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.493, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.498, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.502, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.505, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.510, medians=[1.044, 0.01295, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=5: ok in 65.54s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.252, medians=[0.733, 0.00729, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.260, medians=[0.776, 0.00796, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.273, medians=[0.815, 0.00844, 0.516], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.285, medians=[0.852, 0.00892, 0.577], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.304, medians=[0.886, 0.00936, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.324, medians=[0.918, 0.00981, 0.704], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.348, medians=[0.950, 0.01025, 0.776], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.366, medians=[0.978, 0.01066, 0.847], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.383, medians=[1.002, 0.01110, 0.915], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.401, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.413, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.425, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.438, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.448, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.456, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.465, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.471, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.476, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.482, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.488, medians=[1.026, 0.01143, 0.983], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=6: ok in 65.54s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.236, medians=[0.759, 0.00592, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.214, medians=[0.770, 0.00654, 0.376], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.229, medians=[0.795, 0.00694, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.241, medians=[0.820, 0.00733, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.257, medians=[0.843, 0.00767, 0.505], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.273, medians=[0.867, 0.00801, 0.550], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.288, medians=[0.891, 0.00833, 0.595], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.304, medians=[0.912, 0.00864, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.319, medians=[0.932, 0.00894, 0.682], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.332, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.345, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.362, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.374, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.384, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.396, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.406, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.415, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.420, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.427, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.434, medians=[0.952, 0.00921, 0.726], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=7: ok in 65.51s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.270, medians=[0.795, 0.00640, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.261, medians=[0.829, 0.00683, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.272, medians=[0.855, 0.00716, 0.504], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.277, medians=[0.877, 0.00746, 0.541], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.290, medians=[0.898, 0.00773, 0.578], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.300, medians=[0.917, 0.00799, 0.614], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.308, medians=[0.933, 0.00825, 0.647], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.317, medians=[0.948, 0.00846, 0.679], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.327, medians=[0.963, 0.00866, 0.711], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.336, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.346, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.357, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.366, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.374, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.382, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.387, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.394, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.401, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.406, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.413, medians=[0.977, 0.00887, 0.743], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=8: ok in 65.65s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.209, medians=[0.831, 0.00557, 0.376], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.196, medians=[0.832, 0.00593, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.196, medians=[0.842, 0.00617, 0.432], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.206, medians=[0.854, 0.00638, 0.456], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.210, medians=[0.866, 0.00658, 0.480], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.221, medians=[0.878, 0.00676, 0.503], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.3s, rate=0.231, medians=[0.889, 0.00691, 0.524], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.242, medians=[0.899, 0.00707, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.253, medians=[0.910, 0.00722, 0.566], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.2s, rate=0.262, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.271, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.279, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.286, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.294, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.302, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.309, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.313, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.322, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.327, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.332, medians=[0.921, 0.00737, 0.588], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=9: ok in 65.25s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.260, medians=[0.831, 0.00623, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.238, medians=[0.859, 0.00641, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.231, medians=[0.875, 0.00658, 0.512], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.239, medians=[0.889, 0.00671, 0.532], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.251, medians=[0.903, 0.00685, 0.554], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.256, medians=[0.914, 0.00697, 0.570], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.263, medians=[0.922, 0.00708, 0.586], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.270, medians=[0.930, 0.00719, 0.600], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.275, medians=[0.937, 0.00729, 0.614], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.279, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.283, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.288, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.293, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.297, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.301, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.303, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.306, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.309, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.311, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.314, medians=[0.944, 0.00739, 0.629], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=10: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.192, medians=[0.856, 0.00537, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.177, medians=[0.854, 0.00553, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.177, medians=[0.857, 0.00563, 0.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.181, medians=[0.862, 0.00573, 0.442], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.188, medians=[0.866, 0.00583, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.200, medians=[0.870, 0.00593, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.3s, rate=0.206, medians=[0.875, 0.00601, 0.474], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.209, medians=[0.880, 0.00608, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.212, medians=[0.884, 0.00615, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.8s, rate=0.216, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.0s, rate=0.218, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.2s, rate=0.221, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.4s, rate=0.225, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.6s, rate=0.230, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.8s, rate=0.233, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.0s, rate=0.239, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.2s, rate=0.239, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.4s, rate=0.241, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.6s, rate=0.244, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.9s, rate=0.247, medians=[0.888, 0.00621, 0.500], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=11: ok in 63.92s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.152, medians=[0.801, 0.00490, 0.350], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.154, medians=[0.812, 0.00496, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.157, medians=[0.819, 0.00503, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.159, medians=[0.826, 0.00510, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.162, medians=[0.831, 0.00516, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.164, medians=[0.836, 0.00521, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.169, medians=[0.839, 0.00525, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.171, medians=[0.842, 0.00531, 0.408], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.175, medians=[0.845, 0.00535, 0.414], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.176, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.178, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.177, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.181, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.5s, rate=0.181, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.183, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.185, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.186, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.2s, rate=0.186, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.4s, rate=0.187, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.188, medians=[0.848, 0.00539, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=12: ok in 63.57s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.165, medians=[0.844, 0.00460, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.160, medians=[0.831, 0.00468, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.161, medians=[0.826, 0.00472, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.152, medians=[0.824, 0.00475, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.149, medians=[0.824, 0.00477, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.146, medians=[0.824, 0.00479, 0.364], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.145, medians=[0.825, 0.00480, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.142, medians=[0.826, 0.00482, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.143, medians=[0.826, 0.00484, 0.370], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.143, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.145, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.143, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.143, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.144, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.144, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.144, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.143, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.144, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.144, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.145, medians=[0.827, 0.00485, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=13: ok in 63.47s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.144, medians=[0.767, 0.00457, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.124, medians=[0.782, 0.00449, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.116, medians=[0.789, 0.00445, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.110, medians=[0.792, 0.00443, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.113, medians=[0.793, 0.00442, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.114, medians=[0.793, 0.00442, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.112, medians=[0.794, 0.00443, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.111, medians=[0.794, 0.00443, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.111, medians=[0.795, 0.00443, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.111, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.110, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.110, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.109, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.109, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.109, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.109, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.109, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.110, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.111, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.111, medians=[0.795, 0.00442, 0.327], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=14: ok in 63.48s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.118, medians=[0.799, 0.00431, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.115, medians=[0.795, 0.00429, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.111, medians=[0.793, 0.00426, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.105, medians=[0.790, 0.00424, 0.316], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.103, medians=[0.789, 0.00421, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.105, medians=[0.788, 0.00419, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.102, medians=[0.787, 0.00417, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.100, medians=[0.786, 0.00416, 0.308], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.099, medians=[0.785, 0.00415, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.097, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.097, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.096, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.095, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.3s, rate=0.094, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.094, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.092, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.8s, rate=0.092, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.091, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.090, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.089, medians=[0.785, 0.00413, 0.304], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=15: ok in 63.38s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.147, medians=[0.806, 0.00402, 0.303], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.117, medians=[0.787, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.101, medians=[0.778, 0.00395, 0.289], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.092, medians=[0.774, 0.00392, 0.284], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.088, medians=[0.770, 0.00389, 0.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.088, medians=[0.768, 0.00386, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.085, medians=[0.766, 0.00383, 0.274], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.084, medians=[0.764, 0.00382, 0.271], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.083, medians=[0.763, 0.00380, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.081, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.078, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.077, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.074, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.3s, rate=0.072, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.071, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.071, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.8s, rate=0.069, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.068, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.1s, rate=0.067, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.3s, rate=0.067, medians=[0.761, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=16: ok in 63.33s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.121, medians=[0.767, 0.00393, 0.285], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.097, medians=[0.757, 0.00384, 0.275], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.088, medians=[0.751, 0.00378, 0.268], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.080, medians=[0.748, 0.00373, 0.262], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.078, medians=[0.744, 0.00369, 0.257], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.075, medians=[0.741, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.071, medians=[0.739, 0.00361, 0.248], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.069, medians=[0.737, 0.00357, 0.243], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.066, medians=[0.736, 0.00354, 0.240], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.064, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.062, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.060, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.058, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.3s, rate=0.057, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.055, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.054, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.8s, rate=0.053, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.052, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.051, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.3s, rate=0.051, medians=[0.735, 0.00351, 0.236], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=17: ok in 63.35s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.140, medians=[0.748, 0.00377, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.103, medians=[0.738, 0.00366, 0.255], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.090, medians=[0.733, 0.00360, 0.248], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.082, medians=[0.729, 0.00355, 0.242], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.078, medians=[0.726, 0.00351, 0.237], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.074, medians=[0.723, 0.00346, 0.232], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.072, medians=[0.721, 0.00341, 0.227], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.068, medians=[0.720, 0.00337, 0.222], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.065, medians=[0.718, 0.00333, 0.217], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.062, medians=[0.717, 0.00329, 0.213], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.060, medians=[0.717, 0.00329, 0.213], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.058, medians=[0.717, 0.00329, 0.213], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.1s, rate=0.057, medians=[0.717, 0.00329, 0.213], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.203, medians=[0.656, 0.00695, 0.422], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.232, medians=[0.685, 0.00786, 0.489], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.259, medians=[0.718, 0.00894, 0.571], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.287, medians=[0.755, 0.01010, 0.668], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.317, medians=[0.791, 0.01137, 0.779], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.343, medians=[0.822, 0.01263, 0.890], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.363, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.381, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.397, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.412, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.423, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.434, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.443, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.452, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.460, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.466, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.473, medians=[0.850, 0.01382, 0.995], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=25: ok in 65.19s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.219, medians=[0.676, 0.00476, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.190, medians=[0.645, 0.00558, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.197, medians=[0.649, 0.00638, 0.385], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.214, medians=[0.668, 0.00727, 0.440], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.239, medians=[0.697, 0.00842, 0.515], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.266, medians=[0.732, 0.00964, 0.605], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.294, medians=[0.769, 0.01080, 0.709], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.322, medians=[0.804, 0.01196, 0.817], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.344, medians=[0.835, 0.01310, 0.925], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.366, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.386, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.399, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.412, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.423, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.432, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.442, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.451, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.457, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.464, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.468, medians=[0.862, 0.01405, 1.028], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=26: ok in 65.19s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.240, medians=[0.667, 0.00689, 0.437], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.238, medians=[0.686, 0.00810, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.266, medians=[0.714, 0.00943, 0.576], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.296, medians=[0.754, 0.01074, 0.672], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.329, medians=[0.797, 0.01208, 0.792], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.358, medians=[0.837, 0.01362, 0.923], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.386, medians=[0.872, 0.01503, 1.050], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.409, medians=[0.899, 0.01633, 1.160], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.428, medians=[0.920, 0.01752, 1.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.442, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.453, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.462, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.469, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.478, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.484, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.488, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.494, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.498, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.503, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.507, medians=[0.938, 0.01858, 1.332], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=27: ok in 65.46s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.210, medians=[0.616, 0.00542, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.208, medians=[0.621, 0.00634, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.225, medians=[0.643, 0.00728, 0.429], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.244, medians=[0.674, 0.00831, 0.498], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.275, medians=[0.712, 0.00956, 0.589], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.306, medians=[0.753, 0.01095, 0.696], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.332, medians=[0.792, 0.01227, 0.812], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.358, medians=[0.826, 0.01361, 0.928], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.379, medians=[0.855, 0.01479, 1.036], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.397, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.412, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.422, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.432, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.443, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.451, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.457, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.462, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.469, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.474, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.478, medians=[0.880, 0.01587, 1.137], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=28: ok in 65.37s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.200, medians=[0.613, 0.00630, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.205, medians=[0.636, 0.00720, 0.427], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.233, medians=[0.668, 0.00837, 0.498], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.263, medians=[0.705, 0.00953, 0.580], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.291, medians=[0.747, 0.01067, 0.679], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.324, medians=[0.787, 0.01201, 0.790], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.352, medians=[0.822, 0.01331, 0.900], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.371, medians=[0.853, 0.01437, 1.005], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.390, medians=[0.880, 0.01536, 1.108], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.408, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.423, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.437, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.448, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.457, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.467, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.476, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.483, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.487, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.492, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.496, medians=[0.902, 0.01637, 1.198], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=29: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.217, medians=[0.625, 0.00512, 0.318], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.200, medians=[0.623, 0.00599, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.214, medians=[0.640, 0.00688, 0.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.237, medians=[0.667, 0.00786, 0.476], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.265, medians=[0.703, 0.00883, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.293, medians=[0.743, 0.00996, 0.656], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.323, medians=[0.783, 0.01116, 0.769], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.348, medians=[0.818, 0.01237, 0.887], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.369, medians=[0.849, 0.01352, 1.000], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.389, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.406, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.423, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.433, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.441, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.451, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.460, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.468, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.475, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.480, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.484, medians=[0.875, 0.01458, 1.103], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 19 chain 1, k=30: ok in 65.21s
# [ Info: All k (1..30) finished for dataset 19. Total time 1945.43s -> output dir: output
