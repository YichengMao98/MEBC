# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 2
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.384, medians=[0.638, 0.00923, 0.332], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.3s, rate=0.331, medians=[0.629, 0.01241, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.5s, rate=0.325, medians=[0.676, 0.01418, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=14.8s, rate=0.345, medians=[0.738, 0.01551, 0.622], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.1s, rate=0.378, medians=[0.803, 0.01664, 0.766], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.3s, rate=0.411, medians=[0.862, 0.01778, 0.931], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.6s, rate=0.433, medians=[0.910, 0.01894, 1.097], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=27.8s, rate=0.450, medians=[0.949, 0.01993, 1.244], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.1s, rate=0.468, medians=[0.981, 0.02071, 1.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.3s, rate=0.483, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.5s, rate=0.497, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.7s, rate=0.506, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.9s, rate=0.515, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.1s, rate=0.522, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.3s, rate=0.531, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.4s, rate=0.538, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.6s, rate=0.544, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.8s, rate=0.550, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.9s, rate=0.554, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.2s, rate=0.558, medians=[1.008, 0.02130, 1.492], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=1: ok in 70.12s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.354, medians=[0.782, 0.00900, 0.444], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.334, medians=[0.775, 0.01168, 0.536], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.354, medians=[0.819, 0.01320, 0.649], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.380, medians=[0.873, 0.01450, 0.782], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.408, medians=[0.927, 0.01559, 0.937], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.434, medians=[0.973, 0.01662, 1.097], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.458, medians=[1.013, 0.01749, 1.256], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.477, medians=[1.045, 0.01820, 1.397], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.494, medians=[1.071, 0.01879, 1.521], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.509, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.523, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.531, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.537, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.544, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.4s, rate=0.549, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.6s, rate=0.555, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.8s, rate=0.560, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.0s, rate=0.564, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.2s, rate=0.566, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.4s, rate=0.569, medians=[1.092, 0.01927, 1.623], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=2: ok in 64.42s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.343, medians=[0.698, 0.00822, 0.346], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.301, medians=[0.690, 0.01029, 0.418], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.310, medians=[0.732, 0.01128, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.330, medians=[0.787, 0.01208, 0.599], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.350, medians=[0.841, 0.01290, 0.712], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.383, medians=[0.893, 0.01365, 0.836], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.408, medians=[0.940, 0.01434, 0.972], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.8s, rate=0.432, medians=[0.979, 0.01496, 1.095], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.450, medians=[1.010, 0.01557, 1.207], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.469, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.480, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.492, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.500, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.509, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.5s, rate=0.517, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.7s, rate=0.524, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.529, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.1s, rate=0.534, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.3s, rate=0.540, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.543, medians=[1.035, 0.01617, 1.310], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=3: ok in 64.58s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.304, medians=[0.784, 0.00873, 0.462], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.301, medians=[0.810, 0.00999, 0.546], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.326, medians=[0.854, 0.01086, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.351, medians=[0.899, 0.01165, 0.737], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.378, medians=[0.942, 0.01244, 0.844], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.410, medians=[0.981, 0.01315, 0.956], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.426, medians=[1.016, 0.01375, 1.067], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.446, medians=[1.045, 0.01427, 1.170], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.464, medians=[1.070, 0.01474, 1.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.479, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.491, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.498, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.505, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.513, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.520, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.523, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.527, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.533, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.536, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.541, medians=[1.092, 0.01508, 1.347], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=4: ok in 64.90s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.315, medians=[0.786, 0.00821, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.290, medians=[0.816, 0.00902, 0.524], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.311, medians=[0.856, 0.00968, 0.600], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.336, medians=[0.895, 0.01036, 0.683], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.362, medians=[0.933, 0.01101, 0.769], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.384, medians=[0.966, 0.01157, 0.852], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.405, medians=[0.997, 0.01203, 0.937], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.423, medians=[1.025, 0.01247, 1.018], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.443, medians=[1.050, 0.01283, 1.097], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.453, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.464, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.474, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.481, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.492, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.501, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.508, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.514, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.519, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.523, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.527, medians=[1.070, 0.01321, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=5: ok in 65.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.301, medians=[0.791, 0.00748, 0.440], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.282, medians=[0.822, 0.00821, 0.506], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.297, medians=[0.859, 0.00878, 0.573], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.324, medians=[0.892, 0.00932, 0.639], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.345, medians=[0.924, 0.00979, 0.706], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.367, medians=[0.956, 0.01023, 0.779], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.387, medians=[0.985, 0.01069, 0.853], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.401, medians=[1.009, 0.01110, 0.920], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.414, medians=[1.032, 0.01146, 0.985], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.426, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.438, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.449, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.459, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.468, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.476, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.483, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.491, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.495, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.499, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.503, medians=[1.052, 0.01179, 1.048], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=6: ok in 65.19s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.295, medians=[0.775, 0.00709, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.270, medians=[0.816, 0.00764, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.279, medians=[0.851, 0.00808, 0.549], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.295, medians=[0.882, 0.00847, 0.601], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.315, medians=[0.911, 0.00886, 0.657], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.334, medians=[0.938, 0.00921, 0.710], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.352, medians=[0.962, 0.00953, 0.763], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.368, medians=[0.983, 0.00982, 0.810], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.380, medians=[1.001, 0.01009, 0.854], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.391, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.403, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.415, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.424, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.432, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.440, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.448, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.453, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.459, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.465, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.468, medians=[1.018, 0.01033, 0.898], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=7: ok in 65.27s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.223, medians=[0.724, 0.00596, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.221, medians=[0.761, 0.00633, 0.385], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.223, medians=[0.792, 0.00663, 0.424], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.231, medians=[0.818, 0.00691, 0.462], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.245, medians=[0.842, 0.00719, 0.500], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.262, medians=[0.862, 0.00746, 0.536], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.3s, rate=0.269, medians=[0.882, 0.00770, 0.569], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.279, medians=[0.899, 0.00793, 0.602], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.295, medians=[0.916, 0.00817, 0.637], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.310, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.4s, rate=0.320, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.7s, rate=0.332, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.344, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.353, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.362, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.369, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.375, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.382, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.389, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.395, medians=[0.933, 0.00836, 0.670], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=8: ok in 65.01s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.229, medians=[0.785, 0.00586, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.208, medians=[0.811, 0.00612, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.211, medians=[0.830, 0.00635, 0.445], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.221, medians=[0.848, 0.00657, 0.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.233, medians=[0.862, 0.00677, 0.499], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.243, medians=[0.875, 0.00696, 0.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.1s, rate=0.251, medians=[0.887, 0.00713, 0.545], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.261, medians=[0.900, 0.00731, 0.570], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.269, medians=[0.913, 0.00748, 0.595], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.9s, rate=0.282, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.293, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.302, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.8s, rate=0.311, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.1s, rate=0.320, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.3s, rate=0.326, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.6s, rate=0.333, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.337, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.342, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.346, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.351, medians=[0.924, 0.00763, 0.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=9: ok in 64.84s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.197, medians=[0.800, 0.00515, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.180, medians=[0.807, 0.00539, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.187, medians=[0.817, 0.00560, 0.391], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.194, medians=[0.828, 0.00577, 0.411], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.202, medians=[0.838, 0.00594, 0.432], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.206, medians=[0.848, 0.00610, 0.452], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=21.9s, rate=0.214, medians=[0.858, 0.00624, 0.470], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.221, medians=[0.867, 0.00638, 0.488], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.226, medians=[0.877, 0.00650, 0.505], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.233, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.7s, rate=0.240, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.246, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.253, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.5s, rate=0.257, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.8s, rate=0.263, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.1s, rate=0.271, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.278, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.284, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.0s, rate=0.290, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.2s, rate=0.294, medians=[0.885, 0.00661, 0.521], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=10: ok in 64.26s
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.129, medians=[0.773, 0.00476, 0.313], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.132, medians=[0.781, 0.00491, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.134, medians=[0.793, 0.00505, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.139, medians=[0.804, 0.00519, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.146, medians=[0.813, 0.00531, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.155, medians=[0.821, 0.00542, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.164, medians=[0.829, 0.00553, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.171, medians=[0.837, 0.00563, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.4s, rate=0.179, medians=[0.844, 0.00573, 0.435], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.6s, rate=0.183, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.7s, rate=0.189, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.9s, rate=0.195, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.0s, rate=0.198, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.1s, rate=0.202, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.3s, rate=0.207, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.4s, rate=0.211, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.6s, rate=0.214, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.7s, rate=0.218, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.9s, rate=0.223, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.0s, rate=0.225, medians=[0.850, 0.00581, 0.447], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=11: ok in 63.05s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.209, medians=[0.848, 0.00556, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.193, medians=[0.854, 0.00561, 0.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.190, medians=[0.856, 0.00567, 0.452], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.192, medians=[0.859, 0.00570, 0.457], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.193, medians=[0.862, 0.00573, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.198, medians=[0.865, 0.00575, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=21.9s, rate=0.198, medians=[0.867, 0.00579, 0.470], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.199, medians=[0.869, 0.00581, 0.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.200, medians=[0.871, 0.00583, 0.476], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.203, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.205, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.6s, rate=0.206, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.207, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.209, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.1s, rate=0.212, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.213, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.3s, rate=0.214, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.5s, rate=0.216, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.215, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.7s, rate=0.216, medians=[0.872, 0.00586, 0.479], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=12: ok in 62.77s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.145, medians=[0.815, 0.00430, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.125, medians=[0.802, 0.00440, 0.318], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.121, medians=[0.801, 0.00447, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.121, medians=[0.802, 0.00452, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.121, medians=[0.803, 0.00456, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.123, medians=[0.805, 0.00460, 0.339], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=21.9s, rate=0.125, medians=[0.806, 0.00463, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.126, medians=[0.806, 0.00467, 0.346], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.128, medians=[0.807, 0.00469, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.3s, rate=0.127, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.128, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.6s, rate=0.131, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.7s, rate=0.131, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.133, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.0s, rate=0.135, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.136, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.3s, rate=0.138, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.4s, rate=0.139, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.140, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.7s, rate=0.141, medians=[0.809, 0.00472, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=13: ok in 62.73s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.178, medians=[0.839, 0.00465, 0.370], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.159, medians=[0.820, 0.00467, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.148, medians=[0.814, 0.00466, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.144, medians=[0.812, 0.00465, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.139, medians=[0.810, 0.00465, 0.357], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.133, medians=[0.808, 0.00464, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=21.9s, rate=0.129, medians=[0.807, 0.00463, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.127, medians=[0.806, 0.00462, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.127, medians=[0.805, 0.00462, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.127, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.127, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.6s, rate=0.128, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.127, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.126, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.0s, rate=0.125, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.125, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.3s, rate=0.125, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.4s, rate=0.124, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.124, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.7s, rate=0.124, medians=[0.804, 0.00461, 0.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=14: ok in 62.74s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.107, medians=[0.785, 0.00445, 0.336], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.102, medians=[0.785, 0.00438, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.096, medians=[0.783, 0.00434, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.097, medians=[0.782, 0.00431, 0.322], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.099, medians=[0.781, 0.00429, 0.319], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.100, medians=[0.779, 0.00427, 0.317], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.098, medians=[0.778, 0.00425, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.095, medians=[0.777, 0.00423, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.095, medians=[0.776, 0.00421, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.095, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.095, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.6s, rate=0.094, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.094, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.093, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.0s, rate=0.092, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.091, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.3s, rate=0.090, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.5s, rate=0.090, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.090, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.7s, rate=0.089, medians=[0.776, 0.00420, 0.308], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=15: ok in 62.76s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.164, medians=[0.781, 0.00464, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.139, medians=[0.784, 0.00453, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.130, medians=[0.780, 0.00446, 0.344], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.119, medians=[0.779, 0.00440, 0.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.116, medians=[0.777, 0.00435, 0.332], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.113, medians=[0.774, 0.00430, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.110, medians=[0.772, 0.00425, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.108, medians=[0.769, 0.00421, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.107, medians=[0.767, 0.00416, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.103, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.101, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.099, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.097, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.095, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.1s, rate=0.092, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.090, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.4s, rate=0.089, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.5s, rate=0.087, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.086, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.8s, rate=0.085, medians=[0.765, 0.00412, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=16: ok in 62.80s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.107, medians=[0.734, 0.00409, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.090, medians=[0.737, 0.00398, 0.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.083, medians=[0.737, 0.00391, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.5s, rate=0.082, medians=[0.735, 0.00385, 0.271], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.077, medians=[0.733, 0.00379, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.075, medians=[0.730, 0.00374, 0.259], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.073, medians=[0.729, 0.00369, 0.254], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.070, medians=[0.728, 0.00364, 0.249], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.068, medians=[0.726, 0.00360, 0.244], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.065, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.064, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.6s, rate=0.063, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.061, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=43.9s, rate=0.060, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.1s, rate=0.059, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.2s, rate=0.058, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.3s, rate=0.056, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.5s, rate=0.055, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.6s, rate=0.054, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.8s, rate=0.053, medians=[0.725, 0.00356, 0.240], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=17: ok in 62.80s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.155, medians=[0.734, 0.00437, 0.322], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.131, medians=[0.736, 0.00428, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.119, medians=[0.735, 0.00421, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.112, medians=[0.734, 0.00415, 0.303], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.106, medians=[0.733, 0.00410, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.100, medians=[0.731, 0.00404, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.097, medians=[0.728, 0.00399, 0.286], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.093, medians=[0.726, 0.00393, 0.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.2s, rate=0.088, medians=[0.725, 0.00388, 0.274], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.084, medians=[0.723, 0.00382, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.5s, rate=0.080, medians=[0.723, 0.00382, 0.269], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.079, medians=[0.723, 0.00382, 0.269], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.8s, rate=0.076, medians=[0.723, 0.00382, 0.269], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.145, medians=[0.602, 0.00513, 0.302], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.163, medians=[0.615, 0.00571, 0.339], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.183, medians=[0.635, 0.00643, 0.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.1s, rate=0.208, medians=[0.660, 0.00737, 0.448], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.235, medians=[0.691, 0.00847, 0.526], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.7s, rate=0.261, medians=[0.724, 0.00963, 0.620], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.289, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.311, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.330, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.8s, rate=0.348, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.1s, rate=0.364, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.4s, rate=0.378, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.6s, rate=0.391, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.401, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.1s, rate=0.411, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.420, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.427, medians=[0.756, 0.01087, 0.723], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=25: ok in 64.67s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.171, medians=[0.598, 0.00482, 0.287], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.166, medians=[0.593, 0.00543, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.183, medians=[0.606, 0.00610, 0.354], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.203, medians=[0.627, 0.00695, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.230, medians=[0.656, 0.00799, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.257, medians=[0.693, 0.00920, 0.559], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.3s, rate=0.290, medians=[0.732, 0.01053, 0.663], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.318, medians=[0.769, 0.01180, 0.775], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.342, medians=[0.803, 0.01302, 0.887], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.2s, rate=0.362, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.4s, rate=0.381, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.7s, rate=0.399, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.9s, rate=0.414, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.425, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.4s, rate=0.435, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.7s, rate=0.445, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.455, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.461, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.468, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.475, medians=[0.831, 0.01418, 0.992], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=26: ok in 64.67s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.240, medians=[0.628, 0.00497, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.208, medians=[0.613, 0.00585, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.213, medians=[0.627, 0.00676, 0.394], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.237, medians=[0.655, 0.00774, 0.459], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.265, medians=[0.690, 0.00888, 0.540], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.296, medians=[0.727, 0.01012, 0.635], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.323, medians=[0.766, 0.01144, 0.747], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.349, medians=[0.802, 0.01255, 0.858], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.371, medians=[0.833, 0.01372, 0.968], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.391, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.407, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.422, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.435, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.446, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.5s, rate=0.456, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.466, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.474, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.481, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.486, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.491, medians=[0.859, 0.01489, 1.070], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=27: ok in 64.78s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.265, medians=[0.647, 0.00632, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.253, medians=[0.656, 0.00760, 0.456], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.276, medians=[0.689, 0.00880, 0.535], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.307, medians=[0.730, 0.01008, 0.633], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.335, medians=[0.773, 0.01163, 0.749], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.371, medians=[0.813, 0.01307, 0.874], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.396, medians=[0.849, 0.01438, 0.997], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.410, medians=[0.877, 0.01563, 1.108], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.427, medians=[0.901, 0.01685, 1.209], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.443, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.456, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.468, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.476, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.482, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.488, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.494, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.499, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.505, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.510, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.513, medians=[0.921, 0.01792, 1.298], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=28: ok in 64.94s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.283, medians=[0.699, 0.00616, 0.412], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.266, medians=[0.685, 0.00757, 0.470], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.273, medians=[0.706, 0.00870, 0.540], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.304, medians=[0.741, 0.00993, 0.632], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.339, medians=[0.778, 0.01128, 0.735], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.363, medians=[0.813, 0.01266, 0.844], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.388, medians=[0.846, 0.01398, 0.963], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.406, medians=[0.875, 0.01525, 1.074], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.423, medians=[0.899, 0.01643, 1.180], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.439, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.451, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.459, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.470, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.477, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.484, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.489, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.494, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.499, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.505, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.506, medians=[0.920, 0.01752, 1.279], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=29: ok in 64.91s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.228, medians=[0.639, 0.00558, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.215, medians=[0.641, 0.00674, 0.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.234, medians=[0.666, 0.00785, 0.481], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.272, medians=[0.703, 0.00898, 0.567], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.303, medians=[0.745, 0.01020, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.329, medians=[0.785, 0.01160, 0.785], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.359, medians=[0.823, 0.01288, 0.908], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.8s, rate=0.382, medians=[0.853, 0.01408, 1.017], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.402, medians=[0.879, 0.01526, 1.124], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.419, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.433, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.446, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.456, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.464, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.472, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.480, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.486, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.492, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.497, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.503, medians=[0.902, 0.01629, 1.221], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 02 chain 1, k=30: ok in 64.89s
# [ Info: All k (1..30) finished for dataset 02. Total time 1928.10s -> output dir: output
