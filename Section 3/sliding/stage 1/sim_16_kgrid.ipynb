# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 16
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.366, medians=[0.797, 0.00952, 0.480], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.4s, rate=0.356, medians=[0.792, 0.01274, 0.583], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.7s, rate=0.380, medians=[0.835, 0.01483, 0.710], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.0s, rate=0.411, medians=[0.894, 0.01623, 0.869], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.3s, rate=0.440, medians=[0.950, 0.01747, 1.052], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.6s, rate=0.463, medians=[0.995, 0.01865, 1.231], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.8s, rate=0.482, medians=[1.030, 0.01969, 1.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.0s, rate=0.499, medians=[1.058, 0.02041, 1.525], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.3s, rate=0.511, medians=[1.081, 0.02099, 1.635], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.5s, rate=0.522, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.7s, rate=0.530, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.9s, rate=0.536, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.1s, rate=0.539, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.3s, rate=0.544, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.6s, rate=0.550, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.8s, rate=0.554, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.0s, rate=0.557, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.2s, rate=0.560, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.5s, rate=0.562, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.7s, rate=0.567, medians=[1.099, 0.02153, 1.732], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=1: ok in 70.78s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.327, medians=[0.633, 0.00916, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.309, medians=[0.657, 0.01164, 0.443], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.320, medians=[0.711, 0.01301, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.344, medians=[0.774, 0.01407, 0.653], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.367, medians=[0.834, 0.01501, 0.783], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.395, medians=[0.887, 0.01596, 0.919], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.422, medians=[0.933, 0.01686, 1.063], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.447, medians=[0.972, 0.01753, 1.201], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.463, medians=[1.005, 0.01811, 1.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.477, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.489, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.499, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.509, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.519, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.526, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.530, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.535, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.540, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.545, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.549, medians=[1.032, 0.01857, 1.437], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=2: ok in 64.80s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.290, medians=[0.653, 0.00896, 0.362], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.266, medians=[0.678, 0.01068, 0.438], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.284, medians=[0.734, 0.01154, 0.527], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.317, medians=[0.794, 0.01230, 0.630], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.344, medians=[0.850, 0.01305, 0.744], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.374, medians=[0.901, 0.01381, 0.864], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.400, medians=[0.945, 0.01456, 0.995], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.425, medians=[0.981, 0.01524, 1.111], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.445, medians=[1.013, 0.01576, 1.221], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.463, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.474, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.485, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.493, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.504, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.510, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.516, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.523, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.528, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.532, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.535, medians=[1.040, 0.01619, 1.324], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=3: ok in 64.91s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.286, medians=[0.713, 0.00796, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.266, medians=[0.730, 0.00917, 0.440], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.279, medians=[0.774, 0.00991, 0.515], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.305, medians=[0.823, 0.01056, 0.601], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.336, medians=[0.869, 0.01128, 0.695], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.361, medians=[0.916, 0.01201, 0.809], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.387, medians=[0.960, 0.01266, 0.929], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.408, medians=[0.995, 0.01323, 1.036], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.424, medians=[1.024, 0.01375, 1.131], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.439, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.453, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.467, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.477, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.484, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.492, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.500, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.507, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.514, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.519, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.527, medians=[1.049, 0.01415, 1.218], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=4: ok in 65.04s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.275, medians=[0.746, 0.00779, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.274, medians=[0.775, 0.00863, 0.471], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.290, medians=[0.817, 0.00929, 0.543], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.311, medians=[0.858, 0.00995, 0.622], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.338, medians=[0.899, 0.01051, 0.705], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.365, medians=[0.936, 0.01106, 0.790], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.387, medians=[0.972, 0.01156, 0.878], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.404, medians=[1.002, 0.01207, 0.967], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.420, medians=[1.031, 0.01249, 1.056], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.438, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.449, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.459, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.470, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.478, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.484, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.489, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.497, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.502, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.508, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.513, medians=[1.055, 0.01286, 1.139], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=5: ok in 65.27s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.268, medians=[0.766, 0.00733, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.253, medians=[0.804, 0.00798, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.273, medians=[0.840, 0.00846, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.282, medians=[0.875, 0.00892, 0.604], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.305, medians=[0.907, 0.00943, 0.669], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.327, medians=[0.938, 0.00984, 0.733], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.346, medians=[0.966, 0.01027, 0.801], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.366, medians=[0.994, 0.01068, 0.873], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.386, medians=[1.019, 0.01102, 0.941], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.402, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.419, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.431, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.437, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.445, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.455, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.462, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.468, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.475, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.478, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.481, medians=[1.042, 0.01139, 1.010], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=6: ok in 65.53s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.292, medians=[0.806, 0.00709, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.280, medians=[0.846, 0.00770, 0.528], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.291, medians=[0.877, 0.00814, 0.578], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.304, medians=[0.904, 0.00851, 0.626], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.317, medians=[0.930, 0.00887, 0.676], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.337, medians=[0.954, 0.00918, 0.725], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.350, medians=[0.977, 0.00949, 0.775], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.362, medians=[0.999, 0.00979, 0.828], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.377, medians=[1.018, 0.01008, 0.878], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.391, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.402, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.411, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.420, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.426, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.431, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.438, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.443, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.449, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.455, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.461, medians=[1.035, 0.01031, 0.922], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=7: ok in 65.69s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.227, medians=[0.753, 0.00600, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.211, medians=[0.787, 0.00634, 0.401], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.215, medians=[0.812, 0.00662, 0.437], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.225, medians=[0.834, 0.00690, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.236, medians=[0.854, 0.00716, 0.505], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.249, medians=[0.873, 0.00740, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.266, medians=[0.891, 0.00767, 0.572], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.281, medians=[0.908, 0.00793, 0.609], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.293, medians=[0.926, 0.00817, 0.645], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.307, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.315, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.329, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.339, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.349, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.359, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.367, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.375, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.381, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.385, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.391, medians=[0.942, 0.00841, 0.680], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=8: ok in 65.39s
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.232, medians=[0.821, 0.00610, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.6s, rate=0.220, medians=[0.841, 0.00634, 0.451], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.228, medians=[0.856, 0.00655, 0.477], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.245, medians=[0.873, 0.00677, 0.507], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.255, medians=[0.889, 0.00700, 0.536], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.263, medians=[0.902, 0.00720, 0.562], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.278, medians=[0.915, 0.00739, 0.588], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.285, medians=[0.928, 0.00755, 0.613], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.294, medians=[0.940, 0.00771, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.300, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.306, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.313, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.320, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.326, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.332, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.339, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.344, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.350, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.355, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.361, medians=[0.950, 0.00786, 0.659], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=9: ok in 65.60s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.229, medians=[0.794, 0.00567, 0.394], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.206, medians=[0.821, 0.00582, 0.418], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.199, medians=[0.837, 0.00597, 0.437], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.204, medians=[0.851, 0.00611, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.211, medians=[0.863, 0.00626, 0.477], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.218, medians=[0.874, 0.00639, 0.496], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.224, medians=[0.883, 0.00652, 0.513], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.230, medians=[0.892, 0.00663, 0.529], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.235, medians=[0.900, 0.00674, 0.543], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.8s, rate=0.243, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.1s, rate=0.249, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.3s, rate=0.253, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.259, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.264, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.2s, rate=0.270, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.5s, rate=0.273, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.8s, rate=0.278, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.1s, rate=0.283, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.287, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.290, medians=[0.907, 0.00684, 0.557], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=10: ok in 64.73s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.128, medians=[0.779, 0.00475, 0.316], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.139, medians=[0.791, 0.00490, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.140, medians=[0.801, 0.00502, 0.350], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.146, medians=[0.809, 0.00513, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.150, medians=[0.818, 0.00525, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.157, medians=[0.826, 0.00536, 0.393], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.164, medians=[0.834, 0.00546, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.171, medians=[0.841, 0.00555, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.176, medians=[0.848, 0.00562, 0.429], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.181, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.186, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.190, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.195, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.198, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.200, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.202, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.205, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.208, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.210, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.214, medians=[0.853, 0.00569, 0.439], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=11: ok in 63.40s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.127, medians=[0.767, 0.00435, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.118, medians=[0.778, 0.00443, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.117, medians=[0.783, 0.00453, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.115, medians=[0.789, 0.00460, 0.321], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.120, medians=[0.794, 0.00467, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.123, medians=[0.800, 0.00474, 0.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.128, medians=[0.805, 0.00480, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.132, medians=[0.809, 0.00486, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.138, medians=[0.813, 0.00492, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.142, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.145, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.150, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.151, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.155, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.156, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.157, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.159, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.162, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.164, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.166, medians=[0.817, 0.00497, 0.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=12: ok in 63.38s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.136, medians=[0.792, 0.00473, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.132, medians=[0.804, 0.00472, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.142, medians=[0.807, 0.00475, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.140, medians=[0.811, 0.00476, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.141, medians=[0.814, 0.00479, 0.362], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.142, medians=[0.815, 0.00481, 0.364], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.140, medians=[0.817, 0.00482, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.139, medians=[0.817, 0.00483, 0.367], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.141, medians=[0.818, 0.00484, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.144, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.143, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.142, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.143, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.143, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.143, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.145, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.146, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.147, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.149, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.3s, rate=0.148, medians=[0.819, 0.00485, 0.370], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=13: ok in 63.37s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.103, medians=[0.775, 0.00414, 0.289], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.093, medians=[0.774, 0.00413, 0.290], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.097, medians=[0.775, 0.00413, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.092, medians=[0.775, 0.00414, 0.293], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.095, medians=[0.776, 0.00415, 0.294], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.096, medians=[0.777, 0.00416, 0.296], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.097, medians=[0.778, 0.00417, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.098, medians=[0.779, 0.00418, 0.299], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.099, medians=[0.780, 0.00419, 0.300], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.100, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.100, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.100, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.100, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.100, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.101, medians=[0.780, 0.00420, 0.301], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=14: ok in 63.45s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.130, medians=[0.795, 0.00418, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.106, medians=[0.787, 0.00417, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.099, medians=[0.784, 0.00415, 0.308], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.096, medians=[0.782, 0.00413, 0.305], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.095, medians=[0.781, 0.00412, 0.303], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.096, medians=[0.780, 0.00411, 0.302], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.092, medians=[0.778, 0.00410, 0.300], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.091, medians=[0.777, 0.00409, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.090, medians=[0.777, 0.00407, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.090, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.090, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.090, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.089, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.088, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.088, medians=[0.776, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=15: ok in 63.48s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.153, medians=[0.785, 0.00476, 0.375], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.138, medians=[0.789, 0.00468, 0.367], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.128, medians=[0.787, 0.00460, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.122, medians=[0.785, 0.00452, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.120, medians=[0.783, 0.00446, 0.344], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.119, medians=[0.781, 0.00441, 0.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.114, medians=[0.779, 0.00436, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.111, medians=[0.778, 0.00432, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.107, medians=[0.776, 0.00428, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.105, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.104, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.102, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.099, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.097, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.095, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.092, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.090, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.089, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.087, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.085, medians=[0.775, 0.00424, 0.320], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=16: ok in 63.49s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.108, medians=[0.747, 0.00409, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.102, medians=[0.746, 0.00402, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.098, medians=[0.746, 0.00395, 0.284], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.093, medians=[0.745, 0.00389, 0.278], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.088, medians=[0.743, 0.00384, 0.274], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.085, medians=[0.741, 0.00380, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.081, medians=[0.740, 0.00376, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.079, medians=[0.737, 0.00372, 0.260], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.078, medians=[0.736, 0.00368, 0.256], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.075, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.073, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.071, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.070, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.5s, rate=0.068, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.066, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.064, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.0s, rate=0.062, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.2s, rate=0.061, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.060, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.059, medians=[0.734, 0.00365, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=17: ok in 63.54s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.150, medians=[0.761, 0.00440, 0.339], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.122, medians=[0.754, 0.00431, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.110, medians=[0.749, 0.00426, 0.319], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.111, medians=[0.745, 0.00419, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.108, medians=[0.742, 0.00413, 0.305], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.103, medians=[0.739, 0.00407, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.100, medians=[0.737, 0.00401, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.096, medians=[0.734, 0.00395, 0.285], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.091, medians=[0.732, 0.00389, 0.279], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.088, medians=[0.730, 0.00384, 0.273], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.085, medians=[0.730, 0.00384, 0.273], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.082, medians=[0.730, 0.00384, 0.273], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.3s, rate=0.080, medians=[0.730, 0.00384, 0.273], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.110, medians=[0.616, 0.00385, 0.227], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.116, medians=[0.613, 0.00410, 0.242], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.125, medians=[0.615, 0.00446, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.140, medians=[0.622, 0.00492, 0.293], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.157, medians=[0.634, 0.00547, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.174, medians=[0.650, 0.00613, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.9s, rate=0.197, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.220, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.6s, rate=0.242, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.9s, rate=0.264, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.283, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.4s, rate=0.301, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.7s, rate=0.317, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.332, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.346, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.360, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.371, medians=[0.671, 0.00684, 0.426], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=25: ok in 64.83s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.237, medians=[0.663, 0.00580, 0.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.229, medians=[0.660, 0.00692, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.245, medians=[0.681, 0.00791, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.264, medians=[0.709, 0.00903, 0.555], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.294, medians=[0.747, 0.01029, 0.651], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.323, medians=[0.786, 0.01167, 0.763], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.347, medians=[0.823, 0.01294, 0.883], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.372, medians=[0.856, 0.01412, 1.000], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.395, medians=[0.883, 0.01538, 1.111], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.416, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.429, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.443, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.452, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.459, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.467, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.474, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.479, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.486, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.490, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.494, medians=[0.906, 0.01651, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=26: ok in 65.26s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.167, medians=[0.615, 0.00543, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.186, medians=[0.618, 0.00625, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.198, medians=[0.636, 0.00706, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.225, medians=[0.665, 0.00797, 0.479], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.253, medians=[0.699, 0.00908, 0.557], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.283, medians=[0.738, 0.01030, 0.655], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.311, medians=[0.775, 0.01155, 0.758], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.340, medians=[0.810, 0.01279, 0.869], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.361, medians=[0.840, 0.01390, 0.975], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.382, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.401, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.415, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.425, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.436, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.445, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.454, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.461, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.469, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.473, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.480, medians=[0.866, 0.01490, 1.073], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=27: ok in 65.20s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.201, medians=[0.631, 0.00588, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.205, medians=[0.641, 0.00691, 0.415], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.230, medians=[0.665, 0.00808, 0.480], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.261, medians=[0.702, 0.00928, 0.564], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.295, medians=[0.743, 0.01073, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.324, medians=[0.786, 0.01218, 0.795], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.352, medians=[0.824, 0.01359, 0.919], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.377, medians=[0.857, 0.01487, 1.037], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.397, medians=[0.884, 0.01610, 1.146], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.413, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.428, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.441, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.451, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.461, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.469, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.476, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.480, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.486, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.491, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.495, medians=[0.906, 0.01725, 1.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=28: ok in 65.25s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.208, medians=[0.606, 0.00517, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.196, medians=[0.609, 0.00599, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.212, medians=[0.632, 0.00682, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.234, medians=[0.663, 0.00790, 0.476], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.266, medians=[0.701, 0.00906, 0.565], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.297, medians=[0.741, 0.01042, 0.667], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.324, medians=[0.778, 0.01186, 0.779], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.351, medians=[0.815, 0.01313, 0.902], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.371, medians=[0.846, 0.01426, 1.014], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.387, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.401, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.413, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.425, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.435, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.443, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.450, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.459, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.465, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.472, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.477, medians=[0.871, 0.01527, 1.107], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=29: ok in 65.28s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.237, medians=[0.663, 0.00499, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.203, medians=[0.645, 0.00601, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.223, medians=[0.660, 0.00699, 0.430], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.247, medians=[0.687, 0.00805, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.273, medians=[0.721, 0.00916, 0.585], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.299, medians=[0.758, 0.01035, 0.682], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.323, medians=[0.794, 0.01151, 0.788], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.345, medians=[0.827, 0.01265, 0.900], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.367, medians=[0.857, 0.01366, 1.006], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.383, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.402, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.419, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.429, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.441, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.450, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.458, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.463, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.469, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.474, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.479, medians=[0.882, 0.01463, 1.104], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 16 chain 1, k=30: ok in 65.25s
# [ Info: All k (1..30) finished for dataset 16. Total time 1944.95s -> output dir: output
