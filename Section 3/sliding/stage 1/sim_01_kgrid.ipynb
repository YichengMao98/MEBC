# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")
model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 1
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.393, medians=[0.814, 0.00943, 0.493], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.4s, rate=0.362, medians=[0.801, 0.01285, 0.591], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.7s, rate=0.380, medians=[0.843, 0.01506, 0.722], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.0s, rate=0.405, medians=[0.897, 0.01696, 0.884], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.2s, rate=0.438, medians=[0.948, 0.01845, 1.060], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.5s, rate=0.462, medians=[0.990, 0.01963, 1.227], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.7s, rate=0.479, medians=[1.025, 0.02057, 1.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=27.9s, rate=0.496, medians=[1.051, 0.02134, 1.504], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.2s, rate=0.510, medians=[1.073, 0.02188, 1.608], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.4s, rate=0.519, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.6s, rate=0.529, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.8s, rate=0.536, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.0s, rate=0.541, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.2s, rate=0.546, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.4s, rate=0.552, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.6s, rate=0.554, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.8s, rate=0.557, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.0s, rate=0.562, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.2s, rate=0.566, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.3s, rate=0.569, medians=[1.091, 0.02239, 1.701], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=1: ok in 70.27s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.359, medians=[0.736, 0.00986, 0.434], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.330, medians=[0.736, 0.01249, 0.520], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.347, medians=[0.783, 0.01397, 0.626], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.373, medians=[0.842, 0.01504, 0.753], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.398, medians=[0.897, 0.01603, 0.895], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.427, medians=[0.947, 0.01692, 1.049], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.450, medians=[0.990, 0.01765, 1.204], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.470, medians=[1.023, 0.01831, 1.334], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.482, medians=[1.049, 0.01892, 1.444], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.497, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.510, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.519, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.526, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.534, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.3s, rate=0.540, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.5s, rate=0.545, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.7s, rate=0.550, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.9s, rate=0.553, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.1s, rate=0.558, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.3s, rate=0.563, medians=[1.070, 0.01942, 1.539], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=2: ok in 64.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.332, medians=[0.678, 0.00847, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.281, medians=[0.681, 0.01030, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.293, medians=[0.726, 0.01137, 0.500], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.313, medians=[0.778, 0.01225, 0.596], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.340, medians=[0.835, 0.01307, 0.711], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.370, medians=[0.887, 0.01385, 0.837], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.402, medians=[0.933, 0.01464, 0.970], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.427, medians=[0.973, 0.01533, 1.103], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.445, medians=[1.005, 0.01592, 1.218], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.462, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.474, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.485, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.496, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.506, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.4s, rate=0.515, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.6s, rate=0.522, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.527, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.1s, rate=0.534, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.3s, rate=0.538, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.5s, rate=0.541, medians=[1.032, 0.01642, 1.315], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=3: ok in 64.50s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.310, medians=[0.741, 0.00872, 0.433], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.281, medians=[0.769, 0.01003, 0.511], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.301, medians=[0.818, 0.01082, 0.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.330, medians=[0.867, 0.01156, 0.693], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.361, medians=[0.913, 0.01229, 0.797], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.383, medians=[0.955, 0.01292, 0.903], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.403, medians=[0.991, 0.01346, 1.004], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.424, medians=[1.024, 0.01391, 1.103], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.440, medians=[1.050, 0.01435, 1.191], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.458, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.470, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.481, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.490, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.499, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.506, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.511, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.517, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.523, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.529, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.532, medians=[1.072, 0.01473, 1.270], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=4: ok in 64.72s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.258, medians=[0.747, 0.00797, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.261, medians=[0.782, 0.00886, 0.489], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.280, medians=[0.824, 0.00950, 0.562], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.304, medians=[0.866, 0.01012, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.336, medians=[0.905, 0.01068, 0.719], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.360, medians=[0.941, 0.01122, 0.800], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.380, medians=[0.974, 0.01176, 0.888], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.401, medians=[1.006, 0.01225, 0.979], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.421, medians=[1.034, 0.01265, 1.066], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.438, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.450, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.463, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.472, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.483, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.491, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.497, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.502, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.505, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.510, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.515, medians=[1.059, 0.01304, 1.152], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=5: ok in 65.05s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.295, medians=[0.826, 0.00752, 0.463], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.281, medians=[0.847, 0.00824, 0.524], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.296, medians=[0.875, 0.00879, 0.582], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.310, medians=[0.904, 0.00928, 0.644], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.332, medians=[0.934, 0.00976, 0.709], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.356, medians=[0.965, 0.01024, 0.781], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.376, medians=[0.993, 0.01067, 0.854], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.393, medians=[1.017, 0.01105, 0.919], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.411, medians=[1.038, 0.01138, 0.979], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.424, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.439, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.450, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.461, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.467, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.474, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.481, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.486, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.491, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.495, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.498, medians=[1.059, 0.01167, 1.040], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=6: ok in 65.21s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.219, medians=[0.757, 0.00683, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.221, medians=[0.797, 0.00719, 0.443], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.236, medians=[0.826, 0.00758, 0.489], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.251, medians=[0.853, 0.00797, 0.536], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.270, medians=[0.880, 0.00833, 0.585], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.291, medians=[0.907, 0.00867, 0.635], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.313, medians=[0.932, 0.00901, 0.688], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.332, medians=[0.956, 0.00935, 0.742], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.350, medians=[0.979, 0.00966, 0.798], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.364, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.380, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.390, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.401, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.412, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.423, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.431, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.439, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.447, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.454, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.459, medians=[1.000, 0.00996, 0.850], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=7: ok in 65.12s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.254, medians=[0.847, 0.00671, 0.468], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.246, medians=[0.865, 0.00713, 0.507], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.257, medians=[0.884, 0.00745, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.271, medians=[0.902, 0.00774, 0.580], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.288, medians=[0.919, 0.00802, 0.616], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.304, medians=[0.936, 0.00826, 0.649], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.319, medians=[0.953, 0.00848, 0.685], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.330, medians=[0.969, 0.00869, 0.720], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.339, medians=[0.983, 0.00890, 0.751], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.347, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.356, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.366, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.374, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.382, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.389, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.395, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.401, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.406, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.411, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.417, medians=[0.996, 0.00907, 0.780], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=8: ok in 65.25s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.229, medians=[0.847, 0.00605, 0.434], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.219, medians=[0.856, 0.00636, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.223, medians=[0.866, 0.00658, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.228, medians=[0.877, 0.00677, 0.507], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.243, medians=[0.890, 0.00697, 0.531], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.252, medians=[0.902, 0.00716, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.260, medians=[0.915, 0.00734, 0.582], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.269, medians=[0.927, 0.00749, 0.605], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.279, medians=[0.937, 0.00765, 0.626], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.2s, rate=0.289, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.300, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.306, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.314, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.321, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.328, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.335, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.339, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.343, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.348, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.352, medians=[0.946, 0.00780, 0.647], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=9: ok in 65.00s
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.258, medians=[0.810, 0.00608, 0.440], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.6s, rate=0.240, medians=[0.844, 0.00623, 0.466], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.229, medians=[0.860, 0.00639, 0.487], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.230, medians=[0.873, 0.00651, 0.505], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.238, medians=[0.883, 0.00664, 0.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.247, medians=[0.893, 0.00675, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.252, medians=[0.902, 0.00685, 0.553], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.260, medians=[0.910, 0.00695, 0.567], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.266, medians=[0.918, 0.00704, 0.580], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.2s, rate=0.273, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.279, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.7s, rate=0.283, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.286, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.292, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.295, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.300, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.302, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.304, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.308, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.312, medians=[0.925, 0.00713, 0.595], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=10: ok in 64.99s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.138, medians=[0.786, 0.00477, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.142, medians=[0.792, 0.00494, 0.337], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.145, medians=[0.804, 0.00505, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.147, medians=[0.811, 0.00517, 0.367], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.157, medians=[0.818, 0.00529, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.165, medians=[0.826, 0.00540, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.172, medians=[0.835, 0.00551, 0.410], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.177, medians=[0.842, 0.00561, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.184, medians=[0.849, 0.00571, 0.436], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.191, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.195, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.200, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.205, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.209, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.214, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.218, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.222, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.226, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.229, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.234, medians=[0.856, 0.00579, 0.448], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=11: ok in 63.53s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.111, medians=[0.809, 0.00482, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.126, medians=[0.815, 0.00491, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.133, medians=[0.821, 0.00499, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.139, medians=[0.826, 0.00506, 0.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.145, medians=[0.831, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.155, medians=[0.834, 0.00519, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.158, medians=[0.838, 0.00525, 0.403], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.158, medians=[0.842, 0.00530, 0.410], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.160, medians=[0.844, 0.00535, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.165, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.168, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.172, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.174, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.3s, rate=0.176, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.179, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.182, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.8s, rate=0.184, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.186, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.187, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.188, medians=[0.847, 0.00539, 0.421], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=12: ok in 63.38s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.161, medians=[0.815, 0.00473, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.154, medians=[0.819, 0.00478, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.156, medians=[0.820, 0.00482, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.150, medians=[0.821, 0.00485, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.150, medians=[0.823, 0.00487, 0.375], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.154, medians=[0.825, 0.00489, 0.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.152, medians=[0.826, 0.00490, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.150, medians=[0.827, 0.00492, 0.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.151, medians=[0.827, 0.00494, 0.382], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.151, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.152, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.153, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.155, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.155, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.155, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.154, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.155, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.156, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.155, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.156, medians=[0.829, 0.00495, 0.385], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=13: ok in 63.40s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.144, medians=[0.790, 0.00457, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.133, medians=[0.802, 0.00455, 0.346], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.126, medians=[0.805, 0.00454, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.129, medians=[0.806, 0.00453, 0.346], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.127, medians=[0.805, 0.00453, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.123, medians=[0.804, 0.00452, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.121, medians=[0.804, 0.00451, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.119, medians=[0.803, 0.00450, 0.341], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.118, medians=[0.804, 0.00449, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.117, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.116, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.116, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.115, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.115, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.115, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.113, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.112, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.113, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.113, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.114, medians=[0.804, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=14: ok in 63.40s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.116, medians=[0.794, 0.00436, 0.332], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.113, medians=[0.792, 0.00432, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.110, medians=[0.790, 0.00430, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.106, medians=[0.791, 0.00428, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.104, medians=[0.790, 0.00426, 0.321], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.103, medians=[0.789, 0.00423, 0.317], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.101, medians=[0.787, 0.00421, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.099, medians=[0.786, 0.00419, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.096, medians=[0.785, 0.00416, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.094, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.094, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.093, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.092, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.090, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.089, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.089, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.089, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.089, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.089, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.088, medians=[0.783, 0.00414, 0.307], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=15: ok in 63.42s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.185, medians=[0.772, 0.00451, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.146, medians=[0.778, 0.00445, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.131, medians=[0.778, 0.00440, 0.337], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.123, medians=[0.778, 0.00434, 0.332], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.118, medians=[0.777, 0.00430, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.113, medians=[0.776, 0.00426, 0.323], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.111, medians=[0.775, 0.00422, 0.318], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.109, medians=[0.774, 0.00418, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.107, medians=[0.772, 0.00414, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.104, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.102, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.100, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.098, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.096, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.094, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.093, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.091, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.089, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.087, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.086, medians=[0.771, 0.00411, 0.305], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=16: ok in 63.43s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.139, medians=[0.758, 0.00362, 0.243], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.090, medians=[0.745, 0.00353, 0.238], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.082, medians=[0.739, 0.00349, 0.233], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.075, medians=[0.734, 0.00346, 0.229], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.068, medians=[0.732, 0.00342, 0.225], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.064, medians=[0.730, 0.00338, 0.221], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.061, medians=[0.728, 0.00335, 0.218], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.059, medians=[0.727, 0.00332, 0.214], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.056, medians=[0.726, 0.00329, 0.212], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.053, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.052, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.050, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.049, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.049, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.048, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.8s, rate=0.047, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.046, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.046, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.045, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.5s, rate=0.044, medians=[0.725, 0.00327, 0.209], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=17: ok in 63.48s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.121, medians=[0.723, 0.00404, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.103, medians=[0.728, 0.00395, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.092, medians=[0.729, 0.00387, 0.276], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.088, medians=[0.727, 0.00381, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.084, medians=[0.726, 0.00375, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.081, medians=[0.725, 0.00369, 0.257], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.076, medians=[0.723, 0.00364, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.074, medians=[0.721, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.072, medians=[0.720, 0.00355, 0.241], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.069, medians=[0.718, 0.00351, 0.237], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.066, medians=[0.718, 0.00351, 0.237], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.063, medians=[0.718, 0.00351, 0.237], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.061, medians=[0.718, 0.00351, 0.237], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.255, medians=[0.703, 0.00886, 0.546], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.290, medians=[0.743, 0.01005, 0.643], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.325, medians=[0.786, 0.01139, 0.763], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.351, medians=[0.825, 0.01263, 0.886], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.373, medians=[0.856, 0.01385, 0.997], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.393, medians=[0.883, 0.01492, 1.099], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.409, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.424, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.438, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.450, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.459, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.467, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.472, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.477, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.483, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.488, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.493, medians=[0.906, 0.01589, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=25: ok in 64.91s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.242, medians=[0.686, 0.00505, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.226, medians=[0.656, 0.00611, 0.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.231, medians=[0.666, 0.00696, 0.424], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.257, medians=[0.688, 0.00801, 0.488], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.278, medians=[0.721, 0.00905, 0.568], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.303, medians=[0.757, 0.01035, 0.667], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.330, medians=[0.791, 0.01171, 0.772], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.351, medians=[0.823, 0.01285, 0.877], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.369, medians=[0.852, 0.01402, 0.983], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.386, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.402, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.416, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.428, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.437, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.448, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.455, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.461, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.466, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.472, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.477, medians=[0.877, 0.01504, 1.085], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=26: ok in 64.87s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.130, medians=[0.566, 0.00502, 0.279], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.136, medians=[0.578, 0.00546, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.160, medians=[0.595, 0.00613, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.184, medians=[0.618, 0.00698, 0.399], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.208, medians=[0.648, 0.00790, 0.462], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.240, medians=[0.685, 0.00889, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.271, medians=[0.725, 0.01003, 0.642], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.298, medians=[0.762, 0.01130, 0.749], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.323, medians=[0.795, 0.01251, 0.855], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.345, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.364, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.382, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.397, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.2s, rate=0.411, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.5s, rate=0.422, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.7s, rate=0.432, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.441, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.449, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.456, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.463, medians=[0.824, 0.01370, 0.958], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=27: ok in 64.67s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.221, medians=[0.655, 0.00428, 0.270], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.191, medians=[0.618, 0.00507, 0.299], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.195, medians=[0.621, 0.00582, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.205, medians=[0.637, 0.00670, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.229, medians=[0.663, 0.00773, 0.459], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.258, medians=[0.698, 0.00881, 0.541], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.5s, rate=0.289, medians=[0.735, 0.01000, 0.640], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.8s, rate=0.316, medians=[0.772, 0.01121, 0.752], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.343, medians=[0.807, 0.01242, 0.868], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.362, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.381, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.399, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.0s, rate=0.413, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.424, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.5s, rate=0.434, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.7s, rate=0.445, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.455, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.463, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.469, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.475, medians=[0.838, 0.01356, 0.989], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=28: ok in 64.71s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.189, medians=[0.622, 0.00642, 0.386], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.207, medians=[0.645, 0.00742, 0.444], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.233, medians=[0.677, 0.00849, 0.514], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.271, medians=[0.713, 0.00968, 0.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.300, medians=[0.753, 0.01099, 0.697], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.333, medians=[0.793, 0.01223, 0.809], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.359, medians=[0.830, 0.01352, 0.928], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.377, medians=[0.862, 0.01478, 1.048], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.395, medians=[0.889, 0.01588, 1.156], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.414, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.429, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.441, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.452, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.461, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.470, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.477, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.485, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.490, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.494, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.498, medians=[0.913, 0.01694, 1.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=29: ok in 64.84s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.186, medians=[0.610, 0.00598, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.206, medians=[0.630, 0.00689, 0.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.239, medians=[0.661, 0.00782, 0.478], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.266, medians=[0.700, 0.00887, 0.561], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.301, medians=[0.741, 0.01012, 0.660], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.331, medians=[0.781, 0.01135, 0.770], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.355, medians=[0.818, 0.01251, 0.881], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.376, medians=[0.849, 0.01362, 0.989], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.396, medians=[0.875, 0.01470, 1.082], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.412, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.426, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.438, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.449, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.458, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.466, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.473, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.481, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.486, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.490, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.495, medians=[0.897, 0.01569, 1.170], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 01 chain 1, k=30: ok in 64.92s
# [ Info: All k (1..30) finished for dataset 01. Total time 1937.63s -> output dir: output
