# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 17
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.345, medians=[0.644, 0.00959, 0.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.4s, rate=0.308, medians=[0.670, 0.01247, 0.470], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.7s, rate=0.326, medians=[0.726, 0.01425, 0.579], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.0s, rate=0.355, medians=[0.789, 0.01578, 0.712], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.3s, rate=0.388, medians=[0.853, 0.01714, 0.879], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.6s, rate=0.420, medians=[0.909, 0.01840, 1.057], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.9s, rate=0.444, medians=[0.955, 0.01940, 1.231], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.2s, rate=0.460, medians=[0.990, 0.02038, 1.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.4s, rate=0.474, medians=[1.018, 0.02124, 1.509], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.6s, rate=0.491, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.8s, rate=0.502, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=41.1s, rate=0.512, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.3s, rate=0.522, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.6s, rate=0.531, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.8s, rate=0.538, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=54.0s, rate=0.542, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.2s, rate=0.547, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.4s, rate=0.550, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.7s, rate=0.554, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.9s, rate=0.557, medians=[1.041, 0.02210, 1.625], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=1: ok in 70.86s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.352, medians=[0.713, 0.00940, 0.408], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.312, medians=[0.721, 0.01191, 0.497], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.335, medians=[0.773, 0.01326, 0.603], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.359, medians=[0.830, 0.01449, 0.728], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.393, medians=[0.889, 0.01549, 0.875], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.7s, rate=0.416, medians=[0.939, 0.01640, 1.027], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.0s, rate=0.438, medians=[0.980, 0.01717, 1.167], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.460, medians=[1.016, 0.01780, 1.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.479, medians=[1.047, 0.01832, 1.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.492, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.505, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.517, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.526, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.532, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.537, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.543, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.549, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.553, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.557, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.562, medians=[1.071, 0.01880, 1.553], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=2: ok in 64.88s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.332, medians=[0.706, 0.00849, 0.390], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.296, medians=[0.717, 0.01061, 0.469], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.307, medians=[0.766, 0.01162, 0.558], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.337, medians=[0.820, 0.01261, 0.665], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.368, medians=[0.874, 0.01349, 0.787], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.7s, rate=0.402, medians=[0.923, 0.01443, 0.922], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.0s, rate=0.426, medians=[0.965, 0.01523, 1.055], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.3s, rate=0.444, medians=[1.001, 0.01586, 1.183], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.459, medians=[1.032, 0.01631, 1.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.474, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.486, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.498, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.508, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.517, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.525, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.532, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.535, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.542, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.546, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.550, medians=[1.055, 0.01679, 1.384], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=3: ok in 65.32s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.343, medians=[0.788, 0.00921, 0.502], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.329, medians=[0.826, 0.01056, 0.596], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.355, medians=[0.878, 0.01138, 0.696], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.382, medians=[0.928, 0.01214, 0.806], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.408, medians=[0.972, 0.01286, 0.917], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.428, medians=[1.009, 0.01353, 1.028], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.1s, rate=0.449, medians=[1.041, 0.01410, 1.135], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.4s, rate=0.465, medians=[1.069, 0.01458, 1.235], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.6s, rate=0.478, medians=[1.093, 0.01494, 1.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.9s, rate=0.490, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.2s, rate=0.502, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.510, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.518, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.0s, rate=0.526, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.533, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.537, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.540, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.546, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.548, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.550, medians=[1.114, 0.01521, 1.404], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=4: ok in 65.56s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.281, medians=[0.792, 0.00805, 0.451], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.281, medians=[0.816, 0.00897, 0.520], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.303, medians=[0.853, 0.00964, 0.593], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.330, medians=[0.890, 0.01036, 0.673], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.353, medians=[0.927, 0.01098, 0.759], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.7s, rate=0.376, medians=[0.965, 0.01149, 0.851], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.0s, rate=0.395, medians=[1.000, 0.01195, 0.943], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.4s, rate=0.416, medians=[1.028, 0.01242, 1.028], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.7s, rate=0.435, medians=[1.054, 0.01280, 1.112], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.0s, rate=0.449, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.2s, rate=0.463, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.5s, rate=0.474, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.8s, rate=0.483, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.1s, rate=0.491, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.4s, rate=0.496, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.7s, rate=0.504, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.0s, rate=0.509, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.3s, rate=0.514, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.5s, rate=0.518, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.8s, rate=0.521, medians=[1.076, 0.01319, 1.190], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=5: ok in 65.83s
# [ Info: [sliding] iter 1000/20000 elapsed=3.5s, rate=0.256, medians=[0.746, 0.00683, 0.367], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.6s, rate=0.242, medians=[0.767, 0.00750, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.9s, rate=0.256, medians=[0.800, 0.00801, 0.476], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.271, medians=[0.833, 0.00845, 0.531], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.292, medians=[0.862, 0.00892, 0.587], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.313, medians=[0.894, 0.00935, 0.650], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.1s, rate=0.335, medians=[0.925, 0.00979, 0.717], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.4s, rate=0.355, medians=[0.956, 0.01025, 0.794], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.8s, rate=0.375, medians=[0.984, 0.01066, 0.869], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.1s, rate=0.394, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.4s, rate=0.409, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.7s, rate=0.422, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.0s, rate=0.436, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.3s, rate=0.448, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.6s, rate=0.456, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.9s, rate=0.463, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.2s, rate=0.470, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.5s, rate=0.476, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.8s, rate=0.482, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.1s, rate=0.488, medians=[1.010, 0.01104, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=6: ok in 66.16s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.249, medians=[0.809, 0.00703, 0.445], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.246, medians=[0.838, 0.00752, 0.497], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.262, medians=[0.865, 0.00788, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.281, medians=[0.891, 0.00823, 0.589], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.301, medians=[0.913, 0.00858, 0.634], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.316, medians=[0.936, 0.00890, 0.680], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.332, medians=[0.958, 0.00922, 0.729], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.343, medians=[0.978, 0.00952, 0.775], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.6s, rate=0.356, medians=[0.997, 0.00980, 0.822], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.9s, rate=0.371, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.2s, rate=0.386, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.5s, rate=0.398, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.9s, rate=0.408, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.2s, rate=0.417, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.5s, rate=0.425, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.8s, rate=0.432, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.1s, rate=0.439, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.4s, rate=0.446, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.8s, rate=0.453, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.1s, rate=0.458, medians=[1.015, 0.01007, 0.871], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=7: ok in 66.09s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.270, medians=[0.856, 0.00678, 0.480], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.264, medians=[0.874, 0.00721, 0.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.267, medians=[0.894, 0.00754, 0.561], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.285, medians=[0.914, 0.00781, 0.599], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.300, medians=[0.932, 0.00808, 0.636], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.314, medians=[0.951, 0.00834, 0.674], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.329, medians=[0.967, 0.00861, 0.713], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.347, medians=[0.985, 0.00887, 0.754], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.6s, rate=0.361, medians=[1.001, 0.00912, 0.794], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.9s, rate=0.372, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.2s, rate=0.383, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.5s, rate=0.394, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.9s, rate=0.400, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.2s, rate=0.407, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.5s, rate=0.414, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.8s, rate=0.421, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.2s, rate=0.426, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.5s, rate=0.431, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.8s, rate=0.436, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.1s, rate=0.441, medians=[1.017, 0.00933, 0.833], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=8: ok in 66.16s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.222, medians=[0.766, 0.00569, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.205, medians=[0.796, 0.00600, 0.400], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.211, medians=[0.817, 0.00621, 0.428], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.219, medians=[0.836, 0.00640, 0.454], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.228, medians=[0.851, 0.00660, 0.480], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.241, medians=[0.867, 0.00678, 0.505], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.5s, rate=0.246, medians=[0.881, 0.00696, 0.530], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.8s, rate=0.256, medians=[0.894, 0.00715, 0.555], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.265, medians=[0.906, 0.00731, 0.578], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.278, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.285, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.294, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.300, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.306, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.314, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.319, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.325, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.330, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.335, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.340, medians=[0.918, 0.00747, 0.601], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=9: ok in 65.75s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.188, medians=[0.798, 0.00551, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.189, medians=[0.819, 0.00570, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.186, medians=[0.835, 0.00588, 0.428], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.195, medians=[0.848, 0.00602, 0.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.205, medians=[0.858, 0.00616, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.220, medians=[0.869, 0.00630, 0.483], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.227, medians=[0.879, 0.00642, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.234, medians=[0.887, 0.00654, 0.517], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.240, medians=[0.895, 0.00666, 0.532], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.245, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.4s, rate=0.251, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.254, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.260, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.264, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.269, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.275, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.279, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.283, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.286, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.290, medians=[0.903, 0.00676, 0.547], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=10: ok in 65.35s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.167, medians=[0.762, 0.00476, 0.311], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.151, medians=[0.783, 0.00487, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.155, medians=[0.794, 0.00500, 0.346], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.155, medians=[0.803, 0.00513, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.159, medians=[0.812, 0.00523, 0.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.163, medians=[0.819, 0.00532, 0.386], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.169, medians=[0.825, 0.00541, 0.397], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.177, medians=[0.832, 0.00549, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.181, medians=[0.839, 0.00559, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.184, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.188, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.192, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.196, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.201, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.205, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.210, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.213, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.216, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.218, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.221, medians=[0.845, 0.00568, 0.432], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=11: ok in 64.16s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.201, medians=[0.869, 0.00547, 0.444], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.193, medians=[0.865, 0.00557, 0.449], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.191, medians=[0.865, 0.00561, 0.452], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.187, medians=[0.867, 0.00563, 0.455], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.184, medians=[0.869, 0.00564, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.187, medians=[0.869, 0.00566, 0.459], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.185, medians=[0.869, 0.00568, 0.460], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.186, medians=[0.869, 0.00568, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.188, medians=[0.870, 0.00570, 0.463], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.191, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.191, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.194, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.194, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.195, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.195, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.196, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.197, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.198, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.200, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.202, medians=[0.870, 0.00571, 0.465], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=12: ok in 64.11s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.104, medians=[0.805, 0.00454, 0.334], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.102, medians=[0.806, 0.00457, 0.337], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.108, medians=[0.808, 0.00460, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.114, medians=[0.809, 0.00464, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.118, medians=[0.810, 0.00466, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.119, medians=[0.811, 0.00469, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.120, medians=[0.813, 0.00472, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.121, medians=[0.816, 0.00474, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.123, medians=[0.817, 0.00477, 0.362], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.126, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.125, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.129, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.131, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.131, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.130, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.131, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.130, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.130, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.131, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.131, medians=[0.818, 0.00480, 0.365], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=13: ok in 64.11s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.165, medians=[0.835, 0.00447, 0.355], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.136, medians=[0.820, 0.00451, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.129, medians=[0.815, 0.00452, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.127, medians=[0.812, 0.00452, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.125, medians=[0.811, 0.00450, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.124, medians=[0.809, 0.00449, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.120, medians=[0.807, 0.00449, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.120, medians=[0.806, 0.00448, 0.341], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.119, medians=[0.805, 0.00447, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.115, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.115, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.115, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.114, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.114, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.112, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.112, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.112, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.112, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.111, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.111, medians=[0.804, 0.00447, 0.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=14: ok in 64.13s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.150, medians=[0.834, 0.00495, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.146, medians=[0.828, 0.00491, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.141, medians=[0.825, 0.00486, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.140, medians=[0.822, 0.00481, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.134, medians=[0.819, 0.00477, 0.384], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.130, medians=[0.817, 0.00473, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.128, medians=[0.814, 0.00469, 0.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.125, medians=[0.811, 0.00465, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.121, medians=[0.808, 0.00461, 0.364], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.117, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.114, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.114, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.112, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.111, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.110, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.109, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.109, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.106, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.105, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.105, medians=[0.806, 0.00457, 0.359], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=15: ok in 64.16s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.140, medians=[0.788, 0.00384, 0.281], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.099, medians=[0.771, 0.00381, 0.273], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.092, medians=[0.764, 0.00377, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.085, medians=[0.759, 0.00375, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.080, medians=[0.756, 0.00372, 0.261], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.079, medians=[0.755, 0.00370, 0.258], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.075, medians=[0.753, 0.00368, 0.256], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.076, medians=[0.752, 0.00366, 0.253], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.075, medians=[0.750, 0.00365, 0.251], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.073, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.071, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.071, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.069, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.068, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.067, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.067, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.066, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.066, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.065, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.064, medians=[0.749, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=16: ok in 64.15s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.108, medians=[0.753, 0.00406, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.103, medians=[0.749, 0.00401, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.095, medians=[0.747, 0.00396, 0.287], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.089, medians=[0.744, 0.00392, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.086, medians=[0.742, 0.00388, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.082, medians=[0.741, 0.00383, 0.272], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.5s, rate=0.077, medians=[0.739, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.075, medians=[0.736, 0.00374, 0.262], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.073, medians=[0.735, 0.00370, 0.257], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.071, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.071, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.069, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.067, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.066, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.065, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.063, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.061, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.8s, rate=0.060, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.0s, rate=0.059, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.2s, rate=0.058, medians=[0.734, 0.00366, 0.252], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=17: ok in 64.19s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.130, medians=[0.737, 0.00450, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.116, medians=[0.739, 0.00439, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.109, medians=[0.740, 0.00431, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.106, medians=[0.738, 0.00425, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.100, medians=[0.737, 0.00419, 0.308], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.099, medians=[0.735, 0.00413, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.096, medians=[0.733, 0.00407, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.094, medians=[0.731, 0.00401, 0.289], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.090, medians=[0.729, 0.00395, 0.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.086, medians=[0.728, 0.00390, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.083, medians=[0.728, 0.00390, 0.277], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.080, medians=[0.728, 0.00390, 0.277], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.077, medians=[0.728, 0.00390, 0.277], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.229, medians=[0.683, 0.00805, 0.498], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.260, medians=[0.716, 0.00912, 0.575], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.285, medians=[0.751, 0.01029, 0.666], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.316, medians=[0.787, 0.01141, 0.769], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.340, medians=[0.820, 0.01255, 0.875], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.363, medians=[0.849, 0.01365, 0.978], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.383, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.401, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.418, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.431, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.0s, rate=0.441, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.3s, rate=0.448, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.6s, rate=0.456, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.9s, rate=0.461, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.467, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.473, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.478, medians=[0.874, 0.01477, 1.080], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=25: ok in 65.74s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.215, medians=[0.654, 0.00519, 0.334], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.198, medians=[0.639, 0.00602, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.211, medians=[0.650, 0.00696, 0.417], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.231, medians=[0.674, 0.00799, 0.481], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.261, medians=[0.705, 0.00917, 0.559], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.295, medians=[0.743, 0.01048, 0.660], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.323, medians=[0.783, 0.01185, 0.779], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.354, medians=[0.819, 0.01316, 0.905], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.374, medians=[0.851, 0.01439, 1.029], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.396, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.412, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.428, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.438, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.447, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.455, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.464, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.470, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.476, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.482, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.485, medians=[0.878, 0.01562, 1.145], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=26: ok in 65.58s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.107, medians=[0.553, 0.00471, 0.259], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.119, medians=[0.565, 0.00507, 0.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.140, medians=[0.582, 0.00562, 0.320], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.158, medians=[0.603, 0.00634, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.189, medians=[0.630, 0.00719, 0.423], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.218, medians=[0.665, 0.00826, 0.498], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.249, medians=[0.705, 0.00943, 0.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.280, medians=[0.746, 0.01066, 0.711], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.308, medians=[0.782, 0.01188, 0.827], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.332, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.352, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.369, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.386, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.399, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.412, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.422, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.432, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.438, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.446, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.453, medians=[0.814, 0.01309, 0.944], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=27: ok in 65.60s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.175, medians=[0.606, 0.00604, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.203, medians=[0.623, 0.00692, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.225, medians=[0.649, 0.00793, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.250, medians=[0.682, 0.00903, 0.539], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.276, medians=[0.722, 0.01019, 0.631], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.314, medians=[0.763, 0.01133, 0.737], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.341, medians=[0.802, 0.01245, 0.852], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.366, medians=[0.837, 0.01365, 0.972], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.386, medians=[0.866, 0.01497, 1.086], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.404, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.420, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.433, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.444, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.454, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.463, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.471, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.477, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.484, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.489, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.493, medians=[0.890, 0.01619, 1.193], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=28: ok in 65.62s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.181, medians=[0.579, 0.00532, 0.307], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.178, medians=[0.594, 0.00604, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.195, medians=[0.617, 0.00681, 0.400], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.221, medians=[0.648, 0.00781, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.242, medians=[0.683, 0.00896, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.275, medians=[0.722, 0.01007, 0.638], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.306, medians=[0.762, 0.01120, 0.744], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.334, medians=[0.798, 0.01233, 0.855], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.360, medians=[0.829, 0.01356, 0.964], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.381, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.398, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.413, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.425, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.435, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.447, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.456, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.463, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.469, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.476, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.482, medians=[0.855, 0.01475, 1.068], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=29: ok in 65.63s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.261, medians=[0.692, 0.00618, 0.426], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.261, medians=[0.688, 0.00756, 0.485], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.279, medians=[0.711, 0.00874, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.309, medians=[0.746, 0.01004, 0.647], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.343, medians=[0.787, 0.01138, 0.761], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.365, medians=[0.825, 0.01268, 0.879], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.0s, rate=0.386, medians=[0.858, 0.01404, 0.997], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.3s, rate=0.408, medians=[0.885, 0.01538, 1.111], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.6s, rate=0.425, medians=[0.910, 0.01654, 1.224], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.9s, rate=0.440, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.452, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.462, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.470, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.0s, rate=0.477, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.483, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.490, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.495, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.500, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.505, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.508, medians=[0.931, 0.01751, 1.319], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 17 chain 1, k=30: ok in 65.68s
# [ Info: All k (1..30) finished for dataset 17. Total time 1959.32s -> output dir: output
