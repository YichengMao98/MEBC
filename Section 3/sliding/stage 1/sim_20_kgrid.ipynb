# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 20
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.4s, rate=0.391, medians=[0.810, 0.00990, 0.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.6s, rate=0.375, medians=[0.813, 0.01349, 0.631], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.9s, rate=0.400, medians=[0.859, 0.01573, 0.769], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.2s, rate=0.419, medians=[0.917, 0.01744, 0.941], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.5s, rate=0.440, medians=[0.967, 0.01886, 1.119], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.8s, rate=0.464, medians=[1.008, 0.02014, 1.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=25.0s, rate=0.484, medians=[1.041, 0.02123, 1.462], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.3s, rate=0.503, medians=[1.066, 0.02214, 1.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.5s, rate=0.519, medians=[1.087, 0.02280, 1.714], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.7s, rate=0.530, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.9s, rate=0.539, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=41.2s, rate=0.545, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.4s, rate=0.552, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.6s, rate=0.558, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.8s, rate=0.562, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=54.1s, rate=0.566, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.3s, rate=0.569, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.6s, rate=0.571, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.8s, rate=0.574, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=67.0s, rate=0.576, medians=[1.103, 0.02343, 1.801], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=1: ok in 71.03s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.342, medians=[0.698, 0.00908, 0.374], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.310, medians=[0.690, 0.01190, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.329, medians=[0.735, 0.01346, 0.551], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.353, medians=[0.795, 0.01453, 0.672], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.382, medians=[0.853, 0.01563, 0.809], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.412, medians=[0.906, 0.01675, 0.967], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.435, medians=[0.952, 0.01765, 1.122], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.455, medians=[0.987, 0.01845, 1.256], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.472, medians=[1.016, 0.01907, 1.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.484, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.498, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.509, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.518, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.525, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.531, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.539, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.544, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.548, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.553, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.557, medians=[1.040, 0.01960, 1.467], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=2: ok in 64.82s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.294, medians=[0.613, 0.00905, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.277, medians=[0.639, 0.01092, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.284, medians=[0.698, 0.01176, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.312, medians=[0.758, 0.01261, 0.591], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.336, medians=[0.815, 0.01349, 0.705], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.366, medians=[0.868, 0.01436, 0.829], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.394, medians=[0.917, 0.01518, 0.970], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.416, medians=[0.960, 0.01579, 1.107], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.439, medians=[0.994, 0.01638, 1.226], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.457, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.472, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.484, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.495, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.507, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.514, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.523, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.531, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.535, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.540, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.545, medians=[1.024, 0.01683, 1.338], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=3: ok in 64.84s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.323, medians=[0.687, 0.00882, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.299, medians=[0.731, 0.01003, 0.482], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.315, medians=[0.788, 0.01075, 0.568], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.344, medians=[0.846, 0.01145, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.369, medians=[0.901, 0.01216, 0.784], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.396, medians=[0.949, 0.01288, 0.909], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.421, medians=[0.992, 0.01359, 1.041], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.443, medians=[1.027, 0.01419, 1.163], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.462, medians=[1.057, 0.01470, 1.276], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.475, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.488, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.498, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.507, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.516, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.525, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.532, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.536, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.539, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.543, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.546, medians=[1.080, 0.01514, 1.368], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=4: ok in 65.05s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.262, medians=[0.696, 0.00796, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.250, medians=[0.748, 0.00865, 0.451], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.268, medians=[0.792, 0.00932, 0.521], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.295, medians=[0.837, 0.00992, 0.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.316, medians=[0.877, 0.01049, 0.675], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.337, medians=[0.916, 0.01100, 0.755], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.364, medians=[0.953, 0.01155, 0.846], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.391, medians=[0.986, 0.01199, 0.932], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.408, medians=[1.016, 0.01235, 1.017], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.424, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.437, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.453, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.463, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.473, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.481, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.490, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.497, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.503, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.508, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.512, medians=[1.041, 0.01273, 1.097], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=5: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.303, medians=[0.798, 0.00784, 0.468], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.286, medians=[0.842, 0.00848, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.302, medians=[0.880, 0.00897, 0.602], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.322, medians=[0.912, 0.00943, 0.663], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.340, medians=[0.943, 0.00984, 0.726], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.358, medians=[0.974, 0.01028, 0.797], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.380, medians=[1.001, 0.01072, 0.868], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.397, medians=[1.026, 0.01109, 0.935], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.415, medians=[1.051, 0.01146, 1.010], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.431, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.444, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.456, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.467, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.475, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.483, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.489, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.493, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.498, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.502, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.505, medians=[1.073, 0.01178, 1.083], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=6: ok in 65.55s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.280, medians=[0.841, 0.00728, 0.479], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.274, medians=[0.866, 0.00786, 0.534], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.285, medians=[0.896, 0.00829, 0.590], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.308, medians=[0.924, 0.00870, 0.645], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.326, medians=[0.950, 0.00904, 0.697], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.342, medians=[0.974, 0.00937, 0.751], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.357, medians=[0.997, 0.00971, 0.806], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.370, medians=[1.019, 0.01004, 0.862], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.381, medians=[1.039, 0.01032, 0.916], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.395, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.406, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.415, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.424, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.432, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.438, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.446, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.452, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.459, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.465, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.469, medians=[1.056, 0.01058, 0.963], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=7: ok in 65.64s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.258, medians=[0.868, 0.00688, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.271, medians=[0.885, 0.00727, 0.530], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.272, medians=[0.906, 0.00755, 0.567], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.284, medians=[0.922, 0.00784, 0.603], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.301, medians=[0.938, 0.00810, 0.636], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.310, medians=[0.955, 0.00831, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.324, medians=[0.971, 0.00854, 0.704], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.339, medians=[0.985, 0.00877, 0.739], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.351, medians=[1.000, 0.00898, 0.774], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.360, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.371, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.379, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.387, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.393, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.397, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.402, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.409, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.413, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.417, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.6s, rate=0.421, medians=[1.014, 0.00916, 0.806], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=8: ok in 65.61s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.229, medians=[0.875, 0.00643, 0.479], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.223, medians=[0.890, 0.00670, 0.510], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.234, medians=[0.905, 0.00694, 0.540], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.245, medians=[0.917, 0.00713, 0.564], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.262, medians=[0.928, 0.00732, 0.588], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.278, medians=[0.941, 0.00750, 0.615], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.289, medians=[0.955, 0.00767, 0.642], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.295, medians=[0.966, 0.00783, 0.666], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.303, medians=[0.976, 0.00798, 0.688], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.309, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.317, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.324, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.332, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.340, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.347, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.351, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.354, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.359, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.364, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.367, medians=[0.986, 0.00812, 0.710], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=9: ok in 65.39s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.183, medians=[0.806, 0.00503, 0.337], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.163, medians=[0.815, 0.00524, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.169, medians=[0.826, 0.00542, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.179, medians=[0.837, 0.00558, 0.401], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.184, medians=[0.848, 0.00574, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.191, medians=[0.859, 0.00590, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.199, medians=[0.869, 0.00604, 0.460], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.207, medians=[0.879, 0.00617, 0.478], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.216, medians=[0.888, 0.00630, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.222, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.226, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.9s, rate=0.232, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.242, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.5s, rate=0.248, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.8s, rate=0.255, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.1s, rate=0.261, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.266, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.268, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.0s, rate=0.273, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.3s, rate=0.278, medians=[0.896, 0.00640, 0.510], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=10: ok in 64.31s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.157, medians=[0.781, 0.00484, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.146, medians=[0.796, 0.00498, 0.343], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.145, medians=[0.809, 0.00508, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.149, medians=[0.820, 0.00518, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.155, medians=[0.829, 0.00528, 0.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.157, medians=[0.836, 0.00537, 0.399], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.164, medians=[0.843, 0.00545, 0.410], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.166, medians=[0.849, 0.00553, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.172, medians=[0.855, 0.00561, 0.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.178, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.185, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.191, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.197, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.0s, rate=0.201, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.2s, rate=0.205, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.3s, rate=0.207, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.4s, rate=0.211, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.6s, rate=0.214, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.7s, rate=0.217, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.9s, rate=0.220, medians=[0.862, 0.00568, 0.442], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=11: ok in 62.92s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.150, medians=[0.824, 0.00459, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.141, medians=[0.824, 0.00473, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.139, medians=[0.826, 0.00482, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.140, medians=[0.830, 0.00489, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.147, medians=[0.834, 0.00494, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.150, medians=[0.837, 0.00499, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.153, medians=[0.840, 0.00504, 0.386], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.2s, rate=0.157, medians=[0.843, 0.00509, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.158, medians=[0.846, 0.00513, 0.397], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.5s, rate=0.161, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.165, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.167, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.168, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.0s, rate=0.170, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.2s, rate=0.172, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.3s, rate=0.173, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.5s, rate=0.174, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.6s, rate=0.175, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.8s, rate=0.177, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.9s, rate=0.178, medians=[0.849, 0.00517, 0.403], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=12: ok in 62.99s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.138, medians=[0.838, 0.00439, 0.336], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.128, medians=[0.828, 0.00448, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.131, medians=[0.826, 0.00453, 0.344], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.130, medians=[0.827, 0.00457, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.126, medians=[0.828, 0.00461, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.129, medians=[0.830, 0.00465, 0.357], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.131, medians=[0.831, 0.00469, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.131, medians=[0.833, 0.00472, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.135, medians=[0.834, 0.00474, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.136, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.138, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.137, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.139, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.0s, rate=0.139, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.1s, rate=0.139, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.3s, rate=0.140, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.4s, rate=0.140, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.6s, rate=0.141, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.7s, rate=0.140, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.9s, rate=0.143, medians=[0.835, 0.00477, 0.371], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=13: ok in 62.88s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.129, medians=[0.833, 0.00459, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.124, medians=[0.832, 0.00458, 0.364], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.127, medians=[0.830, 0.00458, 0.362], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.128, medians=[0.829, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.128, medians=[0.827, 0.00455, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.8s, rate=0.123, medians=[0.826, 0.00454, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.120, medians=[0.825, 0.00452, 0.354], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.118, medians=[0.824, 0.00451, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.119, medians=[0.824, 0.00450, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.118, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.116, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.116, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.116, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.0s, rate=0.116, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.1s, rate=0.116, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.3s, rate=0.114, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.4s, rate=0.115, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.6s, rate=0.114, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.7s, rate=0.114, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.9s, rate=0.114, medians=[0.823, 0.00450, 0.351], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=14: ok in 62.88s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.178, medians=[0.824, 0.00462, 0.378], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.154, medians=[0.823, 0.00456, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.134, medians=[0.820, 0.00450, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.126, medians=[0.818, 0.00444, 0.354], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.124, medians=[0.815, 0.00440, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.121, medians=[0.813, 0.00435, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.119, medians=[0.810, 0.00432, 0.337], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.1s, rate=0.118, medians=[0.808, 0.00429, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.115, medians=[0.805, 0.00426, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.4s, rate=0.111, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.108, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.7s, rate=0.106, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.104, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.0s, rate=0.102, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.2s, rate=0.101, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.3s, rate=0.100, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.5s, rate=0.100, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.6s, rate=0.099, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.8s, rate=0.098, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=62.9s, rate=0.098, medians=[0.804, 0.00423, 0.326], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=15: ok in 62.93s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.107, medians=[0.799, 0.00424, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.105, medians=[0.796, 0.00418, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.099, medians=[0.793, 0.00413, 0.319], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.099, medians=[0.791, 0.00409, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.097, medians=[0.789, 0.00405, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.096, medians=[0.787, 0.00401, 0.304], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.094, medians=[0.785, 0.00397, 0.300], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.2s, rate=0.091, medians=[0.784, 0.00394, 0.296], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.089, medians=[0.782, 0.00391, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.5s, rate=0.086, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.084, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.8s, rate=0.082, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=40.9s, rate=0.080, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.1s, rate=0.079, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.2s, rate=0.078, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.4s, rate=0.078, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.5s, rate=0.077, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.7s, rate=0.076, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.8s, rate=0.075, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.0s, rate=0.073, medians=[0.780, 0.00388, 0.288], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=16: ok in 62.98s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.140, medians=[0.792, 0.00395, 0.304], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.107, medians=[0.778, 0.00391, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.099, medians=[0.773, 0.00385, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.092, medians=[0.769, 0.00380, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.089, medians=[0.766, 0.00375, 0.276], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.086, medians=[0.764, 0.00371, 0.270], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.083, medians=[0.762, 0.00366, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.2s, rate=0.079, medians=[0.759, 0.00362, 0.260], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.3s, rate=0.074, medians=[0.757, 0.00359, 0.255], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.5s, rate=0.072, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.6s, rate=0.068, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.8s, rate=0.066, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.0s, rate=0.065, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.1s, rate=0.064, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.3s, rate=0.063, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.4s, rate=0.062, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.6s, rate=0.061, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=56.7s, rate=0.059, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=59.9s, rate=0.058, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.0s, rate=0.057, medians=[0.755, 0.00355, 0.251], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=17: ok in 63.07s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.140, medians=[0.735, 0.00413, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.121, medians=[0.739, 0.00400, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.102, medians=[0.741, 0.00390, 0.284], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.093, medians=[0.740, 0.00383, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.7s, rate=0.085, medians=[0.739, 0.00377, 0.270], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=18.9s, rate=0.080, medians=[0.739, 0.00371, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.0s, rate=0.076, medians=[0.738, 0.00365, 0.259], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.2s, rate=0.072, medians=[0.736, 0.00360, 0.253], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.4s, rate=0.071, medians=[0.735, 0.00355, 0.248], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.5s, rate=0.069, medians=[0.734, 0.00350, 0.243], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.7s, rate=0.067, medians=[0.734, 0.00350, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=37.8s, rate=0.065, medians=[0.734, 0.00350, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.0s, rate=0.063, medians=[0.734, 0.00350, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.6s, rate=0.177, medians=[0.649, 0.00564, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.197, medians=[0.665, 0.00632, 0.399], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.219, medians=[0.688, 0.00715, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.3s, rate=0.248, medians=[0.718, 0.00818, 0.535], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.274, medians=[0.751, 0.00925, 0.627], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.9s, rate=0.301, medians=[0.783, 0.01040, 0.728], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.2s, rate=0.323, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.343, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.361, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.375, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.389, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.402, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.411, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.422, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.431, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.439, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.446, medians=[0.813, 0.01146, 0.832], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=25: ok in 65.00s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.263, medians=[0.698, 0.00638, 0.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.243, medians=[0.701, 0.00763, 0.490], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.264, medians=[0.728, 0.00874, 0.564], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.295, medians=[0.762, 0.00993, 0.653], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.327, medians=[0.802, 0.01117, 0.762], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.351, medians=[0.840, 0.01252, 0.886], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.376, medians=[0.876, 0.01374, 1.016], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.400, medians=[0.906, 0.01485, 1.137], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.422, medians=[0.931, 0.01593, 1.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.436, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.448, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.461, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.471, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.480, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.487, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.493, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.498, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.501, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.506, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.509, medians=[0.951, 0.01698, 1.352], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=26: ok in 65.09s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.189, medians=[0.636, 0.00574, 0.357], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.200, medians=[0.646, 0.00667, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.221, medians=[0.670, 0.00766, 0.469], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.253, medians=[0.701, 0.00887, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.282, medians=[0.736, 0.01009, 0.632], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.315, medians=[0.776, 0.01129, 0.739], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.338, medians=[0.813, 0.01242, 0.848], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.359, medians=[0.844, 0.01367, 0.958], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.381, medians=[0.872, 0.01487, 1.065], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.401, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.418, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.431, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.444, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.454, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.460, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.469, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.475, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.482, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.488, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.494, medians=[0.895, 0.01608, 1.166], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=27: ok in 65.19s
# [ Info: [sliding] iter 1000/20000 elapsed=3.1s, rate=0.199, medians=[0.614, 0.00569, 0.344], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.190, medians=[0.630, 0.00658, 0.393], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.4s, rate=0.214, medians=[0.655, 0.00751, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.247, medians=[0.689, 0.00859, 0.527], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.274, medians=[0.728, 0.00983, 0.621], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.303, medians=[0.770, 0.01108, 0.733], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.331, medians=[0.809, 0.01231, 0.849], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.353, medians=[0.843, 0.01346, 0.968], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.375, medians=[0.874, 0.01458, 1.089], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.394, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.410, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.423, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.434, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.443, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.452, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.462, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.471, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.478, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.484, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.490, medians=[0.898, 0.01568, 1.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=28: ok in 65.13s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.150, medians=[0.602, 0.00543, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.164, medians=[0.617, 0.00613, 0.367], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.188, medians=[0.640, 0.00698, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.211, medians=[0.671, 0.00790, 0.487], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.249, medians=[0.706, 0.00905, 0.568], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.278, medians=[0.747, 0.01011, 0.667], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.313, medians=[0.787, 0.01132, 0.784], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.338, medians=[0.823, 0.01257, 0.903], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.359, medians=[0.853, 0.01377, 1.015], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.378, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.396, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.412, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.424, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.433, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.442, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.451, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.459, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.466, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.472, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.478, medians=[0.878, 0.01485, 1.114], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=29: ok in 65.16s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.201, medians=[0.632, 0.00584, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.218, medians=[0.650, 0.00666, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.243, medians=[0.679, 0.00773, 0.489], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.268, medians=[0.716, 0.00882, 0.572], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.301, medians=[0.759, 0.00998, 0.678], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.329, medians=[0.802, 0.01122, 0.799], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.355, medians=[0.840, 0.01234, 0.922], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.378, medians=[0.871, 0.01346, 1.034], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.396, medians=[0.896, 0.01449, 1.130], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.412, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.427, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.438, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.448, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.458, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.467, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.474, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.480, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.484, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.489, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.494, medians=[0.917, 0.01550, 1.219], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 20 chain 1, k=30: ok in 65.23s
# [ Info: All k (1..30) finished for dataset 20. Total time 1938.88s -> output dir: output
