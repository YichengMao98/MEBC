# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 9
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.383, medians=[0.786, 0.00970, 0.463], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.8s, rate=0.352, medians=[0.770, 0.01312, 0.557], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=12.1s, rate=0.371, medians=[0.812, 0.01520, 0.680], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.5s, rate=0.398, medians=[0.869, 0.01676, 0.832], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.9s, rate=0.427, medians=[0.923, 0.01805, 0.997], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=22.2s, rate=0.448, medians=[0.966, 0.01921, 1.151], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=25.6s, rate=0.469, medians=[1.000, 0.02029, 1.293], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.9s, rate=0.483, medians=[1.027, 0.02118, 1.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=32.2s, rate=0.497, medians=[1.049, 0.02194, 1.522], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=35.5s, rate=0.506, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=38.8s, rate=0.517, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=42.0s, rate=0.527, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=45.3s, rate=0.534, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=48.6s, rate=0.539, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=51.9s, rate=0.544, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=55.2s, rate=0.549, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=58.5s, rate=0.553, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=61.7s, rate=0.557, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=65.0s, rate=0.561, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=68.3s, rate=0.564, medians=[1.067, 0.02262, 1.617], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=1: ok in 72.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.347, medians=[0.663, 0.00908, 0.354], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.297, medians=[0.661, 0.01180, 0.430], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.318, medians=[0.715, 0.01306, 0.529], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.2s, rate=0.344, medians=[0.776, 0.01405, 0.642], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.6s, rate=0.370, medians=[0.837, 0.01491, 0.772], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.9s, rate=0.397, medians=[0.891, 0.01585, 0.917], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.3s, rate=0.423, medians=[0.935, 0.01676, 1.056], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.446, medians=[0.972, 0.01751, 1.179], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.460, medians=[1.002, 0.01811, 1.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.474, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.487, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.8s, rate=0.497, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.1s, rate=0.508, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.4s, rate=0.516, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.6s, rate=0.524, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.9s, rate=0.531, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.2s, rate=0.536, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.5s, rate=0.541, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.8s, rate=0.547, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.0s, rate=0.551, medians=[1.028, 0.01856, 1.392], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=2: ok in 66.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.324, medians=[0.667, 0.00897, 0.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.281, medians=[0.695, 0.01089, 0.465], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.307, medians=[0.751, 0.01194, 0.560], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.2s, rate=0.337, medians=[0.814, 0.01281, 0.674], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.6s, rate=0.370, medians=[0.874, 0.01364, 0.806], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.9s, rate=0.400, medians=[0.928, 0.01439, 0.945], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.3s, rate=0.424, medians=[0.973, 0.01507, 1.084], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.443, medians=[1.008, 0.01571, 1.204], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.461, medians=[1.038, 0.01625, 1.316], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.475, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.486, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.8s, rate=0.498, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.0s, rate=0.508, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.3s, rate=0.516, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.6s, rate=0.522, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.9s, rate=0.529, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.1s, rate=0.533, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.4s, rate=0.537, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.7s, rate=0.541, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.0s, rate=0.544, medians=[1.063, 0.01671, 1.415], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=3: ok in 66.04s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.330, medians=[0.816, 0.00845, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.320, medians=[0.824, 0.01002, 0.554], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.9s, rate=0.332, medians=[0.862, 0.01099, 0.644], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.2s, rate=0.357, medians=[0.909, 0.01180, 0.749], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.6s, rate=0.389, medians=[0.955, 0.01257, 0.869], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=20.0s, rate=0.408, medians=[0.997, 0.01327, 0.992], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.3s, rate=0.426, medians=[1.034, 0.01384, 1.111], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.447, medians=[1.066, 0.01435, 1.232], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.459, medians=[1.092, 0.01480, 1.338], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.473, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.6s, rate=0.483, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.9s, rate=0.493, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.2s, rate=0.503, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.510, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.8s, rate=0.516, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.1s, rate=0.523, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.4s, rate=0.526, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.7s, rate=0.530, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.0s, rate=0.534, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.3s, rate=0.538, medians=[1.113, 0.01518, 1.425], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=4: ok in 66.33s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.276, medians=[0.717, 0.00728, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.237, medians=[0.731, 0.00818, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.246, medians=[0.771, 0.00877, 0.471], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.267, medians=[0.814, 0.00936, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.292, medians=[0.854, 0.00993, 0.620], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.314, medians=[0.892, 0.01056, 0.704], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.339, medians=[0.930, 0.01113, 0.794], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.364, medians=[0.966, 0.01168, 0.891], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.384, medians=[0.997, 0.01216, 0.984], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.3s, rate=0.402, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.6s, rate=0.419, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.0s, rate=0.431, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.3s, rate=0.443, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.6s, rate=0.453, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.0s, rate=0.462, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.3s, rate=0.470, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.6s, rate=0.476, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.0s, rate=0.482, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.3s, rate=0.488, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.6s, rate=0.494, medians=[1.025, 0.01256, 1.071], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=5: ok in 66.63s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.249, medians=[0.769, 0.00691, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.241, medians=[0.784, 0.00764, 0.438], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.257, medians=[0.816, 0.00817, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.278, medians=[0.850, 0.00864, 0.555], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.302, medians=[0.883, 0.00911, 0.618], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.324, medians=[0.916, 0.00962, 0.689], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.345, medians=[0.947, 0.01009, 0.763], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.362, medians=[0.977, 0.01050, 0.835], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.383, medians=[1.002, 0.01093, 0.908], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.3s, rate=0.396, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.6s, rate=0.412, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.0s, rate=0.422, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.3s, rate=0.431, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.7s, rate=0.441, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.0s, rate=0.448, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.4s, rate=0.456, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.7s, rate=0.462, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.1s, rate=0.469, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.4s, rate=0.476, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.7s, rate=0.481, medians=[1.025, 0.01127, 0.972], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=6: ok in 66.77s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.264, medians=[0.824, 0.00708, 0.457], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.259, medians=[0.849, 0.00763, 0.510], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.270, medians=[0.876, 0.00804, 0.560], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.2s, rate=0.291, medians=[0.900, 0.00842, 0.606], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.305, medians=[0.923, 0.00880, 0.655], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.9s, rate=0.324, medians=[0.948, 0.00917, 0.710], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.343, medians=[0.973, 0.00954, 0.768], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.360, medians=[0.996, 0.00989, 0.827], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=30.0s, rate=0.378, medians=[1.017, 0.01021, 0.884], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.3s, rate=0.390, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.7s, rate=0.402, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.1s, rate=0.413, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.4s, rate=0.424, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.8s, rate=0.432, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.1s, rate=0.441, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.5s, rate=0.447, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.9s, rate=0.453, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.2s, rate=0.459, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.6s, rate=0.465, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.9s, rate=0.468, medians=[1.037, 0.01048, 0.936], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=7: ok in 66.94s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.248, medians=[0.802, 0.00642, 0.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.241, medians=[0.832, 0.00687, 0.468], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.247, medians=[0.855, 0.00720, 0.506], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.260, medians=[0.876, 0.00750, 0.544], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.275, medians=[0.898, 0.00778, 0.582], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.289, medians=[0.917, 0.00805, 0.620], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.1s, rate=0.306, medians=[0.935, 0.00829, 0.656], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.5s, rate=0.318, medians=[0.952, 0.00851, 0.690], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.329, medians=[0.967, 0.00873, 0.724], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.340, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.6s, rate=0.348, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.0s, rate=0.357, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.3s, rate=0.368, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.7s, rate=0.379, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.1s, rate=0.385, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.4s, rate=0.392, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.8s, rate=0.399, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.2s, rate=0.404, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.5s, rate=0.409, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.9s, rate=0.413, medians=[0.982, 0.00893, 0.757], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=8: ok in 66.91s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.185, medians=[0.700, 0.00529, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.166, medians=[0.740, 0.00551, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.168, medians=[0.764, 0.00572, 0.357], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.177, medians=[0.785, 0.00593, 0.384], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.192, medians=[0.805, 0.00614, 0.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.206, medians=[0.824, 0.00637, 0.443], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.213, medians=[0.840, 0.00657, 0.470], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.224, medians=[0.855, 0.00675, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.234, medians=[0.868, 0.00694, 0.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.241, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.252, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.5s, rate=0.261, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.8s, rate=0.270, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.2s, rate=0.279, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.6s, rate=0.285, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.9s, rate=0.294, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.3s, rate=0.300, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.7s, rate=0.308, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.0s, rate=0.313, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.4s, rate=0.320, medians=[0.881, 0.00711, 0.542], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=9: ok in 66.42s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.181, medians=[0.798, 0.00506, 0.336], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.168, medians=[0.803, 0.00531, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.171, medians=[0.812, 0.00552, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.176, medians=[0.827, 0.00570, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.184, medians=[0.839, 0.00588, 0.427], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.196, medians=[0.850, 0.00604, 0.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.207, medians=[0.860, 0.00619, 0.466], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.215, medians=[0.869, 0.00633, 0.484], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.220, medians=[0.878, 0.00645, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.225, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.231, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.239, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.246, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.253, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.3s, rate=0.258, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.6s, rate=0.264, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.0s, rate=0.271, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.4s, rate=0.274, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.7s, rate=0.278, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.1s, rate=0.283, medians=[0.886, 0.00657, 0.516], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=10: ok in 66.12s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.228, medians=[0.849, 0.00562, 0.433], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.215, medians=[0.856, 0.00579, 0.449], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.226, medians=[0.865, 0.00590, 0.463], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.225, medians=[0.872, 0.00600, 0.475], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.228, medians=[0.879, 0.00609, 0.488], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.224, medians=[0.885, 0.00617, 0.498], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.228, medians=[0.890, 0.00625, 0.508], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.228, medians=[0.894, 0.00632, 0.518], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.232, medians=[0.898, 0.00640, 0.526], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.235, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.240, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.243, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.246, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.248, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.250, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.252, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.254, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.257, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.258, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.260, medians=[0.902, 0.00646, 0.534], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=11: ok in 65.45s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.135, medians=[0.801, 0.00460, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.125, medians=[0.805, 0.00474, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.128, medians=[0.810, 0.00483, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.136, medians=[0.815, 0.00489, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.140, medians=[0.820, 0.00496, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.143, medians=[0.824, 0.00502, 0.375], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.147, medians=[0.828, 0.00508, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.149, medians=[0.831, 0.00513, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.153, medians=[0.834, 0.00518, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.154, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.157, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.159, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.162, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.164, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.166, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.168, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.171, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.172, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.175, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.175, medians=[0.837, 0.00523, 0.401], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=12: ok in 65.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.124, medians=[0.825, 0.00495, 0.382], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.126, medians=[0.826, 0.00500, 0.387], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.134, medians=[0.827, 0.00503, 0.390], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.139, medians=[0.829, 0.00505, 0.393], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.147, medians=[0.832, 0.00507, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.149, medians=[0.834, 0.00508, 0.399], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.151, medians=[0.836, 0.00509, 0.401], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.153, medians=[0.837, 0.00511, 0.403], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.155, medians=[0.837, 0.00512, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.157, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.155, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.156, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.157, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.159, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.161, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.162, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.162, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.161, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.162, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.163, medians=[0.838, 0.00513, 0.406], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=13: ok in 65.09s
# [ Info: [sliding] iter 1000/20000 elapsed=3.3s, rate=0.151, medians=[0.815, 0.00428, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.139, medians=[0.805, 0.00433, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.129, medians=[0.804, 0.00436, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.126, medians=[0.803, 0.00439, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.123, medians=[0.803, 0.00440, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.120, medians=[0.801, 0.00441, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.118, medians=[0.801, 0.00441, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.116, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.115, medians=[0.800, 0.00441, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.116, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.114, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.113, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.114, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.115, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.116, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.117, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.118, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.118, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.118, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.0s, rate=0.118, medians=[0.800, 0.00442, 0.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=14: ok in 65.03s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.099, medians=[0.772, 0.00415, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.092, medians=[0.774, 0.00412, 0.300], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.085, medians=[0.775, 0.00410, 0.299], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.087, medians=[0.777, 0.00408, 0.298], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.086, medians=[0.776, 0.00407, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.087, medians=[0.775, 0.00407, 0.296], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.084, medians=[0.775, 0.00406, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.083, medians=[0.774, 0.00405, 0.293], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.083, medians=[0.773, 0.00404, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.084, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.082, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.082, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.083, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.084, medians=[0.773, 0.00403, 0.291], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=15: ok in 64.88s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.166, medians=[0.752, 0.00448, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.136, medians=[0.766, 0.00438, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.121, medians=[0.770, 0.00432, 0.325], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.116, medians=[0.771, 0.00427, 0.321], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.106, medians=[0.770, 0.00421, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.103, medians=[0.769, 0.00416, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.102, medians=[0.768, 0.00412, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.101, medians=[0.767, 0.00408, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.096, medians=[0.766, 0.00404, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.093, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.091, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.089, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.089, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.088, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.086, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.085, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.083, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.082, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.081, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.080, medians=[0.765, 0.00401, 0.294], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=16: ok in 64.82s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.127, medians=[0.781, 0.00446, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.120, medians=[0.779, 0.00438, 0.342], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.122, medians=[0.776, 0.00433, 0.336], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.117, medians=[0.774, 0.00427, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.114, medians=[0.771, 0.00422, 0.323], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.109, medians=[0.769, 0.00417, 0.317], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.106, medians=[0.766, 0.00412, 0.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.103, medians=[0.763, 0.00408, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.097, medians=[0.761, 0.00403, 0.301], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.095, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.091, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.087, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.085, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.082, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.080, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.079, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.077, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.075, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.073, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.071, medians=[0.758, 0.00398, 0.295], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=17: ok in 64.78s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.168, medians=[0.781, 0.00430, 0.340], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.142, medians=[0.766, 0.00428, 0.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.135, medians=[0.759, 0.00423, 0.323], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.123, medians=[0.755, 0.00417, 0.315], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.114, medians=[0.753, 0.00411, 0.309], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.107, medians=[0.750, 0.00405, 0.302], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.101, medians=[0.747, 0.00399, 0.295], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.096, medians=[0.744, 0.00393, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.091, medians=[0.741, 0.00387, 0.281], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.089, medians=[0.739, 0.00381, 0.275], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.086, medians=[0.739, 0.00381, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.8s, rate=0.083, medians=[0.739, 0.00381, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.079, medians=[0.739, 0.00381, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.268, medians=[0.733, 0.00885, 0.564], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.295, medians=[0.763, 0.00993, 0.646], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.321, medians=[0.798, 0.01104, 0.745], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.346, medians=[0.833, 0.01210, 0.853], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.5s, rate=0.367, medians=[0.862, 0.01327, 0.959], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.385, medians=[0.890, 0.01430, 1.068], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.403, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.418, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.9s, rate=0.432, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.2s, rate=0.446, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.458, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.8s, rate=0.466, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.1s, rate=0.474, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.4s, rate=0.480, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.7s, rate=0.486, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.0s, rate=0.492, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.3s, rate=0.495, medians=[0.911, 0.01535, 1.162], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=25: ok in 66.37s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.215, medians=[0.666, 0.00564, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.221, medians=[0.661, 0.00662, 0.411], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.237, medians=[0.681, 0.00756, 0.469], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.261, medians=[0.711, 0.00872, 0.547], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.289, medians=[0.750, 0.00999, 0.644], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.320, medians=[0.789, 0.01129, 0.756], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.1s, rate=0.346, medians=[0.828, 0.01257, 0.884], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.5s, rate=0.375, medians=[0.862, 0.01377, 1.008], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.8s, rate=0.397, medians=[0.890, 0.01485, 1.117], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.1s, rate=0.413, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.428, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.8s, rate=0.440, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.1s, rate=0.452, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.4s, rate=0.462, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.7s, rate=0.469, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.1s, rate=0.477, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.4s, rate=0.483, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.7s, rate=0.489, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.0s, rate=0.494, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.3s, rate=0.498, medians=[0.912, 0.01584, 1.210], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=26: ok in 66.32s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.225, medians=[0.642, 0.00641, 0.398], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.229, medians=[0.662, 0.00741, 0.454], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.259, medians=[0.695, 0.00851, 0.528], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.284, medians=[0.734, 0.00974, 0.620], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.321, medians=[0.779, 0.01109, 0.737], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.9s, rate=0.355, medians=[0.823, 0.01258, 0.873], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.384, medians=[0.860, 0.01399, 1.006], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.407, medians=[0.891, 0.01520, 1.128], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.425, medians=[0.916, 0.01640, 1.236], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.442, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.456, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.8s, rate=0.466, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.2s, rate=0.475, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.484, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.8s, rate=0.491, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.1s, rate=0.498, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.4s, rate=0.502, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.7s, rate=0.508, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.0s, rate=0.511, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.3s, rate=0.515, medians=[0.936, 0.01757, 1.331], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=27: ok in 66.31s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.238, medians=[0.659, 0.00584, 0.375], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.228, medians=[0.661, 0.00691, 0.427], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.242, medians=[0.686, 0.00796, 0.493], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.274, medians=[0.719, 0.00911, 0.574], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.303, medians=[0.757, 0.01028, 0.668], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.8s, rate=0.328, medians=[0.794, 0.01157, 0.774], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.358, medians=[0.829, 0.01297, 0.890], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.5s, rate=0.380, medians=[0.858, 0.01434, 0.997], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.401, medians=[0.883, 0.01563, 1.102], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.421, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.6s, rate=0.436, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.9s, rate=0.447, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.2s, rate=0.460, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.471, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.8s, rate=0.477, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.1s, rate=0.483, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.5s, rate=0.489, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.8s, rate=0.496, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.1s, rate=0.500, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.4s, rate=0.504, medians=[0.905, 0.01674, 1.194], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=28: ok in 66.44s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.224, medians=[0.638, 0.00645, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.236, medians=[0.662, 0.00745, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.263, medians=[0.694, 0.00857, 0.532], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.289, medians=[0.732, 0.00985, 0.621], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.5s, rate=0.314, medians=[0.774, 0.01117, 0.732], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.9s, rate=0.342, medians=[0.814, 0.01268, 0.852], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.2s, rate=0.373, medians=[0.850, 0.01405, 0.979], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.6s, rate=0.393, medians=[0.879, 0.01530, 1.090], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.9s, rate=0.410, medians=[0.904, 0.01641, 1.194], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.2s, rate=0.425, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.440, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.9s, rate=0.449, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.2s, rate=0.458, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.465, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.9s, rate=0.474, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.2s, rate=0.479, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.5s, rate=0.485, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.8s, rate=0.490, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.2s, rate=0.494, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.5s, rate=0.500, medians=[0.925, 0.01734, 1.282], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=29: ok in 66.49s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.175, medians=[0.606, 0.00555, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.181, medians=[0.621, 0.00635, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.205, medians=[0.647, 0.00720, 0.438], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.232, medians=[0.681, 0.00804, 0.504], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.266, medians=[0.718, 0.00909, 0.589], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.7s, rate=0.301, medians=[0.757, 0.01036, 0.690], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.1s, rate=0.330, medians=[0.795, 0.01158, 0.802], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.5s, rate=0.356, medians=[0.830, 0.01263, 0.915], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.8s, rate=0.376, medians=[0.859, 0.01371, 1.021], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=33.1s, rate=0.394, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.5s, rate=0.409, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.8s, rate=0.424, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=43.1s, rate=0.436, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.5s, rate=0.445, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.8s, rate=0.453, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.2s, rate=0.461, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.5s, rate=0.466, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.8s, rate=0.472, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.2s, rate=0.476, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.5s, rate=0.481, medians=[0.884, 0.01473, 1.118], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 09 chain 1, k=30: ok in 66.51s
# [ Info: All k (1..30) finished for dataset 09. Total time 1983.06s -> output dir: output
