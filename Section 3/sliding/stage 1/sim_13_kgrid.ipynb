# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 13
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.360, medians=[0.695, 0.00890, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.6s, rate=0.323, medians=[0.684, 0.01217, 0.450], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.9s, rate=0.341, medians=[0.731, 0.01428, 0.563], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.2s, rate=0.377, medians=[0.799, 0.01569, 0.712], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.5s, rate=0.411, medians=[0.867, 0.01685, 0.887], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.7s, rate=0.442, medians=[0.924, 0.01796, 1.071], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=24.9s, rate=0.464, medians=[0.967, 0.01898, 1.231], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.2s, rate=0.483, medians=[1.002, 0.01978, 1.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.3s, rate=0.501, medians=[1.029, 0.02051, 1.493], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.5s, rate=0.513, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=37.7s, rate=0.525, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=40.9s, rate=0.534, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.1s, rate=0.541, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.3s, rate=0.546, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.5s, rate=0.551, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=53.7s, rate=0.554, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.9s, rate=0.557, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.1s, rate=0.561, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.3s, rate=0.564, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=66.4s, rate=0.567, medians=[1.052, 0.02102, 1.593], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=1: ok in 70.45s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.369, medians=[0.698, 0.00943, 0.427], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.341, medians=[0.727, 0.01186, 0.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.360, medians=[0.778, 0.01351, 0.627], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.389, medians=[0.844, 0.01457, 0.764], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.413, medians=[0.903, 0.01556, 0.915], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.443, medians=[0.953, 0.01653, 1.072], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.467, medians=[0.993, 0.01756, 1.226], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.486, medians=[1.026, 0.01832, 1.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.502, medians=[1.053, 0.01898, 1.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.515, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.527, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.7s, rate=0.537, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.8s, rate=0.544, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.0s, rate=0.549, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.2s, rate=0.554, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.4s, rate=0.559, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.6s, rate=0.565, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.8s, rate=0.570, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.574, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.1s, rate=0.577, medians=[1.076, 0.01945, 1.604], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=2: ok in 64.14s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.364, medians=[0.771, 0.00923, 0.481], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.335, medians=[0.802, 0.01097, 0.574], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.361, medians=[0.849, 0.01218, 0.679], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.388, medians=[0.909, 0.01305, 0.809], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.417, medians=[0.962, 0.01397, 0.955], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.446, medians=[1.009, 0.01477, 1.113], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.467, medians=[1.047, 0.01543, 1.254], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.486, medians=[1.078, 0.01601, 1.385], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.502, medians=[1.105, 0.01649, 1.512], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.515, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.5s, rate=0.525, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.7s, rate=0.536, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.9s, rate=0.543, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.0s, rate=0.549, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.2s, rate=0.554, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.4s, rate=0.558, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.6s, rate=0.561, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.8s, rate=0.563, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.1s, rate=0.566, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.3s, rate=0.570, medians=[1.126, 0.01691, 1.619], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=3: ok in 64.28s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.325, medians=[0.837, 0.00902, 0.525], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.337, medians=[0.862, 0.01037, 0.616], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.366, medians=[0.903, 0.01136, 0.715], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.401, medians=[0.948, 0.01216, 0.826], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.426, medians=[0.991, 0.01282, 0.939], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.445, medians=[1.027, 0.01344, 1.047], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.463, medians=[1.058, 0.01394, 1.153], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.478, medians=[1.087, 0.01430, 1.251], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.493, medians=[1.110, 0.01466, 1.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.503, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.513, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.524, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.531, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.537, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.542, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.546, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.550, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.554, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.4s, rate=0.556, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.6s, rate=0.560, medians=[1.131, 0.01497, 1.431], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=4: ok in 64.61s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.278, medians=[0.717, 0.00804, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.268, medians=[0.768, 0.00873, 0.476], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.288, medians=[0.812, 0.00934, 0.546], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.311, medians=[0.854, 0.00993, 0.621], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.339, medians=[0.899, 0.01046, 0.707], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.362, medians=[0.940, 0.01103, 0.801], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.391, medians=[0.976, 0.01156, 0.895], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.410, medians=[1.007, 0.01205, 0.982], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.432, medians=[1.035, 0.01244, 1.066], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.445, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.460, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.469, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.3s, rate=0.482, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.492, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.499, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.506, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.513, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.518, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.7s, rate=0.522, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.9s, rate=0.526, medians=[1.060, 0.01277, 1.149], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=5: ok in 64.92s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.269, medians=[0.813, 0.00734, 0.443], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.268, medians=[0.835, 0.00797, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.285, medians=[0.869, 0.00845, 0.562], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.303, medians=[0.900, 0.00895, 0.624], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.321, medians=[0.931, 0.00944, 0.691], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.347, medians=[0.961, 0.00986, 0.759], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.367, medians=[0.988, 0.01027, 0.825], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.387, medians=[1.013, 0.01067, 0.894], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.406, medians=[1.038, 0.01103, 0.966], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.420, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.434, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.444, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.455, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.6s, rate=0.463, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.470, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.477, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.483, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.491, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.496, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.501, medians=[1.059, 0.01136, 1.033], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=6: ok in 65.14s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.276, medians=[0.799, 0.00696, 0.447], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.269, medians=[0.836, 0.00748, 0.501], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.278, medians=[0.866, 0.00790, 0.550], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.301, medians=[0.895, 0.00828, 0.601], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.320, medians=[0.922, 0.00865, 0.654], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.336, medians=[0.949, 0.00900, 0.708], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.351, medians=[0.972, 0.00936, 0.764], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.366, medians=[0.995, 0.00969, 0.820], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.382, medians=[1.017, 0.00997, 0.875], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.395, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.407, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.416, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.425, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.434, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.442, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.448, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.454, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.462, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.467, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.471, medians=[1.036, 0.01026, 0.927], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=7: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.187, medians=[0.756, 0.00585, 0.350], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.194, medians=[0.787, 0.00621, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.214, medians=[0.811, 0.00650, 0.428], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.225, medians=[0.832, 0.00676, 0.461], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.238, medians=[0.853, 0.00701, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.1s, rate=0.251, medians=[0.872, 0.00726, 0.529], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.269, medians=[0.893, 0.00752, 0.567], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.7s, rate=0.283, medians=[0.912, 0.00778, 0.605], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.0s, rate=0.300, medians=[0.929, 0.00802, 0.641], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.3s, rate=0.308, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.318, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.326, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.336, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.346, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.355, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.0s, rate=0.361, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.3s, rate=0.370, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.377, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.384, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.390, medians=[0.945, 0.00823, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=8: ok in 65.22s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.242, medians=[0.875, 0.00605, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.232, medians=[0.882, 0.00639, 0.485], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.251, medians=[0.894, 0.00664, 0.513], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.263, medians=[0.907, 0.00685, 0.540], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.272, medians=[0.921, 0.00707, 0.569], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.282, medians=[0.934, 0.00727, 0.598], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.5s, rate=0.290, medians=[0.946, 0.00745, 0.624], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.8s, rate=0.299, medians=[0.957, 0.00762, 0.648], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.1s, rate=0.304, medians=[0.967, 0.00778, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.312, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.316, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.0s, rate=0.324, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.332, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.5s, rate=0.339, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.8s, rate=0.345, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.350, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.356, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.7s, rate=0.361, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.364, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.3s, rate=0.367, medians=[0.977, 0.00791, 0.693], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=9: ok in 65.34s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.212, medians=[0.865, 0.00577, 0.439], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.204, medians=[0.871, 0.00596, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.210, medians=[0.879, 0.00611, 0.477], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.216, medians=[0.889, 0.00625, 0.496], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.233, medians=[0.896, 0.00638, 0.512], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.237, medians=[0.904, 0.00649, 0.528], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.247, medians=[0.911, 0.00660, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.253, medians=[0.918, 0.00670, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.6s, rate=0.258, medians=[0.925, 0.00679, 0.570], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.9s, rate=0.262, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.269, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.5s, rate=0.277, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.8s, rate=0.282, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.1s, rate=0.285, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.3s, rate=0.290, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.6s, rate=0.295, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.9s, rate=0.300, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.2s, rate=0.304, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.308, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.311, medians=[0.932, 0.00689, 0.584], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=10: ok in 64.83s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.180, medians=[0.813, 0.00502, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.155, medians=[0.826, 0.00513, 0.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.160, medians=[0.834, 0.00525, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.167, medians=[0.843, 0.00535, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.169, medians=[0.850, 0.00546, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.176, medians=[0.857, 0.00555, 0.432], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.184, medians=[0.864, 0.00563, 0.443], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.191, medians=[0.869, 0.00571, 0.454], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.197, medians=[0.874, 0.00579, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.201, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.206, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.213, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.218, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.223, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.227, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.229, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.231, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.234, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.237, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.239, medians=[0.879, 0.00585, 0.473], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=11: ok in 63.43s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.190, medians=[0.778, 0.00475, 0.336], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.157, medians=[0.801, 0.00478, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.155, medians=[0.810, 0.00484, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.155, medians=[0.819, 0.00491, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.161, medians=[0.827, 0.00497, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.165, medians=[0.831, 0.00504, 0.388], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.166, medians=[0.837, 0.00510, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.167, medians=[0.841, 0.00514, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.168, medians=[0.844, 0.00519, 0.408], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.171, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.175, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.179, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.179, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.181, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.181, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.182, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.184, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.184, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.185, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.186, medians=[0.847, 0.00522, 0.413], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=12: ok in 63.40s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.121, medians=[0.837, 0.00447, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.128, medians=[0.831, 0.00453, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.131, medians=[0.830, 0.00458, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.133, medians=[0.830, 0.00463, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.131, medians=[0.831, 0.00466, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.131, medians=[0.832, 0.00467, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.131, medians=[0.833, 0.00469, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.134, medians=[0.834, 0.00471, 0.370], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.136, medians=[0.835, 0.00472, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.136, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.134, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.135, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.136, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.138, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.139, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.139, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.140, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.141, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.142, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.142, medians=[0.835, 0.00473, 0.373], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=13: ok in 63.43s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.173, medians=[0.815, 0.00481, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.151, medians=[0.825, 0.00474, 0.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.138, medians=[0.825, 0.00471, 0.378], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.140, medians=[0.825, 0.00469, 0.376], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.139, medians=[0.825, 0.00467, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.139, medians=[0.824, 0.00465, 0.371], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.136, medians=[0.824, 0.00462, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.134, medians=[0.823, 0.00460, 0.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.133, medians=[0.821, 0.00458, 0.363], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.130, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.8s, rate=0.127, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.125, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.124, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.3s, rate=0.123, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.5s, rate=0.123, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.122, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.8s, rate=0.122, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.0s, rate=0.120, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.2s, rate=0.120, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.3s, rate=0.120, medians=[0.820, 0.00456, 0.361], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=14: ok in 63.37s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.112, medians=[0.745, 0.00387, 0.266], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.099, medians=[0.757, 0.00381, 0.266], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.092, medians=[0.763, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.088, medians=[0.766, 0.00377, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.081, medians=[0.767, 0.00377, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.079, medians=[0.768, 0.00376, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.079, medians=[0.769, 0.00376, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.078, medians=[0.769, 0.00376, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.077, medians=[0.769, 0.00375, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.077, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.077, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.076, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.077, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.077, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.076, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.076, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.075, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.076, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.076, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.075, medians=[0.770, 0.00374, 0.266], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=15: ok in 63.46s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.159, medians=[0.812, 0.00407, 0.326], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.127, medians=[0.795, 0.00403, 0.314], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.110, medians=[0.789, 0.00398, 0.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.106, medians=[0.784, 0.00393, 0.299], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.101, medians=[0.780, 0.00389, 0.294], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.101, medians=[0.778, 0.00386, 0.290], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.096, medians=[0.777, 0.00383, 0.286], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.091, medians=[0.775, 0.00380, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.088, medians=[0.774, 0.00377, 0.278], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.087, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.086, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.084, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.082, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.080, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.077, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.077, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.075, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.075, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.074, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.073, medians=[0.772, 0.00374, 0.275], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=16: ok in 63.47s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.115, medians=[0.784, 0.00422, 0.334], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.106, medians=[0.777, 0.00415, 0.324], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.103, medians=[0.773, 0.00410, 0.317], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.102, medians=[0.770, 0.00404, 0.310], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.8s, rate=0.100, medians=[0.767, 0.00399, 0.303], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.098, medians=[0.765, 0.00393, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.091, medians=[0.763, 0.00388, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.3s, rate=0.087, medians=[0.761, 0.00383, 0.286], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.084, medians=[0.759, 0.00378, 0.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.083, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.081, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.0s, rate=0.078, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.077, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.4s, rate=0.075, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=47.6s, rate=0.073, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=50.7s, rate=0.071, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=53.9s, rate=0.069, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.1s, rate=0.067, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.3s, rate=0.066, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=63.4s, rate=0.064, medians=[0.757, 0.00373, 0.274], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=17: ok in 63.45s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.126, medians=[0.715, 0.00352, 0.237], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.092, medians=[0.719, 0.00339, 0.227], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.080, medians=[0.719, 0.00332, 0.220], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.071, medians=[0.717, 0.00326, 0.214], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=15.9s, rate=0.065, medians=[0.716, 0.00321, 0.209], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.0s, rate=0.060, medians=[0.715, 0.00317, 0.205], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.2s, rate=0.057, medians=[0.714, 0.00313, 0.201], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.4s, rate=0.054, medians=[0.713, 0.00310, 0.198], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.5s, rate=0.052, medians=[0.713, 0.00307, 0.195], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=31.7s, rate=0.050, medians=[0.712, 0.00304, 0.191], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=34.9s, rate=0.048, medians=[0.712, 0.00304, 0.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.1s, rate=0.046, medians=[0.712, 0.00304, 0.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.2s, rate=0.044, medians=[0.712, 0.00304, 0.191], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.7s, rate=0.247, medians=[0.690, 0.00794, 0.496], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.283, medians=[0.723, 0.00915, 0.581], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.314, medians=[0.761, 0.01055, 0.687], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.336, medians=[0.797, 0.01200, 0.804], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.361, medians=[0.830, 0.01328, 0.917], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.383, medians=[0.859, 0.01452, 1.030], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.401, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.415, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.428, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.440, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.449, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.457, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.468, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.477, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.483, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.490, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.495, medians=[0.884, 0.01569, 1.136], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=25: ok in 64.76s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.247, medians=[0.677, 0.00537, 0.359], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.230, medians=[0.660, 0.00647, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.250, medians=[0.676, 0.00758, 0.466], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.273, medians=[0.705, 0.00876, 0.542], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.300, medians=[0.740, 0.00994, 0.632], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.331, medians=[0.775, 0.01133, 0.733], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.355, medians=[0.810, 0.01274, 0.847], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.379, medians=[0.842, 0.01405, 0.963], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.405, medians=[0.869, 0.01528, 1.067], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.423, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.439, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.451, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.461, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.470, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.480, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.485, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.492, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.497, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.502, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.507, medians=[0.893, 0.01642, 1.172], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=26: ok in 64.73s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.219, medians=[0.656, 0.00580, 0.373], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.220, medians=[0.652, 0.00703, 0.425], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.246, medians=[0.677, 0.00819, 0.495], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.274, medians=[0.715, 0.00953, 0.588], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.307, medians=[0.758, 0.01077, 0.697], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.339, medians=[0.800, 0.01210, 0.821], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.370, medians=[0.838, 0.01346, 0.949], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.392, medians=[0.870, 0.01475, 1.075], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.410, medians=[0.896, 0.01598, 1.183], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.427, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.440, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.452, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.461, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.472, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.479, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.485, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.492, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.497, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.501, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.507, medians=[0.917, 0.01718, 1.280], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=27: ok in 64.79s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.232, medians=[0.630, 0.00640, 0.390], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.237, medians=[0.646, 0.00769, 0.453], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.259, medians=[0.676, 0.00891, 0.525], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.281, medians=[0.713, 0.01014, 0.612], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.314, medians=[0.756, 0.01157, 0.724], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.342, medians=[0.800, 0.01304, 0.855], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.373, medians=[0.838, 0.01451, 0.987], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.394, medians=[0.870, 0.01578, 1.111], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.415, medians=[0.896, 0.01695, 1.218], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.430, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.444, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.453, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.462, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.472, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.480, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.486, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.493, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.499, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.503, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.508, medians=[0.917, 0.01798, 1.312], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=28: ok in 64.76s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.228, medians=[0.629, 0.00648, 0.397], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.246, medians=[0.647, 0.00774, 0.460], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.263, medians=[0.680, 0.00886, 0.533], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.299, medians=[0.720, 0.01001, 0.623], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.328, medians=[0.763, 0.01132, 0.733], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.355, medians=[0.803, 0.01278, 0.853], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.381, medians=[0.840, 0.01407, 0.982], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.405, medians=[0.872, 0.01523, 1.101], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.424, medians=[0.898, 0.01636, 1.207], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.5s, rate=0.438, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.7s, rate=0.450, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.462, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.2s, rate=0.472, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.4s, rate=0.480, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.7s, rate=0.488, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.493, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.1s, rate=0.500, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.4s, rate=0.504, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.6s, rate=0.508, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.8s, rate=0.513, medians=[0.919, 0.01743, 1.306], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=29: ok in 64.87s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.237, medians=[0.689, 0.00514, 0.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.3s, rate=0.227, medians=[0.665, 0.00635, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.5s, rate=0.248, medians=[0.679, 0.00758, 0.472], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.272, medians=[0.709, 0.00885, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.310, medians=[0.753, 0.01012, 0.670], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.342, medians=[0.795, 0.01160, 0.798], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.371, medians=[0.834, 0.01304, 0.937], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.394, medians=[0.866, 0.01451, 1.065], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.416, medians=[0.891, 0.01579, 1.170], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.4s, rate=0.434, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.6s, rate=0.449, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.9s, rate=0.461, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.1s, rate=0.472, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.482, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.487, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.8s, rate=0.493, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.0s, rate=0.498, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.3s, rate=0.501, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.5s, rate=0.505, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.7s, rate=0.508, medians=[0.912, 0.01697, 1.265], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 13 chain 1, k=30: ok in 64.76s
# [ Info: All k (1..30) finished for dataset 13. Total time 1936.57s -> output dir: output
