# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots

const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter_per_k = 20000
const KMAX_UPPER    = 30

include("functions.jl")

Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = String[]
if model_tag_sym === :memoryless
    header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    header_cont = ["beta", "alpha", "gamma"]
end

i = 12
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

t_all = Dates.now()
for k in 1:KMAX_UPPER
    Random.seed!(2025 + i*100 + c*10_000 + k)
    initθ_chain = initθ_for_chain(model_tag_sym)

    t0 = Dates.now()
    try
        samples, loglik_aug_vecs =
            mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
                fit_mech      = model_tag_sym,
                n_iter        = n_iter_per_k,
                initθ         = initθ_chain,
                KMAX_UPPER    = KMAX_UPPER,
                k_max_fixed   = k)

        if size(samples, 1) == 0
            error("Empty samples returned for k=$k.")
        end

        samples_filename = "samples_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

        loglik_filename = "loglik_sim_$(i)_chain_$(c)_k$(k).csv"
        write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

        el = Dates.value(Dates.now() - t0) / 1000
        @info(@sprintf("Dataset %02d chain %d, k=%d: ok in %.2fs", i, c, k, el))
    catch err
        el = Dates.value(Dates.now() - t0) / 1000
        @warn(@sprintf("Dataset %02d chain %d, k=%d: ERROR - %s after %.2fs", i, c, k, err, el))
        continue
    end
end

el_all = Dates.value(Dates.now() - t_all) / 1000
@info(@sprintf("All k (1..%d) finished for dataset %02d. Total time %.2fs -> output dir: %s",
               KMAX_UPPER, i, el_all, out_dir))
# Out:
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.390, medians=[0.857, 0.01029, 0.565], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=8.5s, rate=0.381, medians=[0.861, 0.01379, 0.693], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=11.8s, rate=0.406, medians=[0.906, 0.01608, 0.844], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=15.1s, rate=0.430, medians=[0.957, 0.01784, 1.019], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=18.4s, rate=0.466, medians=[1.001, 0.01942, 1.199], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=21.7s, rate=0.491, medians=[1.037, 0.02074, 1.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=25.0s, rate=0.508, medians=[1.065, 0.02170, 1.519], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=28.3s, rate=0.520, medians=[1.087, 0.02253, 1.637], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=31.5s, rate=0.529, medians=[1.103, 0.02320, 1.730], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=34.8s, rate=0.538, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=38.0s, rate=0.544, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=41.2s, rate=0.549, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=44.5s, rate=0.556, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=47.7s, rate=0.560, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=50.9s, rate=0.564, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=54.2s, rate=0.568, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=57.4s, rate=0.571, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=60.7s, rate=0.574, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=63.9s, rate=0.577, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=67.1s, rate=0.580, medians=[1.117, 0.02373, 1.812], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=1: ok in 71.10s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.367, medians=[0.763, 0.00980, 0.455], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.5s, rate=0.333, medians=[0.773, 0.01231, 0.554], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.8s, rate=0.357, medians=[0.823, 0.01397, 0.677], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.386, medians=[0.880, 0.01528, 0.816], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.4s, rate=0.416, medians=[0.934, 0.01634, 0.970], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.7s, rate=0.438, medians=[0.982, 0.01722, 1.133], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=23.0s, rate=0.461, medians=[1.020, 0.01799, 1.279], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.480, medians=[1.052, 0.01861, 1.421], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.494, medians=[1.078, 0.01924, 1.548], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.508, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.518, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.528, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.535, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.543, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.9s, rate=0.547, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.1s, rate=0.552, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.4s, rate=0.556, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.6s, rate=0.560, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.9s, rate=0.564, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.568, medians=[1.098, 0.01986, 1.658], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=2: ok in 65.12s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.315, medians=[0.707, 0.00950, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.303, medians=[0.726, 0.01130, 0.490], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.316, medians=[0.780, 0.01228, 0.587], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.340, medians=[0.839, 0.01305, 0.699], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.363, medians=[0.897, 0.01388, 0.832], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.393, medians=[0.947, 0.01469, 0.971], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.422, medians=[0.990, 0.01549, 1.117], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.445, medians=[1.024, 0.01622, 1.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.463, medians=[1.052, 0.01684, 1.366], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.474, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.486, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.496, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.507, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.512, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.519, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.525, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.532, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.537, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.0s, rate=0.540, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.2s, rate=0.545, medians=[1.074, 0.01732, 1.459], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=3: ok in 65.27s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.308, medians=[0.796, 0.00864, 0.463], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.293, medians=[0.809, 0.01007, 0.540], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.321, medians=[0.851, 0.01105, 0.633], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.353, medians=[0.898, 0.01189, 0.735], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.379, medians=[0.941, 0.01269, 0.844], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.403, medians=[0.982, 0.01344, 0.963], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.426, medians=[1.018, 0.01404, 1.079], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.447, medians=[1.049, 0.01454, 1.183], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.466, medians=[1.074, 0.01494, 1.271], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.479, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.491, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.501, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.509, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.9s, rate=0.517, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.524, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.530, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.536, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.539, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.543, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.546, medians=[1.094, 0.01539, 1.356], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=4: ok in 65.47s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.265, medians=[0.657, 0.00801, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.241, medians=[0.705, 0.00868, 0.414], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.264, medians=[0.754, 0.00918, 0.478], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.283, medians=[0.799, 0.00972, 0.548], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.303, medians=[0.843, 0.01028, 0.626], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.330, medians=[0.886, 0.01083, 0.711], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.354, medians=[0.924, 0.01137, 0.798], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.377, medians=[0.957, 0.01184, 0.881], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.395, medians=[0.988, 0.01224, 0.963], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.412, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.428, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.443, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.455, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.0s, rate=0.465, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.3s, rate=0.473, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.6s, rate=0.479, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.488, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.494, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.499, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.505, medians=[1.016, 0.01262, 1.045], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=5: ok in 65.75s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.261, medians=[0.794, 0.00739, 0.427], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.253, medians=[0.818, 0.00808, 0.487], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.273, medians=[0.850, 0.00862, 0.547], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.291, medians=[0.882, 0.00913, 0.610], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.310, medians=[0.913, 0.00964, 0.675], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.335, medians=[0.943, 0.01012, 0.744], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.356, medians=[0.973, 0.01054, 0.815], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.379, medians=[1.002, 0.01096, 0.892], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.398, medians=[1.028, 0.01135, 0.967], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.415, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.426, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.437, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.447, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.0s, rate=0.454, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.3s, rate=0.461, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.6s, rate=0.468, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.9s, rate=0.473, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.2s, rate=0.479, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.5s, rate=0.485, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.8s, rate=0.490, medians=[1.051, 0.01168, 1.039], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=6: ok in 65.79s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.267, medians=[0.814, 0.00724, 0.468], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.258, medians=[0.847, 0.00779, 0.521], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.7s, rate=0.289, medians=[0.877, 0.00819, 0.570], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.0s, rate=0.307, medians=[0.904, 0.00860, 0.621], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.330, medians=[0.930, 0.00896, 0.672], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.347, medians=[0.954, 0.00932, 0.724], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.360, medians=[0.979, 0.00967, 0.781], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.376, medians=[1.002, 0.00997, 0.836], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.389, medians=[1.023, 0.01027, 0.891], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.402, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.413, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.4s, rate=0.425, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.7s, rate=0.434, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.1s, rate=0.442, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.4s, rate=0.448, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.7s, rate=0.455, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.0s, rate=0.461, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.3s, rate=0.466, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.6s, rate=0.471, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.9s, rate=0.473, medians=[1.041, 0.01055, 0.940], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=7: ok in 65.91s
# [ Info: [sliding] iter 1000/20000 elapsed=3.5s, rate=0.183, medians=[0.751, 0.00608, 0.352], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.7s, rate=0.178, medians=[0.784, 0.00637, 0.393], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.9s, rate=0.199, medians=[0.809, 0.00666, 0.430], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=13.1s, rate=0.216, medians=[0.832, 0.00695, 0.466], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.3s, rate=0.230, medians=[0.854, 0.00721, 0.502], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.6s, rate=0.243, medians=[0.874, 0.00748, 0.538], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.9s, rate=0.261, medians=[0.894, 0.00774, 0.574], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.2s, rate=0.270, medians=[0.911, 0.00800, 0.608], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.5s, rate=0.283, medians=[0.926, 0.00822, 0.641], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.8s, rate=0.296, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.1s, rate=0.309, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.5s, rate=0.322, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.8s, rate=0.331, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=46.1s, rate=0.341, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.4s, rate=0.349, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.7s, rate=0.357, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=56.0s, rate=0.367, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.3s, rate=0.374, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.6s, rate=0.379, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.9s, rate=0.384, medians=[0.942, 0.00844, 0.674], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=8: ok in 65.95s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.243, medians=[0.867, 0.00632, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.237, medians=[0.875, 0.00664, 0.492], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.250, medians=[0.890, 0.00687, 0.520], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.253, medians=[0.901, 0.00709, 0.545], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.256, medians=[0.913, 0.00728, 0.570], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.270, medians=[0.924, 0.00745, 0.592], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.278, medians=[0.936, 0.00762, 0.617], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.290, medians=[0.947, 0.00779, 0.641], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.301, medians=[0.958, 0.00796, 0.665], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.309, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.317, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.324, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.328, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.337, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.2s, rate=0.343, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.5s, rate=0.349, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.8s, rate=0.355, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.1s, rate=0.361, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.4s, rate=0.366, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.7s, rate=0.369, medians=[0.969, 0.00811, 0.689], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=9: ok in 65.73s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.168, medians=[0.778, 0.00519, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.169, medians=[0.798, 0.00539, 0.361], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.171, medians=[0.811, 0.00558, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.175, medians=[0.823, 0.00575, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.185, medians=[0.836, 0.00591, 0.425], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.199, medians=[0.848, 0.00606, 0.445], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.208, medians=[0.859, 0.00620, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.212, medians=[0.869, 0.00633, 0.482], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.225, medians=[0.879, 0.00645, 0.499], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.1s, rate=0.232, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.3s, rate=0.238, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.6s, rate=0.243, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.9s, rate=0.249, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.3s, rate=0.254, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.6s, rate=0.260, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.9s, rate=0.264, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.2s, rate=0.269, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.5s, rate=0.274, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=61.8s, rate=0.278, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.1s, rate=0.282, medians=[0.888, 0.00657, 0.515], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=10: ok in 65.15s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.151, medians=[0.823, 0.00509, 0.365], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.159, medians=[0.827, 0.00526, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.161, medians=[0.832, 0.00537, 0.393], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.161, medians=[0.838, 0.00547, 0.405], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.170, medians=[0.845, 0.00557, 0.418], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.178, medians=[0.852, 0.00567, 0.431], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.186, medians=[0.857, 0.00575, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.190, medians=[0.862, 0.00583, 0.451], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.197, medians=[0.867, 0.00589, 0.460], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.202, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.207, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.209, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.7s, rate=0.212, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.9s, rate=0.215, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.1s, rate=0.219, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.3s, rate=0.221, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.5s, rate=0.224, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.7s, rate=0.226, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.9s, rate=0.230, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.2s, rate=0.232, medians=[0.872, 0.00596, 0.469], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=11: ok in 64.18s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.183, medians=[0.791, 0.00489, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.154, medians=[0.808, 0.00496, 0.360], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.141, medians=[0.815, 0.00502, 0.369], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.143, medians=[0.821, 0.00508, 0.377], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.146, medians=[0.825, 0.00512, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.146, medians=[0.830, 0.00516, 0.389], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.153, medians=[0.833, 0.00520, 0.395], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.156, medians=[0.837, 0.00524, 0.400], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.159, medians=[0.840, 0.00527, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.161, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.165, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.168, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.168, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.170, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.173, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.174, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.176, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.178, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.179, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.182, medians=[0.843, 0.00530, 0.409], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=12: ok in 64.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.208, medians=[0.835, 0.00516, 0.414], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.185, medians=[0.842, 0.00519, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.180, medians=[0.846, 0.00519, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.178, medians=[0.847, 0.00519, 0.416], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.179, medians=[0.847, 0.00519, 0.417], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.176, medians=[0.847, 0.00520, 0.417], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.177, medians=[0.848, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.177, medians=[0.848, 0.00523, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.175, medians=[0.849, 0.00523, 0.420], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.173, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.173, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.171, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.172, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.170, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.168, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.169, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.169, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.170, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.169, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.170, medians=[0.849, 0.00522, 0.419], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=13: ok in 64.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.126, medians=[0.815, 0.00456, 0.351], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.119, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.122, medians=[0.813, 0.00454, 0.347], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.118, medians=[0.812, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.118, medians=[0.813, 0.00456, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.116, medians=[0.813, 0.00456, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.115, medians=[0.813, 0.00456, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.114, medians=[0.813, 0.00456, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.112, medians=[0.813, 0.00456, 0.349], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.111, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.111, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.108, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.110, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.111, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.112, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.112, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.113, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.113, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.114, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.114, medians=[0.813, 0.00455, 0.348], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=14: ok in 64.06s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.138, medians=[0.826, 0.00363, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.112, medians=[0.797, 0.00370, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.098, medians=[0.787, 0.00373, 0.265], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.095, medians=[0.783, 0.00374, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.091, medians=[0.780, 0.00375, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.089, medians=[0.777, 0.00375, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.087, medians=[0.775, 0.00375, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.086, medians=[0.774, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.085, medians=[0.773, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.085, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.084, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.084, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.083, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.082, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.081, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.081, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.082, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.081, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.080, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.079, medians=[0.772, 0.00376, 0.263], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=15: ok in 63.98s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.088, medians=[0.759, 0.00384, 0.272], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.080, medians=[0.757, 0.00378, 0.267], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.080, medians=[0.758, 0.00374, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.077, medians=[0.757, 0.00371, 0.259], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.077, medians=[0.757, 0.00368, 0.257], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.074, medians=[0.755, 0.00366, 0.254], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.074, medians=[0.754, 0.00364, 0.252], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.075, medians=[0.753, 0.00363, 0.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.073, medians=[0.751, 0.00362, 0.248], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.071, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.070, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.069, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.067, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.066, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.065, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.064, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.063, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.062, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.062, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.062, medians=[0.751, 0.00360, 0.246], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=16: ok in 63.99s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.102, medians=[0.756, 0.00399, 0.292], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.100, medians=[0.757, 0.00389, 0.283], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.092, medians=[0.752, 0.00382, 0.275], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.078, medians=[0.750, 0.00377, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.072, medians=[0.747, 0.00372, 0.263], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.070, medians=[0.745, 0.00368, 0.258], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.069, medians=[0.744, 0.00364, 0.254], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.068, medians=[0.742, 0.00361, 0.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.066, medians=[0.741, 0.00358, 0.247], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.064, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.062, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.061, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.059, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=44.8s, rate=0.059, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=48.0s, rate=0.058, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=51.2s, rate=0.057, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=54.4s, rate=0.055, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=57.6s, rate=0.055, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=60.8s, rate=0.054, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=64.0s, rate=0.054, medians=[0.740, 0.00355, 0.243], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=17: ok in 64.00s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.135, medians=[0.747, 0.00397, 0.291], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.115, medians=[0.741, 0.00389, 0.281], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.102, medians=[0.737, 0.00381, 0.272], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.095, medians=[0.733, 0.00374, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.090, medians=[0.730, 0.00368, 0.257], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.2s, rate=0.083, medians=[0.728, 0.00361, 0.250], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.4s, rate=0.079, medians=[0.727, 0.00356, 0.244], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.6s, rate=0.074, medians=[0.725, 0.00352, 0.239], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=28.8s, rate=0.071, medians=[0.724, 0.00347, 0.234], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.0s, rate=0.069, medians=[0.722, 0.00343, 0.230], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.2s, rate=0.066, medians=[0.722, 0.00343, 0.230], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=38.4s, rate=0.063, medians=[0.722, 0.00343, 0.230], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=41.6s, rate=0.060, medians=[0.722, 0.00343, 0.230], std=[0.0035, 0.000035, 0.0035] [FIXED]
# ...
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.227, medians=[0.677, 0.00805, 0.490], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.1s, rate=0.250, medians=[0.709, 0.00896, 0.560], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.4s, rate=0.281, medians=[0.744, 0.01004, 0.648], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.7s, rate=0.312, medians=[0.780, 0.01136, 0.753], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.0s, rate=0.341, medians=[0.816, 0.01266, 0.871], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.3s, rate=0.362, medians=[0.845, 0.01390, 0.980], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.383, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.9s, rate=0.398, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.415, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.427, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.437, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.447, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.3s, rate=0.458, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.465, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.472, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.477, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.481, medians=[0.871, 0.01498, 1.079], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=25: ok in 65.40s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.132, medians=[0.585, 0.00470, 0.272], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.142, medians=[0.587, 0.00516, 0.297], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.159, medians=[0.599, 0.00581, 0.333], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.8s, rate=0.181, medians=[0.621, 0.00660, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.0s, rate=0.209, medians=[0.648, 0.00758, 0.445], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.3s, rate=0.239, medians=[0.684, 0.00862, 0.525], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.6s, rate=0.267, medians=[0.723, 0.00976, 0.623], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=25.9s, rate=0.295, medians=[0.761, 0.01098, 0.732], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.2s, rate=0.322, medians=[0.795, 0.01231, 0.846], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.6s, rate=0.344, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=35.8s, rate=0.361, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.1s, rate=0.381, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.4s, rate=0.393, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.7s, rate=0.408, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.0s, rate=0.421, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.2s, rate=0.431, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.5s, rate=0.438, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.8s, rate=0.446, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.1s, rate=0.454, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.4s, rate=0.460, medians=[0.824, 0.01352, 0.949], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=26: ok in 65.39s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.197, medians=[0.617, 0.00590, 0.353], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.199, medians=[0.630, 0.00681, 0.401], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.225, medians=[0.655, 0.00792, 0.464], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.256, medians=[0.689, 0.00906, 0.541], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.284, medians=[0.730, 0.01036, 0.639], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.312, medians=[0.771, 0.01166, 0.751], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.338, medians=[0.810, 0.01285, 0.868], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.367, medians=[0.843, 0.01394, 0.977], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.386, medians=[0.871, 0.01506, 1.080], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.401, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.419, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.433, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.446, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.457, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.463, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.470, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.475, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.481, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.485, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.490, medians=[0.894, 0.01618, 1.176], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=27: ok in 65.57s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.215, medians=[0.625, 0.00550, 0.335], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.213, medians=[0.625, 0.00648, 0.380], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.228, medians=[0.646, 0.00763, 0.441], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.251, medians=[0.679, 0.00872, 0.516], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.282, medians=[0.720, 0.00988, 0.611], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.307, medians=[0.761, 0.01112, 0.719], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.336, medians=[0.800, 0.01237, 0.836], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.363, medians=[0.835, 0.01361, 0.956], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.383, medians=[0.864, 0.01482, 1.069], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.399, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.416, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.2s, rate=0.430, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.5s, rate=0.442, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.452, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.461, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.469, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.475, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.480, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.487, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.492, medians=[0.889, 0.01606, 1.173], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=28: ok in 65.50s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.224, medians=[0.640, 0.00574, 0.358], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.231, medians=[0.641, 0.00681, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.249, medians=[0.666, 0.00789, 0.473], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.273, medians=[0.700, 0.00914, 0.556], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.303, medians=[0.741, 0.01030, 0.655], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.332, medians=[0.783, 0.01137, 0.765], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.360, medians=[0.819, 0.01259, 0.876], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.383, medians=[0.851, 0.01384, 0.992], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.401, medians=[0.879, 0.01502, 1.101], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.416, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.428, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.440, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.453, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.463, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.473, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.480, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.6s, rate=0.486, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=58.9s, rate=0.492, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.2s, rate=0.496, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.499, medians=[0.901, 0.01611, 1.196], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=29: ok in 65.49s
# [ Info: [sliding] iter 1000/20000 elapsed=3.2s, rate=0.182, medians=[0.597, 0.00586, 0.345], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/20000 elapsed=6.4s, rate=0.189, medians=[0.620, 0.00670, 0.398], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/20000 elapsed=9.6s, rate=0.215, medians=[0.647, 0.00771, 0.458], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/20000 elapsed=12.9s, rate=0.248, medians=[0.683, 0.00882, 0.537], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/20000 elapsed=16.2s, rate=0.278, medians=[0.724, 0.00999, 0.631], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/20000 elapsed=19.5s, rate=0.305, medians=[0.765, 0.01121, 0.740], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/20000 elapsed=22.8s, rate=0.335, medians=[0.805, 0.01243, 0.860], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/20000 elapsed=26.1s, rate=0.361, medians=[0.839, 0.01364, 0.977], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/20000 elapsed=29.4s, rate=0.383, medians=[0.868, 0.01486, 1.090], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/20000 elapsed=32.7s, rate=0.401, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/20000 elapsed=36.0s, rate=0.416, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 12000/20000 elapsed=39.3s, rate=0.431, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 13000/20000 elapsed=42.6s, rate=0.443, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 14000/20000 elapsed=45.8s, rate=0.452, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 15000/20000 elapsed=49.1s, rate=0.461, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 16000/20000 elapsed=52.4s, rate=0.468, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 17000/20000 elapsed=55.7s, rate=0.477, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 18000/20000 elapsed=59.0s, rate=0.482, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 19000/20000 elapsed=62.3s, rate=0.488, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: [sliding] iter 20000/20000 elapsed=65.5s, rate=0.493, medians=[0.892, 0.01598, 1.188], std=[0.0035, 0.000035, 0.0035] [FIXED]
# [ Info: Dataset 12 chain 1, k=30: ok in 65.56s
# [ Info: All k (1..30) finished for dataset 12. Total time 1955.85s -> output dir: output
