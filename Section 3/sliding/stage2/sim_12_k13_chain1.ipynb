# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots
const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter = 1_000_000
include("functions.jl")
Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :        
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :     
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

KMAX_UPPER = 30 

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

# Fixed output dir
out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = []
if model_tag_sym === :memoryless
    global header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    global header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    global header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    global header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    global header_cont = ["beta", "alpha", "gamma"]   
else
    error("Unknown model tag: $(model_tag_sym)")
end

const FIXED_KMAX = 13

i = 12
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

Random.seed!(2025 + i * 100 + c)
initθ_chain = initθ_for_chain(model_tag_sym) 
t0 = Dates.now()

try
    samples, loglik_aug_vecs =
        mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
            fit_mech=model_tag_sym,
            n_iter=n_iter,
            initθ=initθ_chain,
            KMAX_UPPER=KMAX_UPPER,  k_max_fixed=FIXED_KMAX)

    if size(samples, 1) != n_iter
        error("Chain $c did not complete all iterations.")
    end

    # Save samples
    samples_filename = "samples_sim_$(i)_chain_$(c)_k13.csv"
    write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

    # Save per-time log-likelihoods
    loglik_filename = "loglik_sim_$(i)_chain_$(c)_k13.csv"
    write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

    el = Dates.value(Dates.now() - t0) / 1000
    @info(@sprintf("Dataset %03d chain %d (k=13): ok in %.2fs", i, c, el))
catch err
    el = Dates.value(Dates.now() - t0) / 1000
    @warn(@sprintf("Dataset %03d chain %d (k=13): ERROR - %s after %.2fs", i, c, err))
end

@info "Chain completed -> output dir: $out_dir"
# Out:
# [ Info: [sliding] iter 1000/1000000 elapsed=3.4s, rate=0.166, medians=[0.839, 0.00476, 0.368], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/1000000 elapsed=8.6s, rate=0.147, medians=[0.836, 0.00481, 0.372], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/1000000 elapsed=11.7s, rate=0.141, medians=[0.835, 0.00485, 0.375], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/1000000 elapsed=14.9s, rate=0.142, medians=[0.835, 0.00487, 0.378], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/1000000 elapsed=18.1s, rate=0.142, medians=[0.834, 0.00489, 0.379], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/1000000 elapsed=21.3s, rate=0.143, medians=[0.835, 0.00491, 0.381], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/1000000 elapsed=24.4s, rate=0.144, medians=[0.835, 0.00493, 0.383], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/1000000 elapsed=27.6s, rate=0.145, medians=[0.836, 0.00495, 0.386], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/1000000 elapsed=30.8s, rate=0.146, medians=[0.836, 0.00497, 0.388], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/1000000 elapsed=34.0s, rate=0.149, medians=[0.837, 0.00500, 0.391], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/1000000 elapsed=37.2s, rate=0.146, medians=[0.837, 0.00501, 0.392], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 12000/1000000 elapsed=40.3s, rate=0.144, medians=[0.838, 0.00503, 0.394], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 13000/1000000 elapsed=43.5s, rate=0.145, medians=[0.840, 0.00504, 0.396], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 14000/1000000 elapsed=46.7s, rate=0.147, medians=[0.841, 0.00506, 0.398], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 15000/1000000 elapsed=49.9s, rate=0.147, medians=[0.841, 0.00507, 0.400], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 16000/1000000 elapsed=53.1s, rate=0.148, medians=[0.842, 0.00508, 0.402], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 17000/1000000 elapsed=56.2s, rate=0.149, medians=[0.843, 0.00509, 0.403], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 18000/1000000 elapsed=59.4s, rate=0.148, medians=[0.843, 0.00511, 0.404], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 19000/1000000 elapsed=62.6s, rate=0.149, medians=[0.844, 0.00512, 0.406], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 20000/1000000 elapsed=65.8s, rate=0.150, medians=[0.845, 0.00513, 0.407], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 21000/1000000 elapsed=68.9s, rate=0.151, medians=[0.846, 0.00514, 0.409], std=[0.0153, 0.001247, 0.0251] [ADAPT]
# [ Info: [sliding] iter 22000/1000000 elapsed=72.1s, rate=0.153, medians=[0.846, 0.00515, 0.410], std=[0.0152, 0.001248, 0.0254] [ADAPT]
# [ Info: [sliding] iter 23000/1000000 elapsed=75.3s, rate=0.153, medians=[0.847, 0.00516, 0.411], std=[0.0153, 0.001248, 0.0256] [ADAPT]
# [ Info: [sliding] iter 24000/1000000 elapsed=78.5s, rate=0.154, medians=[0.847, 0.00516, 0.412], std=[0.0155, 0.001248, 0.0258] [ADAPT]
# [ Info: [sliding] iter 25000/1000000 elapsed=81.7s, rate=0.155, medians=[0.848, 0.00517, 0.413], std=[0.0156, 0.001248, 0.0260] [ADAPT]
# [ Info: [sliding] iter 26000/1000000 elapsed=84.9s, rate=0.156, medians=[0.848, 0.00518, 0.414], std=[0.0156, 0.001248, 0.0259] [ADAPT]
# [ Info: [sliding] iter 27000/1000000 elapsed=88.1s, rate=0.156, medians=[0.848, 0.00518, 0.414], std=[0.0154, 0.001248, 0.0257] [ADAPT]
# [ Info: [sliding] iter 28000/1000000 elapsed=91.2s, rate=0.157, medians=[0.849, 0.00519, 0.415], std=[0.0153, 0.001247, 0.0255] [ADAPT]
# [ Info: [sliding] iter 29000/1000000 elapsed=94.4s, rate=0.156, medians=[0.849, 0.00519, 0.415], std=[0.0153, 0.001247, 0.0254] [ADAPT]
# [ Info: [sliding] iter 30000/1000000 elapsed=97.6s, rate=0.157, medians=[0.849, 0.00519, 0.416], std=[0.0151, 0.001247, 0.0252] [ADAPT]
# [ Info: [sliding] iter 31000/1000000 elapsed=100.8s, rate=0.157, medians=[0.849, 0.00520, 0.416], std=[0.0150, 0.001247, 0.0250] [ADAPT]
# [ Info: [sliding] iter 32000/1000000 elapsed=104.0s, rate=0.158, medians=[0.849, 0.00520, 0.417], std=[0.0148, 0.001247, 0.0249] [ADAPT]
# [ Info: [sliding] iter 33000/1000000 elapsed=107.2s, rate=0.158, medians=[0.850, 0.00521, 0.417], std=[0.0147, 0.001246, 0.0247] [ADAPT]
# [ Info: [sliding] iter 34000/1000000 elapsed=110.3s, rate=0.159, medians=[0.850, 0.00521, 0.418], std=[0.0146, 0.001246, 0.0245] [ADAPT]
# [ Info: [sliding] iter 35000/1000000 elapsed=113.5s, rate=0.159, medians=[0.850, 0.00521, 0.418], std=[0.0145, 0.001246, 0.0243] [ADAPT]
# [ Info: [sliding] iter 36000/1000000 elapsed=116.7s, rate=0.160, medians=[0.850, 0.00522, 0.419], std=[0.0145, 0.001246, 0.0242] [ADAPT]
# [ Info: [sliding] iter 37000/1000000 elapsed=119.9s, rate=0.160, medians=[0.851, 0.00522, 0.419], std=[0.0145, 0.001246, 0.0242] [ADAPT]
# [ Info: [sliding] iter 38000/1000000 elapsed=123.1s, rate=0.161, medians=[0.851, 0.00522, 0.419], std=[0.0145, 0.001245, 0.0240] [ADAPT]
# [ Info: [sliding] iter 39000/1000000 elapsed=126.3s, rate=0.161, medians=[0.851, 0.00522, 0.420], std=[0.0144, 0.001245, 0.0238] [ADAPT]
# [ Info: [sliding] iter 40000/1000000 elapsed=129.5s, rate=0.161, medians=[0.851, 0.00523, 0.420], std=[0.0144, 0.001245, 0.0237] [ADAPT]
# [ Info: [sliding] iter 41000/1000000 elapsed=132.6s, rate=0.162, medians=[0.851, 0.00523, 0.420], std=[0.0143, 0.001245, 0.0235] [ADAPT]
# [ Info: [sliding] iter 42000/1000000 elapsed=135.8s, rate=0.162, medians=[0.851, 0.00523, 0.421], std=[0.0142, 0.001244, 0.0233] [ADAPT]
# [ Info: [sliding] iter 43000/1000000 elapsed=139.0s, rate=0.162, medians=[0.852, 0.00523, 0.421], std=[0.0141, 0.001244, 0.0231] [ADAPT]
# [ Info: [sliding] iter 44000/1000000 elapsed=142.2s, rate=0.162, medians=[0.852, 0.00523, 0.421], std=[0.0140, 0.001244, 0.0228] [ADAPT]
# [ Info: [sliding] iter 45000/1000000 elapsed=145.4s, rate=0.162, medians=[0.852, 0.00523, 0.421], std=[0.0139, 0.001243, 0.0226] [ADAPT]
# [ Info: [sliding] iter 46000/1000000 elapsed=148.6s, rate=0.162, medians=[0.852, 0.00523, 0.421], std=[0.0138, 0.001243, 0.0224] [ADAPT]
# [ Info: [sliding] iter 47000/1000000 elapsed=151.7s, rate=0.162, medians=[0.852, 0.00523, 0.421], std=[0.0137, 0.001243, 0.0221] [ADAPT]
# [ Info: [sliding] iter 48000/1000000 elapsed=154.9s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0136, 0.001243, 0.0220] [ADAPT]
# [ Info: [sliding] iter 49000/1000000 elapsed=158.1s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0136, 0.001242, 0.0218] [ADAPT]
# [ Info: [sliding] iter 50000/1000000 elapsed=161.3s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0135, 0.001242, 0.0216] [ADAPT]
# [ Info: [sliding] iter 51000/1000000 elapsed=164.5s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0134, 0.001242, 0.0214] [ADAPT]
# [ Info: [sliding] iter 52000/1000000 elapsed=167.7s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0133, 0.001242, 0.0212] [ADAPT]
# [ Info: [sliding] iter 53000/1000000 elapsed=170.8s, rate=0.162, medians=[0.852, 0.00524, 0.421], std=[0.0133, 0.001242, 0.0210] [ADAPT]
# [ Info: [sliding] iter 54000/1000000 elapsed=174.0s, rate=0.162, medians=[0.852, 0.00524, 0.422], std=[0.0132, 0.001242, 0.0208] [ADAPT]
# [ Info: [sliding] iter 55000/1000000 elapsed=177.2s, rate=0.162, medians=[0.852, 0.00524, 0.422], std=[0.0131, 0.001241, 0.0207] [ADAPT]
# [ Info: [sliding] iter 56000/1000000 elapsed=180.4s, rate=0.162, medians=[0.852, 0.00524, 0.422], std=[0.0131, 0.001241, 0.0206] [ADAPT]
# [ Info: [sliding] iter 57000/1000000 elapsed=183.6s, rate=0.163, medians=[0.852, 0.00524, 0.422], std=[0.0131, 0.001241, 0.0205] [ADAPT]
# [ Info: [sliding] iter 58000/1000000 elapsed=186.8s, rate=0.163, medians=[0.852, 0.00525, 0.422], std=[0.0131, 0.001241, 0.0205] [ADAPT]
# [ Info: [sliding] iter 59000/1000000 elapsed=189.9s, rate=0.163, medians=[0.852, 0.00525, 0.423], std=[0.0131, 0.001241, 0.0205] [ADAPT]
# [ Info: [sliding] iter 60000/1000000 elapsed=193.1s, rate=0.163, medians=[0.852, 0.00525, 0.423], std=[0.0130, 0.001241, 0.0204] [ADAPT]
# [ Info: [sliding] iter 61000/1000000 elapsed=196.3s, rate=0.163, medians=[0.852, 0.00525, 0.423], std=[0.0130, 0.001241, 0.0202] [ADAPT]
# [ Info: [sliding] iter 62000/1000000 elapsed=199.5s, rate=0.163, medians=[0.852, 0.00525, 0.423], std=[0.0129, 0.001241, 0.0202] [ADAPT]
# [ Info: [sliding] iter 63000/1000000 elapsed=202.7s, rate=0.163, medians=[0.853, 0.00526, 0.423], std=[0.0129, 0.001241, 0.0202] [ADAPT]
# [ Info: [sliding] iter 64000/1000000 elapsed=205.9s, rate=0.164, medians=[0.853, 0.00526, 0.424], std=[0.0130, 0.001241, 0.0202] [ADAPT]
# [ Info: [sliding] iter 65000/1000000 elapsed=209.0s, rate=0.164, medians=[0.853, 0.00526, 0.424], std=[0.0130, 0.001241, 0.0202] [ADAPT]
# [ Info: [sliding] iter 66000/1000000 elapsed=212.2s, rate=0.163, medians=[0.853, 0.00526, 0.424], std=[0.0130, 0.001241, 0.0202] [ADAPT]
