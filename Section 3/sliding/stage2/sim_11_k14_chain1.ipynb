# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots
const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter = 1_000_000
include("functions.jl")
Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :        
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :     
    error("Unknown data tag: $tag")

model_tag_sym = :sliding
data_tag_sym  = :sliding

KMAX_UPPER = 30 

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

# Fixed output dir
out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = []
if model_tag_sym === :memoryless
    global header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    global header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    global header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    global header_cont = ["beta", "alpha", "gamma", "lambda_R"]
elseif model_tag_sym === :sliding
    global header_cont = ["beta", "alpha", "gamma"]   
else
    error("Unknown model tag: $(model_tag_sym)")
end

const FIXED_KMAX = 14

i = 11
c = 1
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))

Random.seed!(2025 + i * 100 + c)
initθ_chain = initθ_for_chain(model_tag_sym) 
t0 = Dates.now()

try
    samples, loglik_aug_vecs =
        mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
            fit_mech=model_tag_sym,
            n_iter=n_iter,
            initθ=initθ_chain,
            KMAX_UPPER=KMAX_UPPER,  k_max_fixed=FIXED_KMAX)

    if size(samples, 1) != n_iter
        error("Chain $c did not complete all iterations.")
    end

    # Save samples
    samples_filename = "samples_sim_$(i)_chain_$(c)_k14.csv"
    write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

    # Save per-time log-likelihoods
    loglik_filename = "loglik_sim_$(i)_chain_$(c)_k14.csv"
    write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

    el = Dates.value(Dates.now() - t0) / 1000
    @info(@sprintf("Dataset %03d chain %d (k=14): ok in %.2fs", i, c, el))
catch err
    el = Dates.value(Dates.now() - t0) / 1000
    @warn(@sprintf("Dataset %03d chain %d (k=14): ERROR - %s after %.2fs", i, c, err))
end

@info "Chain completed -> output dir: $out_dir"
# Out:
# [ Info: [sliding] iter 1000/1000000 elapsed=3.4s, rate=0.135, medians=[0.826, 0.00429, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 2000/1000000 elapsed=8.6s, rate=0.127, medians=[0.809, 0.00435, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 3000/1000000 elapsed=11.7s, rate=0.118, medians=[0.804, 0.00438, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 4000/1000000 elapsed=14.9s, rate=0.120, medians=[0.802, 0.00438, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 5000/1000000 elapsed=18.0s, rate=0.114, medians=[0.800, 0.00438, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 6000/1000000 elapsed=21.2s, rate=0.112, medians=[0.798, 0.00439, 0.327], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 7000/1000000 elapsed=24.3s, rate=0.113, medians=[0.798, 0.00440, 0.328], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 8000/1000000 elapsed=27.5s, rate=0.114, medians=[0.799, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 9000/1000000 elapsed=30.6s, rate=0.112, medians=[0.798, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 10000/1000000 elapsed=33.8s, rate=0.111, medians=[0.797, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 11000/1000000 elapsed=36.9s, rate=0.109, medians=[0.798, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 12000/1000000 elapsed=40.1s, rate=0.110, medians=[0.797, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 13000/1000000 elapsed=43.2s, rate=0.109, medians=[0.797, 0.00441, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 14000/1000000 elapsed=46.4s, rate=0.109, medians=[0.796, 0.00442, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 15000/1000000 elapsed=49.5s, rate=0.110, medians=[0.796, 0.00442, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 16000/1000000 elapsed=52.7s, rate=0.110, medians=[0.796, 0.00442, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 17000/1000000 elapsed=55.8s, rate=0.110, medians=[0.796, 0.00442, 0.329], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 18000/1000000 elapsed=59.0s, rate=0.111, medians=[0.797, 0.00442, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 19000/1000000 elapsed=62.1s, rate=0.111, medians=[0.797, 0.00442, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 20000/1000000 elapsed=65.3s, rate=0.111, medians=[0.797, 0.00442, 0.330], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [sliding] iter 21000/1000000 elapsed=68.4s, rate=0.112, medians=[0.797, 0.00443, 0.330], std=[0.0161, 0.001231, 0.0047] [ADAPT]
# [ Info: [sliding] iter 22000/1000000 elapsed=71.6s, rate=0.113, medians=[0.797, 0.00443, 0.331], std=[0.0159, 0.001231, 0.0051] [ADAPT]
# [ Info: [sliding] iter 23000/1000000 elapsed=74.8s, rate=0.112, medians=[0.797, 0.00443, 0.331], std=[0.0156, 0.001231, 0.0052] [ADAPT]
# [ Info: [sliding] iter 24000/1000000 elapsed=77.9s, rate=0.112, medians=[0.797, 0.00443, 0.331], std=[0.0153, 0.001231, 0.0051] [ADAPT]
# [ Info: [sliding] iter 25000/1000000 elapsed=81.1s, rate=0.113, medians=[0.797, 0.00443, 0.331], std=[0.0152, 0.001231, 0.0050] [ADAPT]
# [ Info: [sliding] iter 26000/1000000 elapsed=84.3s, rate=0.113, medians=[0.797, 0.00443, 0.331], std=[0.0149, 0.001231, 0.0051] [ADAPT]
# [ Info: [sliding] iter 27000/1000000 elapsed=87.4s, rate=0.112, medians=[0.797, 0.00444, 0.331], std=[0.0147, 0.001231, 0.0054] [ADAPT]
# [ Info: [sliding] iter 28000/1000000 elapsed=90.6s, rate=0.112, medians=[0.797, 0.00444, 0.332], std=[0.0145, 0.001232, 0.0058] [ADAPT]
# [ Info: [sliding] iter 29000/1000000 elapsed=93.8s, rate=0.112, medians=[0.797, 0.00445, 0.332], std=[0.0144, 0.001232, 0.0063] [ADAPT]
# [ Info: [sliding] iter 30000/1000000 elapsed=97.0s, rate=0.112, medians=[0.797, 0.00445, 0.332], std=[0.0142, 0.001232, 0.0064] [ADAPT]
# [ Info: [sliding] iter 31000/1000000 elapsed=100.1s, rate=0.113, medians=[0.797, 0.00445, 0.332], std=[0.0140, 0.001232, 0.0063] [ADAPT]
# [ Info: [sliding] iter 32000/1000000 elapsed=103.3s, rate=0.113, medians=[0.797, 0.00445, 0.332], std=[0.0138, 0.001232, 0.0063] [ADAPT]
# [ Info: [sliding] iter 33000/1000000 elapsed=106.5s, rate=0.113, medians=[0.797, 0.00445, 0.333], std=[0.0137, 0.001232, 0.0063] [ADAPT]
# [ Info: [sliding] iter 34000/1000000 elapsed=109.6s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0135, 0.001232, 0.0062] [ADAPT]
# [ Info: [sliding] iter 35000/1000000 elapsed=112.8s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0134, 0.001232, 0.0062] [ADAPT]
# [ Info: [sliding] iter 36000/1000000 elapsed=116.0s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0133, 0.001232, 0.0061] [ADAPT]
# [ Info: [sliding] iter 37000/1000000 elapsed=119.1s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0132, 0.001232, 0.0060] [ADAPT]
# [ Info: [sliding] iter 38000/1000000 elapsed=122.3s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0131, 0.001231, 0.0060] [ADAPT]
# [ Info: [sliding] iter 39000/1000000 elapsed=125.5s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0130, 0.001231, 0.0059] [ADAPT]
# [ Info: [sliding] iter 40000/1000000 elapsed=128.6s, rate=0.114, medians=[0.797, 0.00445, 0.333], std=[0.0128, 0.001231, 0.0059] [ADAPT]
# [ Info: [sliding] iter 41000/1000000 elapsed=131.8s, rate=0.114, medians=[0.797, 0.00445, 0.332], std=[0.0128, 0.001231, 0.0059] [ADAPT]
# [ Info: [sliding] iter 42000/1000000 elapsed=135.0s, rate=0.114, medians=[0.797, 0.00445, 0.332], std=[0.0127, 0.001231, 0.0059] [ADAPT]
# [ Info: [sliding] iter 43000/1000000 elapsed=138.1s, rate=0.114, medians=[0.796, 0.00445, 0.332], std=[0.0127, 0.001231, 0.0060] [ADAPT]
# [ Info: [sliding] iter 44000/1000000 elapsed=141.3s, rate=0.114, medians=[0.796, 0.00445, 0.332], std=[0.0126, 0.001231, 0.0061] [ADAPT]
# [ Info: [sliding] iter 45000/1000000 elapsed=144.5s, rate=0.114, medians=[0.796, 0.00445, 0.332], std=[0.0125, 0.001231, 0.0061] [ADAPT]
# [ Info: [sliding] iter 46000/1000000 elapsed=147.6s, rate=0.114, medians=[0.796, 0.00445, 0.332], std=[0.0125, 0.001231, 0.0063] [ADAPT]
# [ Info: [sliding] iter 47000/1000000 elapsed=150.8s, rate=0.114, medians=[0.796, 0.00445, 0.332], std=[0.0124, 0.001231, 0.0065] [ADAPT]
# [ Info: [sliding] iter 48000/1000000 elapsed=154.0s, rate=0.114, medians=[0.796, 0.00444, 0.331], std=[0.0124, 0.001231, 0.0067] [ADAPT]
# [ Info: [sliding] iter 49000/1000000 elapsed=157.1s, rate=0.113, medians=[0.796, 0.00444, 0.331], std=[0.0123, 0.001231, 0.0068] [ADAPT]
# [ Info: [sliding] iter 50000/1000000 elapsed=160.3s, rate=0.113, medians=[0.796, 0.00444, 0.331], std=[0.0122, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 51000/1000000 elapsed=163.5s, rate=0.114, medians=[0.796, 0.00444, 0.331], std=[0.0122, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 52000/1000000 elapsed=166.6s, rate=0.113, medians=[0.796, 0.00444, 0.331], std=[0.0121, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 53000/1000000 elapsed=169.8s, rate=0.113, medians=[0.795, 0.00444, 0.331], std=[0.0122, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 54000/1000000 elapsed=173.0s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0121, 0.001231, 0.0072] [ADAPT]
# [ Info: [sliding] iter 55000/1000000 elapsed=176.1s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0121, 0.001231, 0.0072] [ADAPT]
# [ Info: [sliding] iter 56000/1000000 elapsed=179.3s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0120, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 57000/1000000 elapsed=182.5s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0120, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 58000/1000000 elapsed=185.6s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0120, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 59000/1000000 elapsed=188.8s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0119, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 60000/1000000 elapsed=192.0s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0119, 0.001231, 0.0071] [ADAPT]
# [ Info: [sliding] iter 61000/1000000 elapsed=195.1s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0118, 0.001231, 0.0070] [ADAPT]
# [ Info: [sliding] iter 62000/1000000 elapsed=198.3s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0117, 0.001231, 0.0070] [ADAPT]
# [ Info: [sliding] iter 63000/1000000 elapsed=201.5s, rate=0.113, medians=[0.795, 0.00444, 0.330], std=[0.0117, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 64000/1000000 elapsed=204.6s, rate=0.112, medians=[0.795, 0.00444, 0.330], std=[0.0116, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 65000/1000000 elapsed=207.8s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0115, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 66000/1000000 elapsed=211.0s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0115, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 67000/1000000 elapsed=214.1s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0115, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 68000/1000000 elapsed=217.3s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0114, 0.001231, 0.0069] [ADAPT]
# [ Info: [sliding] iter 69000/1000000 elapsed=220.5s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0115, 0.001231, 0.0070] [ADAPT]
# [ Info: [sliding] iter 70000/1000000 elapsed=223.6s, rate=0.112, medians=[0.795, 0.00443, 0.330], std=[0.0115, 0.001231, 0.0071] [ADAPT]
