# %%
using Random, Distributions, Statistics, Printf, DelimitedFiles, Dates
using LinearAlgebra
using StatsBase
using QuantileRegressions
using Plots
const bb = 120
const aa = 40
const N = 1_000_000
const I0 = 10
const n_iter = 1_000_000
include("functions.jl")
Random.seed!(2025)

data_file_for(tag::Symbol) =
    tag === :memoryless  ? "data/memoryless.csv" :
    tag === :sliding     ? "data/sliding_kmax14.csv" :          
    tag === :powerlaw    ? "data/powerlaw_lambdaP.csv" :
    tag === :exponential ? "data/exponential_lambdaE.csv" :
    tag === :reciprocal  ? "data/reciprocal_lambdaR.csv" :     
    error("Unknown data tag: $tag")

model_tag_sym = :memoryless
data_tag_sym  = :memoryless

KMAX_UPPER = 30  

data_path = data_file_for(data_tag_sym)
raw, hdr = DelimitedFiles.readdlm(data_path, ',', header=true)
raw = Matrix{Float64}(raw)
tau = size(raw, 2) ÷ 3

# Fixed output dir
out_dir = "output"
isdir(out_dir) || mkpath(out_dir)

header_cont = []
if model_tag_sym === :memoryless
    global header_cont = ["beta", "alpha", "gamma"]
elseif model_tag_sym === :powerlaw
    global header_cont = ["beta", "alpha", "gamma", "lambda_P"]
elseif model_tag_sym === :exponential
    global header_cont = ["beta", "alpha", "gamma", "lambda_E"]
elseif model_tag_sym === :reciprocal
    global header_cont = ["beta", "alpha", "gamma", "lambda_R"] 
elseif model_tag_sym === :sliding
    global header_cont = ["beta", "alpha", "gamma"]            
else
    error("Unknown model tag: $(model_tag_sym)")
end

i = 14
c = 2
Istar_obs = Vector{Int}(round.(Int, raw[i, 1:tau]))
@info "[$(String(model_tag_sym))_model_$(String(data_tag_sym))_data] Fitting dataset $(i) chain $(c) (tau=$tau)"

Random.seed!(2025 + i * 100 + c)
initθ_chain = initθ_for_chain(model_tag_sym) 
t0 = Dates.now()

try
    samples, loglik_aug_vecs =
        mcmc_one_chain_with_Rstar!(Istar_obs, N, I0;
            fit_mech=model_tag_sym,
            n_iter=n_iter,
            initθ=initθ_chain,
            KMAX_UPPER=KMAX_UPPER)

    if size(samples, 1) != n_iter
        error("Chain $c did not complete all iterations.")
    end

    # Save samples
    samples_filename = "samples_sim_$(i)_chain_$(c).csv"
    write_csv(joinpath(out_dir, samples_filename), header_cont, samples)

    # Save per-time log-likelihoods (thinned & post-burnin inside mcmc)
    loglik_filename = "loglik_sim_$(i)_chain_$(c).csv"
    write_csv(joinpath(out_dir, loglik_filename), ["loglik"], hcat(loglik_aug_vecs))

    el = Dates.value(Dates.now() - t0) / 1000
    @info(@sprintf("Dataset %03d chain %d: ok in %.2fs", i, c, el))
catch err
    el = Dates.value(Dates.now() - t0) / 1000
    @warn(@sprintf("Dataset %03d chain %d: ERROR - %s after %.2fs", i, c, err))
end

@info "Chain completed -> output dir: $out_dir"
# Out:
# [ Info: [memoryless_model_memoryless_data] Fitting dataset 14 chain 2 (tau=50)
# [ Info: [memoryless] iter 1000/1000000 elapsed=3.4s, rate=0.117, medians=[0.805, 0.00369, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 2000/1000000 elapsed=7.3s, rate=0.108, medians=[0.808, 0.00365, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 3000/1000000 elapsed=10.5s, rate=0.105, medians=[0.801, 0.00367, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 4000/1000000 elapsed=13.7s, rate=0.102, medians=[0.798, 0.00369, 0.264], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 5000/1000000 elapsed=16.8s, rate=0.102, medians=[0.798, 0.00371, 0.266], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 6000/1000000 elapsed=20.0s, rate=0.104, medians=[0.799, 0.00372, 0.268], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 7000/1000000 elapsed=23.1s, rate=0.101, medians=[0.801, 0.00372, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 8000/1000000 elapsed=26.3s, rate=0.102, medians=[0.800, 0.00373, 0.269], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 9000/1000000 elapsed=29.5s, rate=0.099, medians=[0.801, 0.00373, 0.270], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 10000/1000000 elapsed=32.6s, rate=0.100, medians=[0.802, 0.00374, 0.272], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 11000/1000000 elapsed=35.8s, rate=0.100, medians=[0.803, 0.00376, 0.274], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 12000/1000000 elapsed=38.9s, rate=0.101, medians=[0.803, 0.00377, 0.275], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 13000/1000000 elapsed=42.1s, rate=0.103, medians=[0.803, 0.00379, 0.277], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 14000/1000000 elapsed=45.3s, rate=0.104, medians=[0.803, 0.00380, 0.278], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 15000/1000000 elapsed=48.4s, rate=0.107, medians=[0.804, 0.00381, 0.280], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 16000/1000000 elapsed=51.6s, rate=0.107, medians=[0.804, 0.00383, 0.282], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 17000/1000000 elapsed=54.7s, rate=0.109, medians=[0.805, 0.00385, 0.284], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 18000/1000000 elapsed=57.9s, rate=0.110, medians=[0.805, 0.00387, 0.286], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 19000/1000000 elapsed=61.1s, rate=0.111, medians=[0.805, 0.00389, 0.288], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 20000/1000000 elapsed=64.2s, rate=0.111, medians=[0.805, 0.00390, 0.289], std=[0.0035, 0.000035, 0.0035] [ADAPT]
# [ Info: [memoryless] iter 21000/1000000 elapsed=67.4s, rate=0.112, medians=[0.806, 0.00391, 0.291], std=[0.0164, 0.001253, 0.0256] [ADAPT]
# [ Info: [memoryless] iter 22000/1000000 elapsed=70.6s, rate=0.113, medians=[0.806, 0.00393, 0.292], std=[0.0164, 0.001255, 0.0263] [ADAPT]
# [ Info: [memoryless] iter 23000/1000000 elapsed=73.7s, rate=0.114, medians=[0.806, 0.00395, 0.294], std=[0.0162, 0.001259, 0.0277] [ADAPT]
# [ Info: [memoryless] iter 24000/1000000 elapsed=76.9s, rate=0.115, medians=[0.806, 0.00396, 0.295], std=[0.0160, 0.001260, 0.0284] [ADAPT]
# [ Info: [memoryless] iter 25000/1000000 elapsed=80.1s, rate=0.115, medians=[0.807, 0.00397, 0.297], std=[0.0160, 0.001261, 0.0289] [ADAPT]
# [ Info: [memoryless] iter 26000/1000000 elapsed=83.2s, rate=0.116, medians=[0.807, 0.00398, 0.298], std=[0.0159, 0.001262, 0.0293] [ADAPT]
# [ Info: [memoryless] iter 27000/1000000 elapsed=86.4s, rate=0.117, medians=[0.807, 0.00399, 0.299], std=[0.0157, 0.001262, 0.0293] [ADAPT]
# [ Info: [memoryless] iter 28000/1000000 elapsed=89.6s, rate=0.117, medians=[0.807, 0.00400, 0.300], std=[0.0155, 0.001261, 0.0291] [ADAPT]
# [ Info: [memoryless] iter 29000/1000000 elapsed=92.8s, rate=0.118, medians=[0.807, 0.00401, 0.300], std=[0.0153, 0.001262, 0.0292] [ADAPT]
# [ Info: [memoryless] iter 30000/1000000 elapsed=95.9s, rate=0.119, medians=[0.807, 0.00402, 0.301], std=[0.0153, 0.001262, 0.0292] [ADAPT]
# [ Info: [memoryless] iter 31000/1000000 elapsed=99.1s, rate=0.118, medians=[0.807, 0.00402, 0.302], std=[0.0152, 0.001261, 0.0291] [ADAPT]
# [ Info: [memoryless] iter 32000/1000000 elapsed=102.3s, rate=0.119, medians=[0.807, 0.00402, 0.302], std=[0.0152, 0.001261, 0.0287] [ADAPT]
# [ Info: [memoryless] iter 33000/1000000 elapsed=105.4s, rate=0.118, medians=[0.808, 0.00402, 0.302], std=[0.0152, 0.001260, 0.0282] [ADAPT]
# [ Info: [memoryless] iter 34000/1000000 elapsed=108.6s, rate=0.118, medians=[0.808, 0.00403, 0.303], std=[0.0150, 0.001259, 0.0279] [ADAPT]
# [ Info: [memoryless] iter 35000/1000000 elapsed=111.8s, rate=0.119, medians=[0.808, 0.00403, 0.303], std=[0.0150, 0.001258, 0.0276] [ADAPT]
# [ Info: [memoryless] iter 36000/1000000 elapsed=115.0s, rate=0.119, medians=[0.808, 0.00403, 0.303], std=[0.0150, 0.001258, 0.0275] [ADAPT]
# [ Info: [memoryless] iter 37000/1000000 elapsed=118.1s, rate=0.119, medians=[0.808, 0.00404, 0.304], std=[0.0150, 0.001258, 0.0275] [ADAPT]
# [ Info: [memoryless] iter 38000/1000000 elapsed=121.3s, rate=0.119, medians=[0.809, 0.00404, 0.305], std=[0.0155, 0.001258, 0.0275] [ADAPT]
# [ Info: [memoryless] iter 39000/1000000 elapsed=124.5s, rate=0.119, medians=[0.809, 0.00404, 0.305], std=[0.0158, 0.001257, 0.0274] [ADAPT]
# [ Info: [memoryless] iter 40000/1000000 elapsed=127.7s, rate=0.119, medians=[0.809, 0.00405, 0.306], std=[0.0158, 0.001257, 0.0273] [ADAPT]
# [ Info: [memoryless] iter 41000/1000000 elapsed=130.8s, rate=0.119, medians=[0.810, 0.00405, 0.306], std=[0.0158, 0.001256, 0.0271] [ADAPT]
# [ Info: [memoryless] iter 42000/1000000 elapsed=134.0s, rate=0.119, medians=[0.810, 0.00405, 0.306], std=[0.0158, 0.001256, 0.0270] [ADAPT]
# [ Info: [memoryless] iter 43000/1000000 elapsed=137.2s, rate=0.119, medians=[0.810, 0.00406, 0.307], std=[0.0158, 0.001256, 0.0269] [ADAPT]
# [ Info: [memoryless] iter 44000/1000000 elapsed=140.4s, rate=0.119, medians=[0.810, 0.00406, 0.307], std=[0.0157, 0.001256, 0.0269] [ADAPT]
# [ Info: [memoryless] iter 45000/1000000 elapsed=143.5s, rate=0.120, medians=[0.810, 0.00406, 0.307], std=[0.0156, 0.001255, 0.0266] [ADAPT]
