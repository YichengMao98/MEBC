# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_power.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_power.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_exp.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_exp.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_memoryless.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_memoryless.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_rep.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_rep.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_k14.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_k14.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    tr  = "truth" if "truth" in cols else cols[-1]
    return df, Day, med, lo, hi, tr

# ---------- only Istar ----------
df, Day, med, lo, hi, tr = load_df("Istar_stats_with_truth_k7.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.plot(df[Day], df[tr], color="red", linestyle="--", label="Truth")
plt.xlabel("Day")
plt.ylabel(r"$I_t^*$")
plt.tight_layout()
plt.savefig("Istar_vs_truth_k7.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_power.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_power.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_exp.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_exp.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_memoryless.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_memoryless.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_rep.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_rep.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_k14.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_k14.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high","truth"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("alarm_stats_k7.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.xlabel("Day")
plt.ylabel(r"$a_t$")
plt.tight_layout()
plt.savefig("alarm_stats_k7.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_power.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_power.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_exp.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_exp.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_rep.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_rep.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_memoryless.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_memoryless.png", dpi=200)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6, in load_df(path)
#       5 try:
# ----> 6     df = pd.read_csv(path)
#       7 except:
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871 if ioargs.encoding and "b" not in ioargs.mode:
#     872     # Encoding
# --> 873     handle = open(
#     874         handle,
#     875         ioargs.mode,
#     876         encoding=ioargs.encoding,
#     877         errors=errors,
#     878         newline="",
#     879     )
#     880 else:
#     881     # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Rt_stats_memoryless.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 17
#      14     med = "median" if "median" in cols else cols[1]
#      15     return df, Day, med, lo, hi
# ---> 17 df, Day, med, lo, hi = load_df("Rt_stats_memoryless.csv")
#      19 plt.figure(figsize=(6,4))
#      20 plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
#
# Cell In[3], line 8, in load_df(path)
#       6     df = pd.read_csv(path)
#       7 except:
# ----> 8     df = pd.read_csv(path, header=None)
#       9     df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
#      10 cols = df.columns.tolist()
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /sw/arch/RHEL9/EB_production/2024/software/SciPy-bundle/2024.05-gfbf-2024a/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Rt_stats_memoryless.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_k14.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_k14.png", dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_df(path):
    try:
        df = pd.read_csv(path)
    except:
        df = pd.read_csv(path, header=None)
        df.columns = ["Day","median","ci_low","ci_high"][:df.shape[1]]
    cols = df.columns.tolist()
    Day = "Day" if "Day" in cols else cols[0]
    lo  = "ci_low" if "ci_low" in cols else cols[2]
    hi  = "ci_high" if "ci_high" in cols else cols[3]
    med = "median" if "median" in cols else cols[1]
    return df, Day, med, lo, hi

df, Day, med, lo, hi = load_df("Rt_stats_k7.csv")

plt.figure(figsize=(6,4))
plt.fill_between(df[Day], df[lo], df[hi], alpha=0.25, label="95% CI")
plt.plot(df[Day], df[med], color="black", label="Median")
plt.axhline(y=1, color="red", linestyle="--", linewidth=1.5, label=r"$R_0(t)=1$")
plt.xlabel("Day")
plt.ylabel(r"$R_0(t)$")
plt.tight_layout()
plt.savefig("Rt_stats_k7.png", dpi=200)
